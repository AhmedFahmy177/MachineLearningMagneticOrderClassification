# %%
import requests
from bs4 import BeautifulSoup

materials = []

url = "https://www.cryst.ehu.es/magndata/search.php?show_db=1"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

for td in soup.find_all("td"):
    text = td.get_text(strip=True)
    if text and text[0] in "01234" and text[1] == ".":
        parts = text.split()  # split "0.1LaMnO3" → ["0.1LaMnO3"] if no space
        label = ''.join(filter(lambda c: c.isdigit() or c == '.', text[:5]))  # safe parse of index (e.g. "0.1")
        link = f"https://www.cryst.ehu.es/magndata/index.php?index={label}"
        materials.append((label, link))

print(f"✅ Found {len(materials)} magnetic materials.")
print(materials[:-5])  # Preview first 5 to verify
# Out:
# ✅ Found 2329 magnetic materials.
# [('0.1', 'https://www.cryst.ehu.es/magndata/index.php?index=0.1'), ('0.2', 'https://www.cryst.ehu.es/magndata/index.php?index=0.2'), ('0.3', 'https://www.cryst.ehu.es/magndata/index.php?index=0.3'), ('0.4', 'https://www.cryst.ehu.es/magndata/index.php?index=0.4'), ('0.5', 'https://www.cryst.ehu.es/magndata/index.php?index=0.5'), ('0.6', 'https://www.cryst.ehu.es/magndata/index.php?index=0.6'), ('0.7', 'https://www.cryst.ehu.es/magndata/index.php?index=0.7'), ('0.8', 'https://www.cryst.ehu.es/magndata/index.php?index=0.8'), ('0.9', 'https://www.cryst.ehu.es/magndata/index.php?index=0.9'), ('0.10', 'https://www.cryst.ehu.es/magndata/index.php?index=0.10'), ('0.11', 'https://www.cryst.ehu.es/magndata/index.php?index=0.11'), ('0.12', 'https://www.cryst.ehu.es/magndata/index.php?index=0.12'), ('0.13', 'https://www.cryst.ehu.es/magndata/index.php?index=0.13'), ('0.14', 'https://www.cryst.ehu.es/magndata/index.php?index=0.14'), ('0.15', 'https://www.cryst.ehu.es/magndata/index.php?index=0.15'), ('0.16', 'https://www.cryst.ehu.es/magndata/index.php?index=0.16'), ('0.17', 'https://www.cryst.ehu.es/magndata/index.php?index=0.17'), ('0.18', 'https://www.cryst.ehu.es/magndata/index.php?index=0.18'), ('0.19', 'https://www.cryst.ehu.es/magndata/index.php?index=0.19'), ('0.20', 'https://www.cryst.ehu.es/magndata/index.php?index=0.20'), ('0.21', 'https://www.cryst.ehu.es/magndata/index.php?index=0.21'), ('0.22', 'https://www.cryst.ehu.es/magndata/index.php?index=0.22'), ('0.23', 'https://www.cryst.ehu.es/magndata/index.php?index=0.23'), ('0.24', 'https://www.cryst.ehu.es/magndata/index.php?index=0.24'), ('0.25', 'https://www.cryst.ehu.es/magndata/index.php?index=0.25'), ('0.26', 'https://www.cryst.ehu.es/magndata/index.php?index=0.26'), ('0.27', 'https://www.cryst.ehu.es/magndata/index.php?index=0.27'), ('0.28', 'https://www.cryst.ehu.es/magndata/index.php?index=0.28'), ('0.29', 'https://www.cryst.ehu.es/magndata/index.php?index=0.29'), ('0.30', 'https://www.cryst.ehu.es/magndata/index.php?index=0.30'), ('0.31', 'https://www.cryst.ehu.es/magndata/index.php?index=0.31'), ('0.32', 'https://www.cryst.ehu.es/magndata/index.php?index=0.32'), ('0.33', 'https://www.cryst.ehu.es/magndata/index.php?index=0.33'), ('0.34', 'https://www.cryst.ehu.es/magndata/index.php?index=0.34'), ('0.35', 'https://www.cryst.ehu.es/magndata/index.php?index=0.35'), ('0.36', 'https://www.cryst.ehu.es/magndata/index.php?index=0.36'), ('0.37', 'https://www.cryst.ehu.es/magndata/index.php?index=0.37'), ('0.38', 'https://www.cryst.ehu.es/magndata/index.php?index=0.38'), ('0.39', 'https://www.cryst.ehu.es/magndata/index.php?index=0.39'), ('0.40', 'https://www.cryst.ehu.es/magndata/index.php?index=0.40'), ('0.41', 'https://www.cryst.ehu.es/magndata/index.php?index=0.41'), ('0.42', 'https://www.cryst.ehu.es/magndata/index.php?index=0.42'), ('0.43', 'https://www.cryst.ehu.es/magndata/index.php?index=0.43'), ('0.44', 'https://www.cryst.ehu.es/magndata/index.php?index=0.44'), ('0.45', 'https://www.cryst.ehu.es/magndata/index.php?index=0.45'), ('0.46', 'https://www.cryst.ehu.es/magndata/index.php?index=0.46'), ('0.47', 'https://www.cryst.ehu.es/magndata/index.php?index=0.47'), ('0.48', 'https://www.cryst.ehu.es/magndata/index.php?index=0.48'), ('0.49', 'https://www.cryst.ehu.es/magndata/index.php?index=0.49'), ('0.50', 'https://www.cryst.ehu.es/magndata/index.php?index=0.50'), ('0.51', 'https://www.cryst.ehu.es/magndata/index.php?index=0.51'), ('0.52', 'https://www.cryst.ehu.es/magndata/index.php?index=0.52'), ('0.53', 'https://www.cryst.ehu.es/magndata/index.php?index=0.53'), ('0.54', 'https://www.cryst.ehu.es/magndata/index.php?index=0.54'), ('0.55', 'https://www.cryst.ehu.es/magndata/index.php?index=0.55'), ('0.56', 'https://www.cryst.ehu.es/magndata/index.php?index=0.56'), ('0.57', 'https://www.cryst.ehu.es/magndata/index.php?index=0.57'), ('0.58', 'https://www.cryst.ehu.es/magndata/index.php?index=0.58'), ('0.59', 'https://www.cryst.ehu.es/magndata/index.php?index=0.59'), ('0.6 ...

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# Step 1: Request HTML page
url = "https://www.cryst.ehu.es/magndata/search.php?show_db=1"
response = requests.get(url)

# Step 2: Parse the HTML content
soup = BeautifulSoup(response.content, "html.parser")

materials = []

# Step 3: Loop through all <td> entries
for td in soup.find_all("td"):
    text = td.get_text(strip=True)

    # Extract numeric label (e.g., 0.1) from full label (e.g., 0.1LaMnO3)
    match = re.match(r"^([0-4]\.\d+)", text)
    if match:
        numeric_label = match.group(1)
        full_label = text
        link = f"https://www.cryst.ehu.es/magndata/index.php?this_label={numeric_label}"
        materials.append({
            "Full Label": full_label,
            "Numeric Label": numeric_label,
            "URL": link
        })

# Step 4: Convert to DataFrame and export to CSV
df = pd.DataFrame(materials)
csv_filename = "MAGNDATA Magnetic Materials.csv"
df.to_csv(csv_filename, index=False)

# Done
print(f"✅ Saved {len(df)} entries to '{csv_filename}'")
print(df.head())  # Show a preview
# Out:
# ✅ Saved 2329 entries to 'MAGNDATA Magnetic Materials.csv'
#      Full Label Numeric Label  \
# 0     0.1LaMnO3           0.1
# 1   0.2Cd2Os2O7           0.2
# 2  0.3Ca3LiOsO6           0.3
# 3    0.4NiCr2O4           0.4
# 4      0.5Cr2S3           0.5
#
#                                                  URL
# 0  https://www.cryst.ehu.es/magndata/index.php?th...
# 1  https://www.cryst.ehu.es/magndata/index.php?th...
# 2  https://www.cryst.ehu.es/magndata/index.php?th...
# 3  https://www.cryst.ehu.es/magndata/index.php?th...
# 4  https://www.cryst.ehu.es/magndata/index.php?th...

# %%
import pandas as pd

# Load the original CSV
df = pd.read_csv("MAGNDATA Magnetic Materials.csv")

# Keep only the first 2168 rows (up to index 2168, which is row 2169 in Excel/Calc)
df_trimmed = df.iloc[:2167]

# Save to new file
df_trimmed.to_csv("MAGNDATA_Commensurate_Only.csv", index=False)

print(f"✅ Saved {len(df_trimmed)} commensurate materials to 'MAGNDATA_Commensurate_Only.csv'")
# Out:
# ✅ Saved 2167 commensurate materials to 'MAGNDATA_Commensurate_Only.csv'

# %%
print(df.head())  # Show a preview
# Out:
#      Full Label  Numeric Label  \
# 0     0.1LaMnO3            0.1
# 1   0.2Cd2Os2O7            0.2
# 2  0.3Ca3LiOsO6            0.3
# 3    0.4NiCr2O4            0.4
# 4      0.5Cr2S3            0.5
#
#                                                  URL
# 0  https://www.cryst.ehu.es/magndata/index.php?th...
# 1  https://www.cryst.ehu.es/magndata/index.php?th...
# 2  https://www.cryst.ehu.es/magndata/index.php?th...
# 3  https://www.cryst.ehu.es/magndata/index.php?th...
# 4  https://www.cryst.ehu.es/magndata/index.php?th...

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import time

# Load dataset
df = pd.read_csv("MAGNDATA_Commensurate_Only.csv")

# Function to extract propagation vector
def get_propagation_vector(url):
    try:
        response = requests.get(url, timeout=10)
        soup = BeautifulSoup(response.content, "html.parser")
        text = soup.get_text()
        
        # Look for: Propagation vector: k1 (1/2, 0, 1/2)
        match = re.search(r"Propagation vector:\s*k\d?\s*\((.*?)\)", text)
        if match:
            return match.group(1).strip()
        else:
            return "Not found"
    except Exception as e:
        return f"Error: {e}"

# Prepare new column
propagation_vectors = []

# Loop and extract with live printing
for i, (label, url) in enumerate(zip(df["Full Label"], df["URL"]), start=1):
    vector = get_propagation_vector(url)
    propagation_vectors.append(vector)
    print(f"🔍 {i:4d}/{len(df)} — {label:<20} → Propagation vector: {vector}")
    time.sleep(0.5)  # be polite

# Add new column and save result
df["Propagation Vector"] = propagation_vectors
df.to_csv("MAGNDATA_Commensurate_WithVectors.csv", index=False)
print("✅ All done! Results saved to 'MAGNDATA_Commensurate_WithVectors.csv'")
# Out:
# 🔍    1/2167 — 0.1LaMnO3            → Propagation vector: 0, 0, 0
# 🔍    2/2167 — 0.2Cd2Os2O7          → Propagation vector: 0, 0, 0
# 🔍    3/2167 — 0.3Ca3LiOsO6         → Propagation vector: 0, 0, 0
# 🔍    4/2167 — 0.4NiCr2O4           → Propagation vector: 0, 0, 0
# 🔍    5/2167 — 0.5Cr2S3             → Propagation vector: 0, 0, 0
# 🔍    6/2167 — 0.6YMnO3             → Propagation vector: 0, 0, 0
# 🔍    7/2167 — 0.7ScMnO3            → Propagation vector: 0, 0, 0
# 🔍    8/2167 — 0.8ScMnO3            → Propagation vector: 0, 0, 0
# 🔍    9/2167 — 0.9GdB4              → Propagation vector: 0, 0, 0
# 🔍   10/2167 — 0.10DyFeO3           → Propagation vector: 0, 0, 0
# 🔍   11/2167 — 0.11DyFeO3           → Propagation vector: 0, 0, 0
# 🔍   12/2167 — 0.12U3Ru4Al12        → Propagation vector: 0, 0, 0
# 🔍   13/2167 — 0.13Ca3Co2-xMnxO6    → Propagation vector: 0, 0, 0
# 🔍   14/2167 — 0.14Gd5Ge4           → Propagation vector: 0, 0, 0
# 🔍   15/2167 — 0.15MnF2             → Propagation vector: 0, 0, 0
# 🔍   16/2167 — 0.16EuTiO3           → Propagation vector: 0, 0, 0
# 🔍   17/2167 — 0.17FePO4            → Propagation vector: 0, 0, 0
# 🔍   18/2167 — 0.18BaMn2As2         → Propagation vector: 0, 0, 0
# 🔍   19/2167 — 0.19MnTiO3           → Propagation vector: 0, 0, 0
# 🔍   20/2167 — 0.20MnTe2            → Propagation vector: 0, 0, 0
# 🔍   21/2167 — 0.21PbNiO3           → Propagation vector: 0, 0, 0
# 🔍   22/2167 — 0.22DyB4             → Propagation vector: 0, 0, 0
# 🔍   23/2167 — 0.23Ca3Mn2O7         → Propagation vector: 0, 0, 0
# 🔍   24/2167 — 0.24LiMnPO4          → Propagation vector: 0, 0, 0
# 🔍   25/2167 — 0.25NaOsO3           → Propagation vector: 0, 0, 0
# 🔍   26/2167 — 0.26TmAgGe           → Propagation vector: 0, 0, 0
# 🔍   27/2167 — 0.27YFe4Ge2          → Propagation vector: 0, 0, 0
# 🔍   28/2167 — 0.28LiFeSi2O6        → Propagation vector: 0, 0, 0
# 🔍   29/2167 — 0.29Er2Ti2O7         → Propagation vector: 0, 0, 0
# 🔍   30/2167 — 0.30YbMnO3           → Propagation vector: 0, 0, 0
# 🔍   31/2167 — 0.31HoMnO3           → Propagation vector: 0, 0, 0
# 🔍   32/2167 — 0.32HoMnO3           → Propagation vector: 0, 0, 0
# 🔍   33/2167 — 0.33HoMnO3           → Propagation vector: 0, 0, 0
# 🔍   34/2167 — 0.34La0.5Sr0.5FeO2.5F0.5 → Propagation vector: 0, 0, 0
# 🔍   35/2167 — 0.35Cu2OSeO3         → Propagation vector: 0, 0, 0
# 🔍   36/2167 — 0.36NiF2             → Propagation vector: 0, 0, 0
# 🔍   37/2167 — 0.37U3Al2Si3         → Propagation vector: 0, 0, 0
# 🔍   38/2167 — 0.38GaFeO3           → Propagation vector: 0, 0, 0
# 🔍   39/2167 — 0.39Nd2NaRuO6        → Propagation vector: 0, 0, 0
# 🔍   40/2167 — 0.40Mn2O3-alpha      → Propagation vector: 0, 0, 0
# 🔍   41/2167 — 0.41Mn2O3-alpha      → Propagation vector: 0, 0, 0
# 🔍   42/2167 — 0.42HoMnO3           → Propagation vector: 0, 0, 0
# 🔍   43/2167 — 0.43HoMnO3           → Propagation vector: 0, 0, 0
# 🔍   44/2167 — 0.44YMnO3            → Propagation vector: 0, 0, 0
# 🔍   45/2167 — 0.45La2NiO4          → Propagation vector: 0, 0, 0
# 🔍   46/2167 — 0.46CaBaCo4O7        → Propagation vector: 0, 0, 0
# 🔍   47/2167 — 0.47Gd2Sn2O7         → Propagation vector: 0, 0, 0
# 🔍   48/2167 — 0.48Tb2Sn2O7         → Propagation vector: 0, 0, 0
# 🔍   49/2167 — 0.49Ho2Ru2O7         → Propagation vector: 0, 0, 0
# 🔍   50/2167 — 0.50MnTiO3           → Propagation vector: 0, 0, 0
# 🔍   51/2167 — 0.51Ho2Ru2O7         → Propagation vector: 0, 0, 0
# 🔍   52/2167 — 0.52KyFe2-xSe2       → Propagation vector: 0, 0, 0
# 🔍   53/2167 — 0.53RbyFe2-xSe2      → Propagation vector: 0, 0, 0
# 🔍   54/2167 — 0.54RbyFe2-xSe2      → Propagation vector: 0, 0, 0
# 🔍   55/2167 — 0.55KyFe2-xSe2       → Propagation vector: 0, 0, 0
# 🔍   56/2167 — 0.56Ba2CoGe2O7       → Propagation vector: 0, 0, 0
# 🔍   57/2167 — 0.57ScFeO3           → Propagation vector: 0, 0, 0
# 🔍   58/2167 — 0.58CoAl2O4          → Propagation vector: 0, 0, 0
# 🔍   59/2167 — 0.59Cr2O3            → Propagation vector: 0, 0, 0
# 🔍   60/2167 — 0.60[NH2(CH3)2]n[FeIIIFeII(HCOO)6]n → Propagation vector: 0, 0, 0
# 🔍   61/2167 — 0.61Li2FeP2O7        → Propagation vector: 0, 0, 0
# 🔍   62/2167 — 0.62SrMn2V2O8        → Propagation vector: 0, 0, 0
# 🔍   63/2167 — 0.63Ho2CrSbO7        → Propagation vector: 0, 0, 0
# 🔍   64/2167 — 0.64MnV2O4           → Propagation vector: 0, 0, 0
# 🔍   65/2167 — 0.65Fe2O3-alpha      → Propagation vector: 0, 0, 0
# 🔍   66/2167 — 0.66Fe2O3-alpha      → Propagation vector: 0, 0, 0
# 🔍   67/2167 — 0.67BiFe0.5Sc0.5O3   → Propagation vector: 0, 0, 0
# 🔍   68/2167 — 0.68BiFe0.5Sc0.5O3   → Propagation vector: 0, 0, 0
# 🔍   69/2167 — 0.69Co4(OH)2(C10H16O4)3 → Propagation vector: 0, 0, 0
# 🔍   70/2167 — 0.70Na3Co(CO3)2Cl    → Propagation vector: 0, 0, 0
# 🔍   71/2167 — 0.71Li2Ni(SO4)2      → Propagation vector: 0, 0, 0
# 🔍   72/2167 — 0.72CaMnBi2          → Propagation vector: 0, 0, 0
# 🔍   73/2167 — 0.73SrMnBi2          → Propagation vector: 0, 0, 0
# 🔍   74/2167 — 0.74Mn3Cu0.5Ge0.5N   → Propagation vector: 0, 0, 0
# 🔍   75/2167 — 0.75Cr2WO6           → Propagation vector: 0, 0, 0
# 🔍   76/2167 — 0.76Cr2TeO6          → Propagation vector: 0, 0, 0
# 🔍   77/2167 — 0.77Tb2Ti2O7         → Propagation vector: 0, 0, 0
# 🔍   78/2167 — 0.78NiN2O6           → Propagation vector: 0, 0, 0
# 🔍   79/2167 — 0.79CaIrO3           → Propagation vector: 0, 0, 0
# 🔍   80/2167 — 0.80U2Pd2In          → Propagation vector: 0, 0, 0
# 🔍   81/2167 — 0.81U2Pd2Sn          → Propagation vector: 0, 0, 0
# 🔍   82/2167 — 0.82Gd2CuO4          → Propagation vector: 0, 0, 0
# 🔍   83/2167 — 0.83LiFeP2O7         → Propagation vector: 0, 0, 0
# 🔍   84/2167 — 0.84Mn2FeMoO6        → Propagation vector: 0, 0, 0
# 🔍   85/2167 — 0.85KCo4(PO4)3       → Propagation vector: 0, 0, 0
# 🔍   86/2167 — 0.86KMn4(PO4)3       → Propagation vector: 0, 0, 0
# 🔍   87/2167 — 0.87NaFePO4          → Propagation vector: 0, 0, 0
# 🔍   88/2167 — 0.88LiNiPO4          → Propagation vector: 0, 0, 0
# 🔍   89/2167 — 0.89BaMn2Bi2         → Propagation vector: 0, 0, 0
# 🔍   90/2167 — 0.90Rb2Fe2O(AsO4)2   → Propagation vector: 0, 0, 0
# 🔍   91/2167 — 0.91Rb2Fe2O(AsO4)2   → Propagation vector: 0, 0, 0
# 🔍   92/2167 — 0.92CaMn2Sb2         → Propagation vector: 0, 0, 0
# 🔍   93/2167 — 0.93Ca2Fe2O5         → Propagation vector: 0, 0, 0
# 🔍   94/2167 — 0.94TeNiO3           → Propagation vector: 0, 0, 0
# 🔍   95/2167 — 0.95LiFePO4          → Propagation vector: 0, 0, 0
# 🔍   96/2167 — 0.96CoSO4            → Propagation vector: 0, 0, 0
# 🔍   97/2167 — 0.97FeSb2O4          → Propagation vector: 0, 0, 0
# 🔍   98/2167 — 0.98YBaMn2O5.5       → Propagation vector: 0, 0, 0
# 🔍   99/2167 — 0.99YBaMn2O5.5       → Propagation vector: 0, 0, 0
# 🔍  100/2167 — 0.100YCr0.5Mn0.5O3   → Propagation vector: 0, 0, 0
# 🔍  101/2167 — 0.101Mn2GeO4         → Propagation vector: 0, 0, 0
# 🔍  102/2167 — 0.102Mn2GeO4         → Propagation vector: 0, 0, 0
# 🔍  103/2167 — 0.103Mn2GeO4         → Propagation vector: 0, 0, 0
# 🔍  104/2167 — 0.104ErVO3           → Propagation vector: 0, 0, 0
# 🔍  105/2167 — 0.105ErVO3           → Propagation vector: 0, 0, 0
# 🔍  106/2167 — 0.106DyVO3           → Propagation vector: 0, 0, 0
# 🔍  107/2167 — 0.107Ho2Ge2O7        → Propagation vector: 0, 0, 0
# 🔍  108/2167 — 0.108Mn3Ir           → Propagation vector: 0, 0, 0
# 🔍  109/2167 — 0.109Mn3Pt           → Propagation vector: 0, 0, 0
# 🔍  110/2167 — 0.110Cr2O3           → Propagation vector: 0, 0, 0
# 🔍  111/2167 — 0.111Co4Nb2O9        → Propagation vector: 0, 0, 0
# 🔍  112/2167 — 0.112FeBO3           → Propagation vector: 0, 0, 0
# 🔍  113/2167 — 0.113NiCO3           → Propagation vector: 0, 0, 0
# 🔍  114/2167 — 0.114CoCO3           → Propagation vector: 0, 0, 0
# 🔍  115/2167 — 0.115MnCO3           → Propagation vector: 0, 0, 0
# 🔍  116/2167 — 0.116FeCO3           → Propagation vector: 0, 0, 0
# 🔍  117/2167 — 0.117LuFeO3          → Propagation vector: 0, 0, 0
# 🔍  118/2167 — 0.118Ba5Co5ClO13     → Propagation vector: 0, 0, 0
# 🔍  119/2167 — 0.119CoSe2O5         → Propagation vector: 0, 0, 0
# 🔍  120/2167 — 0.120LiFe(SO4)2      → Propagation vector: 0, 0, 0
# 🔍  121/2167 — 0.121Li2Co(SO4)2     → Propagation vector: 0, 0, 0
# 🔍  122/2167 — 0.122Li2Mn(SO4)2     → Propagation vector: 0, 0, 0
# 🔍  123/2167 — 0.123Mn3NiN          → Propagation vector: 0, 0, 0
# 🔍  124/2167 — 0.124Mn3NiN          → Propagation vector: 0, 0, 0
# 🔍  125/2167 — 0.125MnGeO3          → Propagation vector: 0, 0, 0
# 🔍  126/2167 — 0.126NpCo2           → Propagation vector: 0, 0, 0
# 🔍  127/2167 — 0.127Dy3Al5O12       → Propagation vector: 0, 0, 0
# 🔍  128/2167 — 0.128FeSO4F          → Propagation vector: 0, 0, 0
# 🔍  129/2167 — 0.129Cu3Mo2O9        → Propagation vector: 0, 0, 0
# 🔍  130/2167 — 0.130Cu3Mo2O9        → Propagation vector: 0, 0, 0
# 🔍  131/2167 — 0.131Mn(N(CN2))2     → Propagation vector: 0, 0, 0
# 🔍  132/2167 — 0.132Fe(N(CN2))2     → Propagation vector: 0, 0, 0
# 🔍  133/2167 — 0.133Ni3B7O13Cl      → Propagation vector: 0, 0, 0
# 🔍  134/2167 — 0.134Mn3B7O13I       → Propagation vector: 0, 0, 0
# 🔍  135/2167 — 0.135Ni3B7O13Br      → Propagation vector: 0, 0, 0
# 🔍  136/2167 — 0.136Co3B7O13Br      → Propagation vector: 0, 0, 0
# 🔍  137/2167 — 0.137Cu2V2O7         → Propagation vector: 0, 0, 0
# 🔍  138/2167 — 0.138BiCrO3          → Propagation vector: 0, 0, 0
# 🔍  139/2167 — 0.139BiCrO3          → Propagation vector: 0, 0, 0
# 🔍  140/2167 — 0.140LuFe4Ge2        → Propagation vector: 0, 0, 0
# 🔍  141/2167 — 0.141Tb5Ge4          → Propagation vector: 0, 0, 0
# 🔍  142/2167 — 0.142Fe2TeO6         → Propagation vector: 0, 0, 0
# 🔍  143/2167 — 0.143Cr2TeO6         → Propagation vector: 0, 0, 0
# 🔍  144/2167 — 0.144Cr2WO6          → Propagation vector: 0, 0, 0
# 🔍  145/2167 — 0.145Co3TeO6         → Propagation vector: 0, 0, 0
# 🔍  146/2167 — 0.146EuZrO3          → Propagation vector: 0, 0, 0
# 🔍  147/2167 — 0.147EuZrO3          → Propagation vector: 0, 0, 0
# 🔍  148/2167 — 0.148La2LiRuO6       → Propagation vector: 0, 0, 0
# 🔍  149/2167 — 0.149Nd3Ru4Al12      → Propagation vector: 0, 0, 0
# 🔍  150/2167 — 0.150NiS2            → Propagation vector: 0, 0, 0
# 🔍  151/2167 — 0.151Tm2Mn2O7        → Propagation vector: 0, 0, 0
# 🔍  152/2167 — 0.152LiFePO4         → Propagation vector: 0, 0, 0
# 🔍  153/2167 — 0.153Bi2RuMnO7       → Propagation vector: 0, 0, 0
# 🔍  154/2167 — 0.154Er2Ru2O7        → Propagation vector: 0, 0, 0
# 🔍  155/2167 — 0.155CaMnGe2O6       → Propagation vector: 0, 0, 0
# 🔍  156/2167 — 0.156CaMnGe2O6       → Propagation vector: 0, 0, 0
# 🔍  157/2167 — 0.157Yb2Sn2O7        → Propagation vector: 0, 0, 0
# 🔍  158/2167 — 0.158Yb2Ti2O7        → Propagation vector: 0, 0, 0
# 🔍  159/2167 — 0.159DyCoO3          → Propagation vector: 0, 0, 0
# 🔍  160/2167 — 0.160TbCoO3          → Propagation vector: 0, 0, 0
# 🔍  161/2167 — 0.161CoSe2O5         → Propagation vector: 0, 0, 0
# 🔍  162/2167 — 0.162NdCrTiO5        → Propagation vector: 0, 0, 0
# 🔍  163/2167 — 0.163MnPS3           → Propagation vector: 0, 0, 0
# 🔍  164/2167 — 0.164Y2MnCoO6        → Propagation vector: 0, 0, 0
# 🔍  165/2167 — 0.165SrMn(VO4)(OH)   → Propagation vector: 0, 0, 0
# 🔍  166/2167 — 0.166Ce2PdGe3        → Propagation vector: 0, 0, 0
# 🔍  167/2167 — 0.167Nd3Sb3Mg2O14    → Propagation vector: 0, 0, 0
# 🔍  168/2167 — 0.168NH4Fe2F6        → Propagation vector: 0, 0, 0
# 🔍  169/2167 — 0.169U3As4           → Propagation vector: 0, 0, 0
# 🔍  170/2167 — 0.170U3P4            → Propagation vector: 0, 0, 0
# 🔍  171/2167 — 0.171DyScO3          → Propagation vector: 0, 0, 0
# 🔍  172/2167 — 0.172Y3Co3.25Al0.75  → Propagation vector: 0, 0, 0
# 🔍  173/2167 — 0.173Pr3Ru4Al12      → Propagation vector: 0, 0, 0
# 🔍  174/2167 — 0.174Pr3Ru4Al12      → Propagation vector: 0, 0, 0
# 🔍  175/2167 — 0.175Ca2CoSi2O7      → Propagation vector: 0, 0, 0
# 🔍  176/2167 — 0.176Mn3Ti2Te6       → Propagation vector: 0, 0, 0
# 🔍  177/2167 — 0.177Mn3GaN          → Propagation vector: 0, 0, 0
# 🔍  178/2167 — 0.178CoF2            → Propagation vector: 0, 0, 0
# 🔍  179/2167 — 0.179FeCl5D2O(ND4)2  → Propagation vector: 0, 0, 0
# 🔍  180/2167 — 0.180MnPSe3          → Propagation vector: 0, 0, 0
# 🔍  181/2167 — 0.181Nd15Ge9C0.39    → Propagation vector: 0, 0, 0
# 🔍  182/2167 — 0.182KCrF4           → Propagation vector: 0, 0, 0
# 🔍  183/2167 — 0.183KMnFeF6         → Propagation vector: 0, 0, 0
# 🔍  184/2167 — 0.184Nd5Si4          → Propagation vector: 0, 0, 0
# 🔍  185/2167 — 0.185Nd5Ge4          → Propagation vector: 0, 0, 0
# 🔍  186/2167 — 0.186CeMnAsO         → Propagation vector: 0, 0, 0
# 🔍  187/2167 — 0.187CeMnAsO         → Propagation vector: 0, 0, 0
# 🔍  188/2167 — 0.188CeMnAsO         → Propagation vector: 0, 0, 0
# 🔍  189/2167 — 0.189CeMn2Ge4O12     → Propagation vector: 0, 0, 0
# 🔍  190/2167 — 0.190CeMnCoGe4O12    → Propagation vector: 0, 0, 0
# 🔍  191/2167 — 0.191BaCuF4          → Propagation vector: 0, 0, 0
# 🔍  192/2167 — 0.192RbFe2F6         → Propagation vector: 0, 0, 0
# 🔍  193/2167 — 0.193LiCoPO4         → Propagation vector: 0, 0, 0
# 🔍  194/2167 — 0.194UPt2Si2         → Propagation vector: 0, 0, 0
# 🔍  195/2167 — 0.195Sr2Ir0.92Sn0.08O4 → Propagation vector: 0, 0, 0
# 🔍  196/2167 — 0.196Co4Nb2O9        → Propagation vector: 0, 0, 0
# 🔍  197/2167 — 0.197Co4Nb2O9        → Propagation vector: 0, 0, 0
# 🔍  198/2167 — 0.198GdVO4           → Propagation vector: 0, 0, 0
# 🔍  199/2167 — 0.199Mn3Sn           → Propagation vector: 0, 0, 0
# 🔍  200/2167 — 0.200Mn3Sn           → Propagation vector: 0, 0, 0
# 🔍  201/2167 — 0.201Ca2PrCr2NbO9    → Propagation vector: 0, 0, 0
# 🔍  202/2167 — 0.202Ca2PrCr2TaO9    → Propagation vector: 0, 0, 0
# 🔍  203/2167 — 0.203Mn3Ge           → Propagation vector: 0, 0, 0
# 🔍  204/2167 — 0.204Ca2MnReO6       → Propagation vector: 0, 0, 0
# 🔍  205/2167 — 0.205Sr2MnReO6       → Propagation vector: 0, 0, 0
# 🔍  206/2167 — 0.206Ca2Fe0.875Cr0.125GaO5 → Propagation vector: 0, 0, 0
# 🔍  207/2167 — 0.207TlFe1.6Se2      → Propagation vector: 0, 0, 0
# 🔍  208/2167 — 0.208TlFe1.6Se2      → Propagation vector: 0, 0, 0
# 🔍  209/2167 — 0.209TlFe1.6Se2      → Propagation vector: 0, 0, 0
# 🔍  210/2167 — 0.210Sr2CoOsO6       → Propagation vector: 0, 0, 0
# 🔍  211/2167 — 0.211Ca2MnO4         → Propagation vector: 0, 0, 0
# 🔍  212/2167 — 0.212Sr2Mn3As2O2     → Propagation vector: 0, 0, 0
# 🔍  213/2167 — 0.213Sr2Mn2CuAs2O2   → Propagation vector: 0, 0, 0
# 🔍  214/2167 — 0.214FePbBiO4        → Propagation vector: 0, 0, 0
# 🔍  215/2167 — 0.215BaNi2P2O8       → Propagation vector: 0, 0, 0
# 🔍  216/2167 — 0.216SrEr2O4         → Propagation vector: 0, 0, 0
# 🔍  217/2167 — 0.217LiCrGe2O6       → Propagation vector: 0, 0, 0
# 🔍  218/2167 — 0.218Co2SiO4         → Propagation vector: 0, 0, 0
# 🔍  219/2167 — 0.219Co2SiO4         → Propagation vector: 0, 0, 0
# 🔍  220/2167 — 0.220Mn2SiO4         → Propagation vector: 0, 0, 0
# 🔍  221/2167 — 0.221Fe2SiO4         → Propagation vector: 0, 0, 0
# 🔍  222/2167 — 0.222CuMnAs          → Propagation vector: 0, 0, 0
# 🔍  223/2167 — 0.223Cu0.95MnAs      → Propagation vector: 0, 0, 0
# 🔍  224/2167 — 0.224Nd0.5Tb0.5Co2   → Propagation vector: 0, 0, 0
# 🔍  225/2167 — 0.225Nd0.5Tb0.5Co2   → Propagation vector: 0, 0, 0
# 🔍  226/2167 — 0.226NdCo2           → Propagation vector: 0, 0, 0
# 🔍  227/2167 — 0.227NdCo2           → Propagation vector: 0, 0, 0
# 🔍  228/2167 — 0.228TbCo2           → Propagation vector: 0, 0, 0
# 🔍  229/2167 — 0.229Ba2MnSi2O7      → Propagation vector: 0, 0, 0
# 🔍  230/2167 — 0.230K2CoP2O7        → Propagation vector: 0, 0, 0
# 🔍  231/2167 — 0.231TmMn3O6         → Propagation vector: 0, 0, 0
# 🔍  232/2167 — 0.232TmMn3O6         → Propagation vector: 0, 0, 0
# 🔍  233/2167 — 0.233Mn2FeSbO6       → Propagation vector: 0, 0, 0
# 🔍  234/2167 — 0.234MnLaMnSbO6      → Propagation vector: 0, 0, 0
# 🔍  235/2167 — 0.235MnPrMnSbO6      → Propagation vector: 0, 0, 0
# 🔍  236/2167 — 0.236CaFe4Al8        → Propagation vector: 0, 0, 0
# 🔍  237/2167 — 0.237Er2Sn2O7        → Propagation vector: 0, 0, 0
# 🔍  238/2167 — 0.238Er2Pt2O7        → Propagation vector: 0, 0, 0
# 🔍  239/2167 — 0.239Ca3LiRuO6       → Propagation vector: 0, 0, 0
# 🔍  240/2167 — 0.240Er2Cu2O5        → Propagation vector: 0, 0, 0
# 🔍  241/2167 — 0.241Y2Cu2O5         → Propagation vector: 0, 0, 0
# 🔍  242/2167 — 0.242Tm2Cu2O5        → Propagation vector: 0, 0, 0
# 🔍  243/2167 — 0.243Li2Fe(SO4)2     → Propagation vector: 0, 0, 0
# 🔍  244/2167 — 0.244Li2Co(SO4)2     → Propagation vector: 0, 0, 0
# 🔍  245/2167 — 0.245Li1.5Fe(SO4)2   → Propagation vector: 0, 0, 0
# 🔍  246/2167 — 0.246LiFe(SO4)2      → Propagation vector: 0, 0, 0
# 🔍  247/2167 — 0.247Nd2NiO4.11      → Propagation vector: 0, 0, 0
# 🔍  248/2167 — 0.248TbPt0.8Cu0.2    → Propagation vector: 0, 0, 0
# 🔍  249/2167 — 0.249NdNi0.6Cu0.4    → Propagation vector: 0, 0, 0
# 🔍  250/2167 — 0.250(NH2(CH3)2)(FeCo(HCOO)6) → Propagation vector: 0, 0, 0
# 🔍  251/2167 — 0.251(NH2(CH3)2)(FeMn(HCOO)6) → Propagation vector: 0, 0, 0
# 🔍  252/2167 — 0.252Cs2FeCl5.D2O    → Propagation vector: 0, 0, 0
# 🔍  253/2167 — 0.253Cs2FeCl5.D2O    → Propagation vector: 0, 0, 0
# 🔍  254/2167 — 0.254[C(ND2)3]Cu(DCOO)3 → Propagation vector: 0, 0, 0
# 🔍  255/2167 — 0.255[C(ND2)3]Cu(DCOO)3 → Propagation vector: 0, 0, 0
# 🔍  256/2167 — 0.256[C(ND2)3]Mn(DCOO)3 → Propagation vector: 0, 0, 0
# 🔍  257/2167 — 0.257[C(ND2)3]Co(DCOO)3 → Propagation vector: 0, 0, 0
# 🔍  258/2167 — 0.258Li3Fe2(PO4)3    → Propagation vector: 0, 0, 0
# 🔍  259/2167 — 0.259Li3Fe2(PO4)3    → Propagation vector: 0, 0, 0
# 🔍  260/2167 — 0.260CuFePO5         → Propagation vector: 0, 0, 0
# 🔍  261/2167 — 0.261NiFePO5         → Propagation vector: 0, 0, 0
# 🔍  262/2167 — 0.262CoFePO5         → Propagation vector: 0, 0, 0
# 🔍  263/2167 — 0.263Fe2PO5          → Propagation vector: 0, 0, 0
# 🔍  264/2167 — 0.264Fe3(PO4)2       → Propagation vector: 0, 0, 0
# 🔍  265/2167 — 0.265Mn3(Co0.61Mn0.39)N → Propagation vector: 0, 0, 0
# 🔍  266/2167 — 0.266Na2BaCo(VO4)2   → Propagation vector: 0, 0, 0
# 🔍  267/2167 — 0.267YbMnBi2         → Propagation vector: 0, 0, 0
# 🔍  268/2167 — 0.268Tb2MnNiO6       → Propagation vector: 0, 0, 0
# 🔍  269/2167 — 0.269Tb2MnNiO6       → Propagation vector: 0, 0, 0
# 🔍  270/2167 — 0.270Tb2MnNiO6       → Propagation vector: 0, 0, 0
# 🔍  271/2167 — 0.271Tb2MnNiO6       → Propagation vector: 0, 0, 0
# 🔍  272/2167 — 0.272Tb2MnNiO6       → Propagation vector: 0, 0, 0
# 🔍  273/2167 — 0.273Mn3ZnN          → Propagation vector: 0, 0, 0
# 🔍  274/2167 — 0.274Mn4N            → Propagation vector: 0, 0, 0
# 🔍  275/2167 — 0.275Mn3AlN          → Propagation vector: 0, 0, 0
# 🔍  276/2167 — 0.276Mn3AlN          → Propagation vector: 0, 0, 0
# 🔍  277/2167 — 0.277MgMnO3          → Propagation vector: 0, 0, 0
# 🔍  278/2167 — 0.278Cu0.82Mn1.18As  → Propagation vector: 0, 0, 0
# 🔍  279/2167 — 0.279Mn3As           → Propagation vector: 0, 0, 0
# 🔍  280/2167 — 0.280Mn3As           → Propagation vector: 0, 0, 0
# 🔍  281/2167 — 0.281Co2V2O7         → Propagation vector: 0, 0, 0
# 🔍  282/2167 — 0.282U14Au51         → Propagation vector: 0, 0, 0
# 🔍  283/2167 — 0.283U14Au51         → Propagation vector: 0, 0, 0
# 🔍  284/2167 — 0.284KOsO4           → Propagation vector: 0, 0, 0
# 🔍  285/2167 — 0.285KRuO4           → Propagation vector: 0, 0, 0
# 🔍  286/2167 — 0.286Mn5Ge3          → Propagation vector: 0, 0, 0
# 🔍  287/2167 — 0.287SrCo(VO4)(OH)   → Propagation vector: 0, 0, 0
# 🔍  288/2167 — 0.288NdMnO3          → Propagation vector: 0, 0, 0
# 🔍  289/2167 — 0.289NdMnO3          → Propagation vector: 0, 0, 0
# 🔍  290/2167 — 0.290CeCu2           → Propagation vector: 0, 0, 0
# 🔍  291/2167 — 0.291Tl2NiMnO6       → Propagation vector: 0, 0, 0
# 🔍  292/2167 — 0.292NiTe2O5         → Propagation vector: 0, 0, 0
# 🔍  293/2167 — 0.293(Tm0.7Mn0.3)MnO3 → Propagation vector: 0, 0, 0
# 🔍  294/2167 — 0.294Cu4(OD)6FBr     → Propagation vector: 0, 0, 0
# 🔍  295/2167 — 0.295Cu2(OD)3Cl      → Propagation vector: 0, 0, 0
# 🔍  296/2167 — 0.296Cu2(OD)3Cl      → Propagation vector: 0, 0, 0
# 🔍  297/2167 — 0.297NaCrGe2O6       → Propagation vector: 0, 0, 0
# 🔍  298/2167 — 0.298Na2BaFe(VO4)2   → Propagation vector: 0, 0, 0
# 🔍  299/2167 — 0.299Fe2O3           → Propagation vector: 0, 0, 0
# 🔍  300/2167 — 0.300Fe2O3           → Propagation vector: 0, 0, 0
# 🔍  301/2167 — 0.301Sr2CoTeO6       → Propagation vector: 0, 0, 0
# 🔍  302/2167 — 0.302Sr2Co0.9Mg0.1TeO6 → Propagation vector: 0, 0, 0
# 🔍  303/2167 — 0.303BaCrF5          → Propagation vector: 0, 0, 0
# 🔍  304/2167 — 0.304Pr0.5Sr0.5CoO3  → Propagation vector: 0, 0, 0
# 🔍  305/2167 — 0.305Pr0.5Sr0.5CoO3  → Propagation vector: 0, 0, 0
# 🔍  306/2167 — 0.306GaFeO3          → Propagation vector: 0, 0, 0
# 🔍  307/2167 — 0.307ScCrO3          → Propagation vector: 0, 0, 0
# 🔍  308/2167 — 0.308InCrO3          → Propagation vector: 0, 0, 0
# 🔍  309/2167 — 0.309TlCrO3          → Propagation vector: 0, 0, 0
# 🔍  310/2167 — 0.310NaMnFeF6        → Propagation vector: 0, 0, 0
# 🔍  311/2167 — 0.311CoGeO3          → Propagation vector: 0, 0, 0
# 🔍  312/2167 — 0.312MnGeO3          → Propagation vector: 0, 0, 0
# 🔍  313/2167 — 0.313MnGeO3          → Propagation vector: 0, 0, 0
# 🔍  314/2167 — 0.314ZrCo2Ge4O12     → Propagation vector: 0, 0, 0
# 🔍  315/2167 — 0.315ZrMn2Ge4O12     → Propagation vector: 0, 0, 0
# 🔍  316/2167 — 0.316DyCrWO6         → Propagation vector: 0, 0, 0
# 🔍  317/2167 — 0.317Ho2CoMnO6       → Propagation vector: 0, 0, 0
# 🔍  318/2167 — 0.318Tm2CoMnO6       → Propagation vector: 0, 0, 0
# 🔍  319/2167 — 0.319Tm2CoMnO6       → Propagation vector: 0, 0, 0
# 🔍  320/2167 — 0.320U2Pd2In         → Propagation vector: 0, 0, 0
# 🔍  321/2167 — 0.321U2Pd2Sn         → Propagation vector: 0, 0, 0
# 🔍  322/2167 — 0.322Cu1.94Mn1.06BO5 → Propagation vector: 0, 0, 0
# 🔍  323/2167 — 0.323LaCrO3          → Propagation vector: 0, 0, 0
# 🔍  324/2167 — 0.324CdYb2S4         → Propagation vector: 0, 0, 0
# 🔍  325/2167 — 0.325CdYb2Se4        → Propagation vector: 0, 0, 0
# 🔍  326/2167 — 0.326Nd2Sn2O7        → Propagation vector: 0, 0, 0
# 🔍  327/2167 — 0.327CsMnF4          → Propagation vector: 0, 0, 0
# 🔍  328/2167 — 0.328KMnF4           → Propagation vector: 0, 0, 0
# 🔍  329/2167 — 0.329RbMnF4          → Propagation vector: 0, 0, 0
# 🔍  330/2167 — 0.330ErGe3           → Propagation vector: 0, 0, 0
# 🔍  331/2167 — 0.331Fe2Mo3O8        → Propagation vector: 0, 0, 0
# 🔍  332/2167 — 0.332Co2Mo3O8        → Propagation vector: 0, 0, 0
# 🔍  333/2167 — 0.333Mn2Mo3O8        → Propagation vector: 0, 0, 0
# 🔍  334/2167 — 0.334CoF3            → Propagation vector: 0, 0, 0
# 🔍  335/2167 — 0.335FeF3            → Propagation vector: 0, 0, 0
# 🔍  336/2167 — 0.336NdFeO3          → Propagation vector: 0, 0, 0
# 🔍  337/2167 — 0.337NdFeO3          → Propagation vector: 0, 0, 0
# 🔍  338/2167 — 0.338Co2Mo3O8        → Propagation vector: 0, 0, 0
# 🔍  339/2167 — 0.339Nd2Hf2O7        → Propagation vector: 0, 0, 0
# 🔍  340/2167 — 0.340Nd2Zr2O7        → Propagation vector: 0, 0, 0
# 🔍  341/2167 — 0.341DyGe1.75        → Propagation vector: 0, 0, 0
# 🔍  342/2167 — 0.342Tb3Ge5          → Propagation vector: 0, 0, 0
# 🔍  343/2167 — 0.343TbGe2           → Propagation vector: 0, 0, 0
# 🔍  344/2167 — 0.344ErGe1.83        → Propagation vector: 0, 0, 0
# 🔍  345/2167 — 0.345Tb2C3           → Propagation vector: 0, 0, 0
# 🔍  346/2167 — 0.346Tb2ReC2         → Propagation vector: 0, 0, 0
# 🔍  347/2167 — 0.347Er2ReC2         → Propagation vector: 0, 0, 0
# 🔍  348/2167 — 0.348Bi2CuO4         → Propagation vector: 0, 0, 0
# 🔍  349/2167 — 0.349Nd2NiO4         → Propagation vector: 0, 0, 0
# 🔍  350/2167 — 0.350TbAlO3          → Propagation vector: 0, 0, 0
# 🔍  351/2167 — 0.351TbFeO3          → Propagation vector: 0, 0, 0
# 🔍  352/2167 — 0.352TbFeO3          → Propagation vector: 0, 0, 0
# 🔍  353/2167 — 0.353TbFeO3          → Propagation vector: 0, 0, 0
# 🔍  354/2167 — 0.354TbCrO3          → Propagation vector: 0, 0, 0
# 🔍  355/2167 — 0.355Mn2.85Ga1.15    → Propagation vector: 0, 0, 0
# 🔍  356/2167 — 0.356Mn2.85Ga1.15    → Propagation vector: 0, 0, 0
# 🔍  357/2167 — 0.357CaFe5O7         → Propagation vector: 0, 0, 0
# 🔍  358/2167 — 0.358CaFe5O7         → Propagation vector: 0, 0, 0
# 🔍  359/2167 — 0.359Mn2ScSbO6       → Propagation vector: 0, 0, 0
# 🔍  360/2167 — 0.360Mn2ScSbO6       → Propagation vector: 0, 0, 0
# 🔍  361/2167 — 0.361Sr3LiRuO6       → Propagation vector: 0, 0, 0
# 🔍  362/2167 — 0.362RbFeCl5(D2O)    → Propagation vector: 0, 0, 0
# 🔍  363/2167 — 0.363KFeCl5(D2O)     → Propagation vector: 0, 0, 0
# 🔍  364/2167 — 0.364SrCr2As2        → Propagation vector: 0, 0, 0
# 🔍  365/2167 — 0.365BaCr2As2        → Propagation vector: 0, 0, 0
# 🔍  366/2167 — 0.366BaCrFeAs2       → Propagation vector: 0, 0, 0
# 🔍  367/2167 — 0.367EuCr2As2        → Propagation vector: 0, 0, 0
# 🔍  368/2167 — 0.368(CH3NH3)(Co(COOH)3 → Propagation vector: 0, 0, 0
# 🔍  369/2167 — 0.369(CH3NH3)(Co(COOH)3 → Propagation vector: 0, 0, 0
# 🔍  370/2167 — 0.370NdMnO3          → Propagation vector: 0, 0, 0
# 🔍  371/2167 — 0.371NdMnO3          → Propagation vector: 0, 0, 0
# 🔍  372/2167 — 0.372DyCrO4          → Propagation vector: 0, 0, 0
# 🔍  373/2167 — 0.373La0.75Bi0.25Fe0.5Cr0.5O3 → Propagation vector: 0, 0, 0
# 🔍  374/2167 — 0.374YNi4Si          → Propagation vector: 0, 0, 0
# 🔍  375/2167 — 0.375La2CoIrO6       → Propagation vector: 0, 0, 0
# 🔍  376/2167 — 0.376LaCaFeO4        → Propagation vector: 0, 0, 0
# 🔍  377/2167 — 0.377Mn3Ge           → Propagation vector: 0, 0, 0
# 🔍  378/2167 — 0.378UBi2            → Propagation vector: 0, 0, 0
# 🔍  379/2167 — 0.379SmFeO3          → Propagation vector: 0, 0, 0
# 🔍  380/2167 — 0.380SmFeO3          → Propagation vector: 0, 0, 0
# 🔍  381/2167 — 0.381Co6(OH)3(TeO3)4(OH)0.9(H20) → Propagation vector: 0, 0, 0
# 🔍  382/2167 — 0.382LiMnPO4         → Propagation vector: 0, 0, 0
# 🔍  383/2167 — 0.383LiCoPO4         → Propagation vector: 0, 0, 0
# 🔍  384/2167 — 0.384LiCoPO4         → Propagation vector: 0, 0, 0
# 🔍  385/2167 — 0.385LiCoPO4         → Propagation vector: 0, 0, 0
# 🔍  386/2167 — 0.386Fe3BO5          → Propagation vector: 0, 0, 0
# 🔍  387/2167 — 0.387Fe3BO5          → Propagation vector: 0, 0, 0
# 🔍  388/2167 — 0.388Co3Al2Si3O12    → Propagation vector: 0, 0, 0
# 🔍  389/2167 — 0.389Fe1.5Mn1.5BO5   → Propagation vector: 0, 0, 0
# 🔍  390/2167 — 0.390Y2SrCu0.6Co1.4O6.5 → Propagation vector: 0, 0, 0
# 🔍  391/2167 — 0.391Y2SrCu0.6Co1.4O6.5 → Propagation vector: 0, 0, 0
# 🔍  392/2167 — 0.392Fe3(PO4)2(OH)2  → Propagation vector: 0, 0, 0
# 🔍  393/2167 — 0.393Cu4(OH)6FBr     → Propagation vector: 0, 0, 0
# 🔍  394/2167 — 0.394Cu2CdB2O6       → Propagation vector: 0, 0, 0
# 🔍  395/2167 — 0.395MnPtGa          → Propagation vector: 0, 0, 0
# 🔍  396/2167 — 0.396MnPtGa          → Propagation vector: 0, 0, 0
# 🔍  397/2167 — 0.397Mn3Si2Te6       → Propagation vector: 0, 0, 0
# 🔍  398/2167 — 0.398Ca2RuO4         → Propagation vector: 0, 0, 0
# 🔍  399/2167 — 0.399FeOOH           → Propagation vector: 0, 0, 0
# 🔍  400/2167 — 0.400Sr2Fe1.9Co0.1O5.5 → Propagation vector: 0, 0, 0
# 🔍  401/2167 — 0.401Sr4Fe4O11       → Propagation vector: 0, 0, 0
# 🔍  402/2167 — 0.402Sr4Fe4O11       → Propagation vector: 0, 0, 0
# 🔍  403/2167 — 0.403NdCo2           → Propagation vector: 0, 0, 0
# 🔍  404/2167 — 0.404Sr3NaRuO6       → Propagation vector: 0, 0, 0
# 🔍  405/2167 — 0.405CsCoF4          → Propagation vector: 0, 0, 0
# 🔍  406/2167 — 0.406GdNiSi3         → Propagation vector: 0, 0, 0
# 🔍  407/2167 — 0.407NdSi            → Propagation vector: 0, 0, 0
# 🔍  408/2167 — 0.408PrSi            → Propagation vector: 0, 0, 0
# 🔍  409/2167 — 0.409TmNi            → Propagation vector: 0, 0, 0
# 🔍  410/2167 — 0.410GdAlO3          → Propagation vector: 0, 0, 0
# 🔍  411/2167 — 0.411Tb5Ge4          → Propagation vector: 0, 0, 0
# 🔍  412/2167 — 0.412Tb5Ge4          → Propagation vector: 0, 0, 0
# 🔍  413/2167 — 0.413UGeSe           → Propagation vector: 0, 0, 0
# 🔍  414/2167 — 0.414AlFe2B2         → Propagation vector: 0, 0, 0
# 🔍  415/2167 — 0.415EuFe2P2         → Propagation vector: 0, 0, 0
# 🔍  416/2167 — 0.416LaCrO3          → Propagation vector: 0, 0, 0
# 🔍  417/2167 — 0.417LaCrO3          → Propagation vector: 0, 0, 0
# 🔍  418/2167 — 0.418K0.8Fe1.8Se2    → Propagation vector: 0, 0, 0
# 🔍  419/2167 — 0.419Er2Ge2O7        → Propagation vector: 0, 0, 0
# 🔍  420/2167 — 0.420Sr2LuRuO6       → Propagation vector: 0, 0, 0
# 🔍  421/2167 — 0.421EuMnSb2         → Propagation vector: 0, 0, 0
# 🔍  422/2167 — 0.422EuMnSb2         → Propagation vector: 0, 0, 0
# 🔍  423/2167 — 0.423EuMnSb2         → Propagation vector: 0, 0, 0
# 🔍  424/2167 — 0.424EuMnSb2         → Propagation vector: 0, 0, 0
# 🔍  425/2167 — 0.425Na2CoP2O7       → Propagation vector: 0, 0, 0
# 🔍  426/2167 — 0.426EuMnBi2         → Propagation vector: 0, 0, 0
# 🔍  427/2167 — 0.427Sm2Ti2O7        → Propagation vector: 0, 0, 0
# 🔍  428/2167 — 0.428BaMn2Si2O7      → Propagation vector: 0, 0, 0
# 🔍  429/2167 — 0.429CaCr0.86Fe3.14As3 → Propagation vector: 0, 0, 0
# 🔍  430/2167 — 0.430Yb3Pt4          → Propagation vector: 0, 0, 0
# 🔍  431/2167 — 0.431CuB2O4          → Propagation vector: 0, 0, 0
# 🔍  432/2167 — 0.432KMnF3           → Propagation vector: 0, 0, 0
# 🔍  433/2167 — 0.433KMnF3           → Propagation vector: 0, 0, 0
# 🔍  434/2167 — 0.434K2ReI6          → Propagation vector: 0, 0, 0
# 🔍  435/2167 — 0.435Pb5Fe3TiO11Cl   → Propagation vector: 1/2, 1/2, 0
# 🔍  436/2167 — 0.436TbNi4Si         → Propagation vector: 0, 0, 0
# 🔍  437/2167 — 0.437Ho3NiGe2        → Propagation vector: 0, 0, 0
# 🔍  438/2167 — 0.438Pr3CoGe2        → Propagation vector: 0, 0, 0
# 🔍  439/2167 — 0.439Tb3NiGe2        → Propagation vector: 0, 0, 0
# 🔍  440/2167 — 0.440SrCuTe2O6       → Propagation vector: 0, 0, 0
# 🔍  441/2167 — 0.441Fe4Nb2O9        → Propagation vector: 0, 0, 0
# 🔍  442/2167 — 0.442Fe4Nb2O9        → Propagation vector: 0, 0, 0
# 🔍  443/2167 — 0.443Fe4Nb2O9        → Propagation vector: 0, 0, 0
# 🔍  444/2167 — 0.444YbCl3           → Propagation vector: 0, 0, 0
# 🔍  445/2167 — 0.445MnCoGe          → Propagation vector: 0, 0, 0
# 🔍  446/2167 — 0.446MnCoGeB0.05     → Propagation vector: 0, 0, 0
# 🔍  447/2167 — 0.447MnCoGeB0.05     → Propagation vector: 0, 0, 0
# 🔍  448/2167 — 0.448Ce4Ge3          → Propagation vector: 0, 0, 0
# 🔍  449/2167 — 0.449Tb2Pt           → Propagation vector: 0, 0, 0
# 🔍  450/2167 — 0.450Nd5Ge4          → Propagation vector: 0, 0, 0
# 🔍  451/2167 — 0.451DyRuAsO         → Propagation vector: 0, 0, 0
# 🔍  452/2167 — 0.452TbRuAsO         → Propagation vector: 0, 0, 0
# 🔍  453/2167 — 0.453DyCoSi2         → Propagation vector: 0, 0, 0
# 🔍  454/2167 — 0.454PrScSb          → Propagation vector: 1, 1, 1
# 🔍  455/2167 — 0.455RbFeO2          → Propagation vector: 0, 0, 0
# 🔍  456/2167 — 0.456RbFeO2          → Propagation vector: 0, 0, 0
# 🔍  457/2167 — 0.457CsFeO2          → Propagation vector: 0, 0, 0
# 🔍  458/2167 — 0.458CsFeO2          → Propagation vector: 0, 0, 0
# 🔍  459/2167 — 0.459KFeO2           → Propagation vector: 0, 0, 0
# 🔍  460/2167 — 0.460KFeO2           → Propagation vector: 0, 0, 0
# 🔍  461/2167 — 0.461CoRh2O4         → Propagation vector: 0, 0, 0
# 🔍  462/2167 — 0.462MnAl2O4         → Propagation vector: 0, 0, 0
# 🔍  463/2167 — 0.463Co3O4           → Propagation vector: 0, 0, 0
# 🔍  464/2167 — 0.464BaMn2P2         → Propagation vector: 0, 0, 0
# 🔍  465/2167 — 0.465HoCr2Si2        → Propagation vector: 0, 0, 0
# 🔍  466/2167 — 0.466ThCr2Si2        → Propagation vector: 0, 0, 0
# 🔍  467/2167 — 0.467TbPO4           → Propagation vector: 0, 0, 0
# 🔍  468/2167 — 0.468ErB4            → Propagation vector: 0, 0, 0
# 🔍  469/2167 — 0.469TbB4            → Propagation vector: 0, 0, 0
# 🔍  470/2167 — 0.470BaMn2Sb2        → Propagation vector: 0, 0, 0
# 🔍  471/2167 — 0.471Ba2Mn3Sb2O2     → Propagation vector: 0, 0, 0
# 🔍  472/2167 — 0.472LaMn2Si2        → Propagation vector: 0, 0, 0
# 🔍  473/2167 — 0.473LaMn2Si2        → Propagation vector: 0, 0, 0
# 🔍  474/2167 — 0.474EuMn2Ge2        → Propagation vector: 0, 0, 0
# 🔍  475/2167 — 0.475Sr2TbIrO6       → Propagation vector: 0, 0, 0
# 🔍  476/2167 — 0.476Cs2[FeCl5(H2O)] → Propagation vector: 0, 0, 0
# 🔍  477/2167 — 0.477Mn4Ta2O9        → Propagation vector: 0, 0, 0
# 🔍  478/2167 — 0.478SmCrO3          → Propagation vector: 0, 0, 0
# 🔍  479/2167 — 0.479SmCrO3          → Propagation vector: 0, 0, 0
# 🔍  480/2167 — 0.480HoNi            → Propagation vector: 0, 0, 0
# 🔍  481/2167 — 0.481HoNi            → Propagation vector: 0, 0, 0
# 🔍  482/2167 — 0.482SrMn2As2        → Propagation vector: 0, 0, 0
# 🔍  483/2167 — 0.483YbMn2Sb2        → Propagation vector: 0, 0, 0
# 🔍  484/2167 — 0.484U2N2S           → Propagation vector: 0, 0, 0
# 🔍  485/2167 — 0.485U2N2Se          → Propagation vector: 0, 0, 0
# 🔍  486/2167 — 0.486ErCr2Si2        → Propagation vector: 0, 0, 0
# 🔍  487/2167 — 0.487ErCr2Si2        → Propagation vector: 0, 0, 0
# 🔍  488/2167 — 0.488YbMnO3          → Propagation vector: 0, 0, 0
# 🔍  489/2167 — 0.489YbMnO3          → Propagation vector: 0, 0, 0
# 🔍  490/2167 — 0.490YbMnO3          → Propagation vector: 0, 0, 0
# 🔍  491/2167 — 0.491NdB4            → Propagation vector: 0, 0, 0
# 🔍  492/2167 — 0.492NdB4            → Propagation vector: 0, 0, 0
# 🔍  493/2167 — 0.493Ho(Co0.667Ga0.333)2 → Propagation vector: 0, 0, 0
# 🔍  494/2167 — 0.494Er(Co0.667Ga0.333)2 → Propagation vector: 0, 0, 0
# 🔍  495/2167 — 0.495LaMn2Si2        → Propagation vector: 0, 0, 0
# 🔍  496/2167 — 0.496LaMn2Si2        → Propagation vector: 0, 0, 0
# 🔍  497/2167 — 0.497LaMn2Si2        → Propagation vector: 0, 0, 0
# 🔍  498/2167 — 0.498LaMn2Si2        → Propagation vector: 0, 0, 0
# 🔍  499/2167 — 0.499UCr2Si2C        → Propagation vector: 0, 0, 0
# 🔍  500/2167 — 0.500Ca2FeMn0.5W0.5O6 → Propagation vector: 0, 0, 0
# 🔍  501/2167 — 0.501LiFe2F6         → Propagation vector: 0, 0, 0
# 🔍  502/2167 — 0.502La2Ni1.19Os0.81O6 → Propagation vector: 0, 0, 0
# 🔍  503/2167 — 0.503K1.62Fe4O6.62(OH)0.38 → Propagation vector: 0, 0, 0
# 🔍  504/2167 — 0.504NaCrSi2O6       → Propagation vector: 0, 0, 0
# 🔍  505/2167 — 0.505Pb2VO(PO4)2     → Propagation vector: 0, 0, 0
# 🔍  506/2167 — 0.506Cs2Cu3SnF12     → Propagation vector: 0, 0, 0
# 🔍  507/2167 — 0.507Mn4Nb2O9        → Propagation vector: 0, 0, 0
# 🔍  508/2167 — 0.508FeMnO3          → Propagation vector: 0, 0, 0
# 🔍  509/2167 — 0.509BaFe12O19       → Propagation vector: 0, 0, 0
# 🔍  510/2167 — 0.510Mn2NiReO6       → Propagation vector: 0, 0, 0
# 🔍  511/2167 — 0.511Co4Ta2O9        → Propagation vector: 0, 0, 0
# 🔍  512/2167 — 0.512Mn3As2          → Propagation vector: 0, 0, 0
# 🔍  513/2167 — 0.513YRuO3           → Propagation vector: 0, 0, 0
# 🔍  514/2167 — 0.514CoFe3O5         → Propagation vector: 0, 0, 0
# 🔍  515/2167 — 0.515CoFe3O5         → Propagation vector: 0, 0, 0
# 🔍  516/2167 — 0.516BaMg2Fe16O27    → Propagation vector: 0, 0, 0
# 🔍  517/2167 — 0.517BaCo2Fe16O27    → Propagation vector: 0, 0, 0
# 🔍  518/2167 — 0.518TbCr2Si2        → Propagation vector: 0, 0, 0
# 🔍  519/2167 — 0.519HoCr2Si2        → Propagation vector: 0, 0, 0
# 🔍  520/2167 — 0.520TbCoO3          → Propagation vector: 0, 0, 0
# 🔍  521/2167 — 0.521DyCoO3          → Propagation vector: 0, 0, 0
# 🔍  522/2167 — 0.522La2O3FeMnSe2    → Propagation vector: 0, 0, 0
# 🔍  523/2167 — 0.523CaMn2Sb2        → Propagation vector: 0, 0, 0
# 🔍  524/2167 — 0.524MnPSe3          → Propagation vector: 0, 0, 0
# 🔍  525/2167 — 0.525NaCeO2          → Propagation vector: 0, 0, 0
# 🔍  526/2167 — 0.526Mn4Ta2O9        → Propagation vector: 0, 0, 0
# 🔍  527/2167 — 0.527Er2Si2O7        → Propagation vector: 0, 0, 0
# 🔍  528/2167 — 0.528CrSb            → Propagation vector: 0, 0, 0
# 🔍  529/2167 — 0.529Co4Nb2O9        → Propagation vector: 0, 0, 0
# 🔍  530/2167 — 0.530SrCuTe2O6       → Propagation vector: 0, 0, 0
# 🔍  531/2167 — 0.531Sr0.7Tb0.3CoO2.9 → Propagation vector: 0, 0, 0
# 🔍  532/2167 — 0.532Sr0.7Ho0.3CoO2.7 → Propagation vector: 0, 0, 0
# 🔍  533/2167 — 0.533Sr0.7Er0.3CoO2.8 → Propagation vector: 0, 0, 0
# 🔍  534/2167 — 0.534Tb0.55Sr0.45MnO3 → Propagation vector: 0, 0, 0
# 🔍  535/2167 — 0.535Tb0.55Sr0.45MnO3 → Propagation vector: 0, 0, 0
# 🔍  536/2167 — 0.536Tb0.55Sr0.45MnO3 → Propagation vector: 0, 0, 0
# 🔍  537/2167 — 0.537CaMn0.7Co1.3ReO6 → Propagation vector: 0, 0, 0
# 🔍  538/2167 — 0.538CaMn1.2Ni0.8ReO6 → Propagation vector: 0, 0, 0
# 🔍  539/2167 — 0.539Mn2Fe0.8Mo1.2O6 → Propagation vector: 0, 0, 0
# 🔍  540/2167 — 0.540Mn2Fe0.8Mo1.2O6 → Propagation vector: 0, 0, 0
# 🔍  541/2167 — 0.541Mn2FeReO6       → Propagation vector: 0, 0, 0
# 🔍  542/2167 — 0.542Mn2FeReO6       → Propagation vector: 0, 0, 0
# 🔍  543/2167 — 0.543Mn2FeReO6       → Propagation vector: 0, 0, 0
# 🔍  544/2167 — 0.544Mn2FeReO6       → Propagation vector: 0, 0, 0
# 🔍  545/2167 — 0.545Mn2FeReO6       → Propagation vector: 0, 0, 0
# 🔍  546/2167 — 0.546Mn2FeReO6       → Propagation vector: 0, 0, 0
# 🔍  547/2167 — 0.547Mn2FeReO6       → Propagation vector: 0, 0, 0
# 🔍  548/2167 — 0.548Mn2FeReO6       → Propagation vector: 0, 0, 0
# 🔍  549/2167 — 0.549Mn2FeReO6       → Propagation vector: 0, 0, 0
# 🔍  550/2167 — 0.550Mn3ReO6         → Propagation vector: 1/2, 1/2, 0
# 🔍  551/2167 — 0.551Mn3ReO6         → Propagation vector: 1/2, 1/2, 0
# 🔍  552/2167 — 0.552Pb2MnO4         → Propagation vector: 0, 0, 0
# 🔍  553/2167 — 0.553K2ReI6          → Propagation vector: 0, 0, 0
# 🔍  554/2167 — 0.554Co2MnSi         → Propagation vector: 0, 0, 0
# 🔍  555/2167 — 0.555Ho0.05Bi0.95FeO3 → Propagation vector: 0, 0, 0
# 🔍  556/2167 — 0.556Ho0.1Bi0.9FeO3  → Propagation vector: 0, 0, 0
# 🔍  557/2167 — 0.557Ho0.15Bi0.85FeO3 → Propagation vector: 0, 0, 0
# 🔍  558/2167 — 0.558Ho0.2Bi0.8FeO3  → Propagation vector: 0, 0, 0
# 🔍  559/2167 — 0.559Ho0.15Bi0.85FeO3 → Propagation vector: 0, 0, 0
# 🔍  560/2167 — 0.560Ho0.2Bi0.8FeO3  → Propagation vector: 0, 0, 0
# 🔍  561/2167 — 0.561NdNiGe2         → Propagation vector: 0, 0, 0
# 🔍  562/2167 — 0.562Ce2Ni3Ge5       → Propagation vector: 1, 1, 1
# 🔍  563/2167 — 0.563Ce2Ni3Ge5       → Propagation vector: 1, 1, 1
# 🔍  564/2167 — 0.564U2Rh3Si5        → Propagation vector: 0, 1, 0
# 🔍  565/2167 — 0.565Ce2Ni3Ge5       → Propagation vector: 1, 1, 1
# 🔍  566/2167 — 0.566TbNiGe2         → Propagation vector: 0, 0, 0
# 🔍  567/2167 — 0.567HoNi0.64Ge2     → Propagation vector: 0, 0, 0
# 🔍  568/2167 — 0.568TbNi0.4Ge2      → Propagation vector: 0, 0, 0
# 🔍  569/2167 — 0.569TbCu0.4Ge2      → Propagation vector: 0, 0, 0
# 🔍  570/2167 — 0.570Li0.5FeCr1.5O4  → Propagation vector: 0, 0, 0
# 🔍  571/2167 — 0.571CoSO4           → Propagation vector: 0, 0, 0
# 🔍  572/2167 — 0.572Na2NiCrF7       → Propagation vector: 0, 0, 0
# 🔍  573/2167 — 0.573Na2NiCrF7       → Propagation vector: 0, 0, 0
# 🔍  574/2167 — 0.574MnFeF5(H2O)2    → Propagation vector: 0, 0, 0
# 🔍  575/2167 — 0.575ZnFeF5(H2O)2    → Propagation vector: 0, 0, 0
# 🔍  576/2167 — 0.576Cr2F5           → Propagation vector: 0, 0, 0
# 🔍  577/2167 — 0.577BaMnFeF7        → Propagation vector: 0, 0, 0
# 🔍  578/2167 — 0.578NaBaFe2F9       → Propagation vector: 0, 0, 0
# 🔍  579/2167 — 0.579Na2NiFeF7       → Propagation vector: 0, 0, 0
# 🔍  580/2167 — 0.580Na2NiFeF7       → Propagation vector: 0, 0, 0
# 🔍  581/2167 — 0.581FeF3            → Propagation vector: 0, 0, 0
# 🔍  582/2167 — 0.582Fe3F8(H2O)2     → Propagation vector: 0, 0, 0
# 🔍  583/2167 — 0.583Fe2F5(H2O)2     → Propagation vector: 0, 0, 0
# 🔍  584/2167 — 0.584Fe2F5(H2O)2     → Propagation vector: 0, 0, 0
# 🔍  585/2167 — 0.585YbCl3           → Propagation vector: 0, 0, 0
# 🔍  586/2167 — 0.586YCrO3           → Propagation vector: 0, 0, 0
# 🔍  587/2167 — 0.587TmCrO3          → Propagation vector: 0, 0, 0
# 🔍  588/2167 — 0.588PrCrO3          → Propagation vector: 0, 0, 0
# 🔍  589/2167 — 0.589NdCrO3          → Propagation vector: 0, 0, 0
# 🔍  590/2167 — 0.590ErCrO3          → Propagation vector: 0, 0, 0
# 🔍  591/2167 — 0.591ErCrO3          → Propagation vector: 0, 0, 0
# 🔍  592/2167 — 0.592DyCrO3          → Propagation vector: 0, 0, 0
# 🔍  593/2167 — 0.593UPSe            → Propagation vector: 0, 0, 0
# 🔍  594/2167 — 0.594UAsS            → Propagation vector: 0, 0, 0
# 🔍  595/2167 — 0.595UPTe            → Propagation vector: 0, 0, 0
# 🔍  596/2167 — 0.596UAsTe           → Propagation vector: 0, 0, 0
# 🔍  597/2167 — 0.597MnBi8Te13       → Propagation vector: 0, 0, 0
# 🔍  598/2167 — 0.598AlCr2           → Propagation vector: 0, 0, 1
# 🔍  599/2167 — 0.599CaMnSi          → Propagation vector: 0, 0, 0
# 🔍  600/2167 — 0.600CaMnSi          → Propagation vector: 0, 0, 0
# 🔍  601/2167 — 0.601CaMnGe          → Propagation vector: 0, 0, 0
# 🔍  602/2167 — 0.602CaMnGe          → Propagation vector: 0, 0, 0
# 🔍  603/2167 — 0.603CaMn2Ge2        → Propagation vector: 0, 0, 0
# 🔍  604/2167 — 0.604CaMn2Ge2        → Propagation vector: 0, 0, 0
# 🔍  605/2167 — 0.605BaMn2Ge2        → Propagation vector: 0, 0, 0
# 🔍  606/2167 — 0.606BaMn2Ge2        → Propagation vector: 0, 0, 0
# 🔍  607/2167 — 0.607RuO2            → Propagation vector: 0, 0, 0
# 🔍  608/2167 — 0.608PrMnO3          → Propagation vector: 0, 0, 0
# 🔍  609/2167 — 0.609NdMnO3          → Propagation vector: 0, 0, 0
# 🔍  610/2167 — 0.610Pr0.95K0.05MnO3 → Propagation vector: 0, 0, 0
# 🔍  611/2167 — 0.611BaMnSb2         → Propagation vector: 0, 0, 0
# 🔍  612/2167 — 0.612Cu2OSO4         → Propagation vector: 0, 0, 0
# 🔍  613/2167 — 0.613FeCr2S4         → Propagation vector: 0, 0, 0
# 🔍  614/2167 — 0.614FeCr2S4         → Propagation vector: 0, 0, 0
# 🔍  615/2167 — 0.615FeCr2S4         → Propagation vector: 0, 0, 0
# 🔍  616/2167 — 0.616HoB2            → Propagation vector: 0, 0, 0
# 🔍  617/2167 — 0.617KMnSb           → Propagation vector: 0, 0, 0
# 🔍  618/2167 — 0.618KMnBi           → Propagation vector: 0, 0, 0
# 🔍  619/2167 — 0.619LaMnAsO         → Propagation vector: 0, 0, 0
# 🔍  620/2167 — 0.620NdMnAsO         → Propagation vector: 0, 0, 0
# 🔍  621/2167 — 0.621NdMnAsO         → Propagation vector: 0, 0, 0
# 🔍  622/2167 — 0.622NdMnAsO         → Propagation vector: 0, 0, 0
# 🔍  623/2167 — 0.623NdMnAsO         → Propagation vector: 0, 0, 0
# 🔍  624/2167 — 0.624LaMnAsO         → Propagation vector: 0, 0, 0
# 🔍  625/2167 — 0.625U2Pd2In         → Propagation vector: 0, 0, 0
# 🔍  626/2167 — 0.626NaMnP           → Propagation vector: 0, 0, 0
# 🔍  627/2167 — 0.627NaMnP           → Propagation vector: 0, 0, 0
# 🔍  628/2167 — 0.628NaMnP           → Propagation vector: 0, 0, 0
# 🔍  629/2167 — 0.629NaMnAs          → Propagation vector: 0, 0, 0
# 🔍  630/2167 — 0.630NaMnAs          → Propagation vector: 0, 0, 0
# 🔍  631/2167 — 0.631NaMnSb          → Propagation vector: 0, 0, 0
# 🔍  632/2167 — 0.632NaMnSb          → Propagation vector: 0, 0, 0
# 🔍  633/2167 — 0.633KFeS2           → Propagation vector: 0, 0, 0
# 🔍  634/2167 — 0.634NaMnBi          → Propagation vector: 0, 0, 0
# 🔍  635/2167 — 0.635NaMnBi          → Propagation vector: 0, 0, 0
# 🔍  636/2167 — 0.636RbFeS2          → Propagation vector: 0, 0, 0
# 🔍  637/2167 — 0.637KFeSe2          → Propagation vector: 0, 0, 0
# 🔍  638/2167 — 0.638RbFeSe2         → Propagation vector: 0, 0, 0
# 🔍  639/2167 — 0.639Mn2Au           → Propagation vector: 0, 0, 0
# 🔍  640/2167 — 0.640Mn2Au           → Propagation vector: 0, 0, 0
# 🔍  641/2167 — 0.641Mn3Ga           → Propagation vector: 0, 0, 0
# 🔍  642/2167 — 0.642LaMnO3          → Propagation vector: 0, 0, 0
# 🔍  643/2167 — 0.643La0.95Ca0.05MnO3 → Propagation vector: 0, 0, 0
# 🔍  644/2167 — 0.644La0.95Ba0.05MnO3 → Propagation vector: 0, 0, 0
# 🔍  645/2167 — 0.645La0.95Ba0.05Mn0.95Ti0.05O3 → Propagation vector: 0, 0, 0
# 🔍  646/2167 — 0.646La0.90Ba0.10Mn0.90Ti0.10O3 → Propagation vector: 0, 0, 0
# 🔍  647/2167 — 0.647La0.875Ba0.125Mn0.875Ti0.125O3 → Propagation vector: 0, 0, 0
# 🔍  648/2167 — 0.648(Ho0.8Mn0.2)MnO3 → Propagation vector: 0, 0, 0
# 🔍  649/2167 — 0.649(Ho0.8Mn0.2)MnO3 → Propagation vector: 0, 0, 0
# 🔍  650/2167 — 0.650Er2Si2O7        → Propagation vector: 0, 0, 0
# 🔍  651/2167 — 0.651Er3Cu4Sn4       → Propagation vector: 0, 0, 1/2
# 🔍  652/2167 — 0.652HoMnO3          → Propagation vector: 0, 0, 0
# 🔍  653/2167 — 0.653HoMn0.99Fe0.01O3 → Propagation vector: 0, 0, 0
# 🔍  654/2167 — 0.654HoMn0.95Fe0.05O3 → Propagation vector: 0, 0, 0
# 🔍  655/2167 — 0.655HoMn0.9Fe0.1O3  → Propagation vector: 0, 0, 0
# 🔍  656/2167 — 0.656NdMn2Ge2        → Propagation vector: 0, 0, 0
# 🔍  657/2167 — 0.657PrMn2Ge2        → Propagation vector: 0, 0, 0
# 🔍  658/2167 — 0.658BaCuTe2O6       → Propagation vector: 0, 0, 0
# 🔍  659/2167 — 0.659NdMn0.8Fe0.2O3  → Propagation vector: 0, 0, 0
# 🔍  660/2167 — 0.660NdMn0.8Fe0.2O3  → Propagation vector: 0, 0, 0
# 🔍  661/2167 — 0.661(Lu0.6Mn0.4)MnO3 → Propagation vector: 0, 0, 0
# 🔍  662/2167 — 0.662Mn3Sn2          → Propagation vector: 0, 0, 0
# 🔍  663/2167 — 0.663Mn3Sn2          → Propagation vector: 0, 0, 0
# 🔍  664/2167 — 0.664Mn3Sn2          → Propagation vector: 0, 0, 0
# 🔍  665/2167 — 0.665CeMnSbO         → Propagation vector: 0, 0, 0
# 🔍  666/2167 — 0.666CeMnSbO         → Propagation vector: 0, 0, 0
# 🔍  667/2167 — 0.667LaMnSbO         → Propagation vector: 0, 0, 0
# 🔍  668/2167 — 0.668PrMnSbO         → Propagation vector: 0, 0, 0
# 🔍  669/2167 — 0.669Sr2YbRuO6       → Propagation vector: 0, 0, 0
# 🔍  670/2167 — 0.670Sr2YbRuO6       → Propagation vector: 0, 0, 0
# 🔍  671/2167 — 0.671Sr2TmRuO6       → Propagation vector: 0, 0, 0
# 🔍  672/2167 — 0.672CaCu3Fe2Sb2O12  → Propagation vector: 0, 0, 0
# 🔍  673/2167 — 0.673MnFe4Si3        → Propagation vector: 0, 0, 0
# 🔍  674/2167 — 0.674MnFe4Si3        → Propagation vector: 0, 0, 0
# 🔍  675/2167 — 0.675MnFe4Si3        → Propagation vector: 0, 0, 0
# 🔍  676/2167 — 0.676Nd0.95Sr0.05CrO3 → Propagation vector: 0, 0, 0
# 🔍  677/2167 — 0.677Nd0.9Sr0.1CrO3  → Propagation vector: 0, 0, 0
# 🔍  678/2167 — 0.678Nd0.85Sr0.15CrO3 → Propagation vector: 0, 0, 0
# 🔍  679/2167 — 0.679TbCr0.5Mn0.5O3  → Propagation vector: 0, 0, 0
# 🔍  680/2167 — 0.680Bi0.8La0.2Fe0.5Mn0.5O3 → Propagation vector: 0, 0, 0
# 🔍  681/2167 — 0.681Ce4Sb3          → Propagation vector: 0, 0, 0
# 🔍  682/2167 — 0.682Ca2FeOsO6       → Propagation vector: 0, 0, 0
# 🔍  683/2167 — 0.683SrCaFeOsO6      → Propagation vector: 0, 0, 0
# 🔍  684/2167 — 0.684TbPt            → Propagation vector: 0, 0, 0
# 🔍  685/2167 — 0.685ErPt            → Propagation vector: 0, 0, 0
# 🔍  686/2167 — 0.686HoPt            → Propagation vector: 0, 0, 0
# 🔍  687/2167 — 0.687DyPt            → Propagation vector: 0, 0, 0
# 🔍  688/2167 — 0.688TmPt            → Propagation vector: 0, 0, 0
# 🔍  689/2167 — 0.689PrPt            → Propagation vector: 0, 0, 0
# 🔍  690/2167 — 0.690NdPt            → Propagation vector: 0, 0, 0
# 🔍  691/2167 — 0.691CaCo1.86As2     → Propagation vector: 1, 1, 1
# 🔍  692/2167 — 0.692Ba4Ru3O10       → Propagation vector: 0, 0, 0
# 🔍  693/2167 — 0.693Ba4Ru3O10       → Propagation vector: 0, 0, 0
# 🔍  694/2167 — 0.694Bi2CuO4         → Propagation vector: 0, 0, 0
# 🔍  695/2167 — 0.695Bi2CuO4         → Propagation vector: 0, 0, 0
# 🔍  696/2167 — 0.696SmCrO3          → Propagation vector: 0, 0, 0
# 🔍  697/2167 — 0.697SmCrO3          → Propagation vector: 0, 0, 0
# 🔍  698/2167 — 0.698SmCrO3          → Propagation vector: 0, 0, 0
# 🔍  699/2167 — 0.699LiMn6Sn6        → Propagation vector: 0, 0, 0
# 🔍  700/2167 — 0.700TbMn6Sn6        → Propagation vector: 0, 0, 0
# 🔍  701/2167 — 0.701TbMn6Sn6        → Propagation vector: 0, 0, 0
# 🔍  702/2167 — 0.702TbMn6Sn6        → Propagation vector: 0, 0, 0
# 🔍  703/2167 — 0.703HoMn6Sn6        → Propagation vector: 0, 0, 0
# 🔍  704/2167 — 0.704HoMn6Sn6        → Propagation vector: 0, 0, 0
# 🔍  705/2167 — 0.705HoMn6Sn6        → Propagation vector: 0, 0, 0
# 🔍  706/2167 — 0.706Tb2Ir3Ga9       → Propagation vector: 0, 0, 0
# 🔍  707/2167 — 0.707Tb2Ir3Ga9       → Propagation vector: 0, 0, 0
# 🔍  708/2167 — 0.708CrNb4S8         → Propagation vector: 0, 0, 0
# 🔍  709/2167 — 0.709MnNb4S8         → Propagation vector: 0, 0, 0
# 🔍  710/2167 — 0.710MnNb3S6         → Propagation vector: 0, 0, 0
# 🔍  711/2167 — 0.711MnTa4S8         → Propagation vector: 0, 0, 0
# 🔍  712/2167 — 0.712VNb3S6          → Propagation vector: 0, 0, 0
# 🔍  713/2167 — 0.713NiFe2O4         → Propagation vector: 0, 0, 0
# 🔍  714/2167 — 0.714Li2Ni(SO4)2     → Propagation vector: 0, 0, 0
# 🔍  715/2167 — 0.715HoCrWO6         → Propagation vector: 0, 0, 0
# 🔍  716/2167 — 0.716HoCrWO6         → Propagation vector: 0, 0, 0
# 🔍  717/2167 — 0.717Pr0.5Sr0.4Ba0.1CoO3 → Propagation vector: 0, 0, 0
# 🔍  718/2167 — 0.718Pr0.5Sr0.4Ba0.1CoO3 → Propagation vector: 0, 0, 0
# 🔍  719/2167 — 0.719Yb0.42Sc0.58FeO3 → Propagation vector: 0, 0, 0
# 🔍  720/2167 — 0.720Yb0.42Sc0.58FeO3 → Propagation vector: 0, 0, 0
# 🔍  721/2167 — 0.721Yb0.42Sc0.58FeO3 → Propagation vector: 0, 0, 0
# 🔍  722/2167 — 0.722Mn4Nb2O9        → Propagation vector: 0, 0, 0
# 🔍  723/2167 — 0.723YbCl3           → Propagation vector: 0, 0, 0
# 🔍  724/2167 — 0.724BaCoSiO4        → Propagation vector: 0, 0, 0
# 🔍  725/2167 — 0.725Ce5TeO8         → Propagation vector: 0, 0, 0
# 🔍  726/2167 — 0.726CsMn2F6         → Propagation vector: 0, 0, 0
# 🔍  727/2167 — 0.727CsMn2F6         → Propagation vector: 0, 0, 0
# 🔍  728/2167 — 0.728MoP3SiO11       → Propagation vector: 0, 0, 0
# 🔍  729/2167 — 0.729ErNi4B          → Propagation vector: 0, 0, 0
# 🔍  730/2167 — 0.730TbNi4B          → Propagation vector: 0, 0, 0
# 🔍  731/2167 — 0.731HoNi4B          → Propagation vector: 0, 0, 0
# 🔍  732/2167 — 0.732SrRuO3          → Propagation vector: 0, 0, 0
# 🔍  733/2167 — 0.733AgRuO3          → Propagation vector: 0, 0, 0
# 🔍  734/2167 — 0.734Mn3Ta2O8        → Propagation vector: 0, 0, 0
# 🔍  735/2167 — 0.735LaBaMn2O5       → Propagation vector: 0, 0, 0
# ...
# 🔍 1932/2167 — 1.763BaNiTe2O7       → Propagation vector: 1/2, 1, 0
# 🔍 1933/2167 — 1.764NdSbTe          → Propagation vector: 1/2, 0, 1/4
# 🔍 1934/2167 — 1.765DySbTe          → Propagation vector: 0, 0, 1/2
# 🔍 1935/2167 — 1.766DySbTe          → Propagation vector: 1/2, 0, 1/4
# 🔍 1936/2167 — 1.767Li2CoCl4        → Propagation vector: 1, 0, 0
# 🔍 1937/2167 — 1.768Ni2Mo3O8        → Propagation vector: 1/2, 0, 0
# 🔍 1938/2167 — 1.769Ni2Te3O8        → Propagation vector: 1, 0, 0
# 🔍 1939/2167 — 1.770Tb2Ni2In        → Propagation vector: 1/2, 1/2, 1/2
# 🔍 1940/2167 — 1.771Na2Co2TeO6      → Propagation vector: 1/2, 1/2, 0
# 🔍 1941/2167 — 1.772Pr2PdAl7Ge4     → Propagation vector: 0, 0, 1/2
# 🔍 1942/2167 — 1.773PrIr3B2         → Propagation vector: 1/2, 1/2, 0
# 🔍 1943/2167 — 1.774BaNd2PtO5       → Propagation vector: 1/2, 1/2, 1/2
# 🔍 1944/2167 — 1.775CaCu3Ti4O12     → Propagation vector: 1, 1, 1
# 🔍 1945/2167 — 1.776Ba2ErRuO6       → Propagation vector: 0, 0, 1
# 🔍 1946/2167 — 1.777EuAl2Si2        → Propagation vector: 0, 0, 1/2
# 🔍 1947/2167 — 1.778ThCr2Si2C       → Propagation vector: 0, 0, 1/2
# 🔍 1948/2167 — 1.779Sr2FeIrO6       → Propagation vector: 0, 1/2, 1/2
# 🔍 1949/2167 — 1.780YMn12           → Propagation vector: 0, 0, 1
# 🔍 1950/2167 — 1.781CsMn(NCS)3      → Propagation vector: 0, 1/2, 1/2
# 🔍 1951/2167 — 1.782FeBr3           → Propagation vector: 0, 0, 3/2
# 🔍 1952/2167 — 1.783Fe0.99O         → Propagation vector: 0, 0, 1/2
# 🔍 1953/2167 — 1.784Li2CoCl4        → Propagation vector: 1, 0, 0
# 🔍 1954/2167 — 1.785K2ReCl6         → Propagation vector: 1/2, -1/2, 0
# 🔍 1955/2167 — 1.786RuBr3           → Propagation vector: 0, 1/2, 1
# 🔍 1956/2167 — 1.787RuCl3           → Propagation vector: 0, 1/2, 1
# 🔍 1957/2167 — 1.788Na3Co2SbO6      → Propagation vector: 1/2, 1/2, 0
# 🔍 1958/2167 — 1.789Na3Ni2BiO6      → Propagation vector: 0, 1, 0
# 🔍 1959/2167 — 1.790Tm5Pt2In4       → Propagation vector: 0, 1/2, 1/2
# 🔍 1960/2167 — 1.791La0.4Na0.6Fe2As2 → Propagation vector: 1/2, 1/2, 0
# 🔍 1961/2167 — 1.792V3O5            → Propagation vector: 1/2, 1/2, 0
# 🔍 1962/2167 — 1.793Ca3Ru2O7        → Propagation vector: 1, 0, 0
# 🔍 1963/2167 — 1.794Ca3Ru2O7        → Propagation vector: 1, 0, 0
# 🔍 1964/2167 — 1.795BiMn3Cr4O12     → Propagation vector: 1, 1, 1
# 🔍 1965/2167 — 1.796BiMn3Cr4O12     → Propagation vector: 1, 1, 1
# 🔍 1966/2167 — 1.797BiMn3Cr4O12     → Propagation vector: 1, 1, 1
# 🔍 1967/2167 — 1.798Tb2O3           → Propagation vector: 1, 1, 1
# 🔍 1968/2167 — 1.799MnO             → Propagation vector: 1/2, 1/2, 1/2
# 🔍 1969/2167 — 1.800NiO             → Propagation vector: 1/2, 1/2, 1/2
# 🔍 1970/2167 — 1.801Tb3NbO7         → Propagation vector: 1, 0, 0
# 🔍 1971/2167 — 1.802CrSBr           → Propagation vector: 0, 0, 1/2
# 🔍 1972/2167 — 1.803LiCrTe2         → Propagation vector: 0, 0, 1/2
# 🔍 1973/2167 — 1.804Na2Cu3O(SO4)3   → Propagation vector: 0, 1, 0
# 🔍 1974/2167 — 1.805FeVMoO7         → Propagation vector: 1/2, 1/2, 1/2
# 🔍 1975/2167 — 1.806CrVMoO7         → Propagation vector: 1/2, 0, 1/2
# 🔍 1976/2167 — 1.807FeWO4           → Propagation vector: 1/2, 0, 0
# 🔍 1977/2167 — 1.808BaFeO2.96       → Propagation vector: 0, 0, 1/2
# 🔍 1978/2167 — 1.809BiCoO3          → Propagation vector: 1/2, 1/2, 0
# 🔍 1979/2167 — 1.810BiCoO3          → Propagation vector: 1/2, 1/2, 0
# 🔍 1980/2167 — 1.811BiCoO3          → Propagation vector: 1/2, 1/2, 0
# 🔍 1981/2167 — 1.812TbFe6Ge6        → Propagation vector: 1, 0, 0
# 🔍 1982/2167 — 1.813TbFe6Ge6        → Propagation vector: 1, 0, 0
# 🔍 1983/2167 — 1.814TbFe6Ge6        → Propagation vector: 1, 0, 0
# 🔍 1984/2167 — 1.815Ba4CeMn3O12     → Propagation vector: 1/4, 1/4, 3/2
# 🔍 1985/2167 — 1.816Ba4PrMn3O12     → Propagation vector: 1/4, 1/4, 3/2
# 🔍 1986/2167 — 1.817Ba4PrMn3O12     → Propagation vector: 1/4, 1/4, 3/2
# 🔍 1987/2167 — 1.818(Ho0.68Lu0.32)2Fe2Si2C → Propagation vector: 0, 0, 1/2
# 🔍 1988/2167 — 1.819(Ho0.54Lu0.46)2Fe2Si2C → Propagation vector: 0, 0, 1/2
# 🔍 1989/2167 — 1.820Ba4TbRu3O12     → Propagation vector: 0, 0, 3/2
# 🔍 1990/2167 — 1.821Yb3Ga5O12       → Propagation vector: 1/2, 1/2, 0
# 🔍 1991/2167 — 1.822Sr2MnSi2O7      → Propagation vector: 0, 0, 1/2
# 🔍 1992/2167 — 1.823Sr2MnSi2O7      → Propagation vector: 0, 0, 1/2
# 🔍 1993/2167 — 1.824PbCo2V2O8       → Propagation vector: 1, 1, 1
# 🔍 1994/2167 — 1.825TbFeWO6         → Propagation vector: 0, 1/2, 1/2
# 🔍 1995/2167 — 1.826NdZnPO          → Propagation vector: 1/2, 0, 1/2
# 🔍 1996/2167 — 1.827(Co0.45Fe0.55)Sn → Propagation vector: 0, 0, 1/2
# 🔍 1997/2167 — 1.828ZnFe2O4         → Propagation vector: 1, 0, 1/2
# 🔍 1998/2167 — 1.829LuFeWO6         → Propagation vector: 0, 1/2, 1/2
# 🔍 1999/2167 — 1.830FeBi4S7         → Propagation vector: 1, 0, 1/2
# 🔍 2000/2167 — 1.831Y6FeSi2S14      → Propagation vector: 1/3, 1/3, 1/2
# 🔍 2001/2167 — 1.832Tb6FeSi2S14     → Propagation vector: 1/3, 1/3, 1/2
# 🔍 2002/2167 — 1.833Pb(OF)Cu3(SeO3)2(NO3) → Propagation vector: 0, 0, 3/2
# 🔍 2003/2167 — 1.834Na3Co(CO3)2Cl   → Propagation vector: 0, 0, 0
# 🔍 2004/2167 — 1.835La2Co2O3Se2     → Propagation vector: 1/2, 1/2, 0
# 🔍 2005/2167 — 1.836CeLi3Bi2        → Propagation vector: 1/2, 0, 0
# 🔍 2006/2167 — 1.837Y2Co3           → Propagation vector: 0, 1, 0
# 🔍 2007/2167 — 1.838LaMn2Au4        → Propagation vector: 1, 1, 1
# 🔍 2008/2167 — 1.839LaMnAu5         → Propagation vector: 1/2, 1/2, 1/2
# 🔍 2009/2167 — 1.840Sr2Mn2O5        → Propagation vector: 0, 0, 1/2
# 🔍 2010/2167 — 1.841Sr3Fe2O5Cl2     → Propagation vector: 1/2, 1/2, 0
# 🔍 2011/2167 — 1.842Ca2FeO3Cl       → Propagation vector: 1/2, 1/2, 0
# 🔍 2012/2167 — 1.843Ca2FeO3Cl       → Propagation vector: 1/2, 1/2, 0
# 🔍 2013/2167 — 1.844Sr2FeO3Cl       → Propagation vector: 1/2, 1/2, 0
# 🔍 2014/2167 — 1.845Sr2FeO3Cl       → Propagation vector: 1/2, 1/2, 0
# 🔍 2015/2167 — 1.846LaCu3Fe4O12     → Propagation vector: 1/2, 1/2, 1/2
# 🔍 2016/2167 — 1.847PrCaFeO4        → Propagation vector: 1, 0, 0
# 🔍 2017/2167 — 1.848La2Ba2Mn4O11    → Propagation vector: 1, 0, 1/2
# 🔍 2018/2167 — 1.849Na3Ni2SbO6      → Propagation vector: 1/2, 1/2, 0
# 🔍 2019/2167 — 1.850Tb6FeSi2S14     → Propagation vector: 1/3, 1/3, 1/2
# 🔍 2020/2167 — 1.851Y6FeSi2S14      → Propagation vector: 1/3, 1/3, 1/2
# 🔍 2021/2167 — 1.852UCu0.6Bi2       → Propagation vector: 0, 0, 1/2
# 🔍 2022/2167 — 1.853Ba2YFeO5        → Propagation vector: 0, 1/2, 1/2
# 🔍 2023/2167 — 2.1EuFe2As2          → Propagation vector: Not found
# 🔍 2024/2167 — 2.2Sr2F2Fe2OS2       → Propagation vector: Not found
# 🔍 2025/2167 — 2.3HoNiO3            → Propagation vector: Not found
# 🔍 2026/2167 — 2.4Eu(Fe0.82Co0.18)As2 → Propagation vector: Not found
# 🔍 2027/2167 — 2.5Mn3CuN            → Propagation vector: Not found
# 🔍 2028/2167 — 2.6Nd2CuO4           → Propagation vector: Not found
# 🔍 2029/2167 — 2.7Sm2CuO4           → Propagation vector: Not found
# 🔍 2030/2167 — 2.8SrHo2O4           → Propagation vector: Not found
# 🔍 2031/2167 — 2.9Ca3CuNi2(PO4)4    → Propagation vector: Not found
# 🔍 2032/2167 — 2.10HoP              → Propagation vector: Not found
# 🔍 2033/2167 — 2.11TbMg             → Propagation vector: Not found
# 🔍 2034/2167 — 2.12TbMg             → Propagation vector: Not found
# 🔍 2035/2167 — 2.13UP               → Propagation vector: Not found
# 🔍 2036/2167 — 2.14NdMg             → Propagation vector: Not found
# 🔍 2037/2167 — 2.15Mn3Ni20P6        → Propagation vector: Not found
# 🔍 2038/2167 — 2.16Ce2PdGe3         → Propagation vector: Not found
# 🔍 2039/2167 — 2.17Pb2Mn0.6Co0.4WO6 → Propagation vector: Not found
# 🔍 2040/2167 — 2.18Sc2NiMnO6        → Propagation vector: Not found
# 🔍 2041/2167 — 2.19Mn3ZnC           → Propagation vector: Not found
# 🔍 2042/2167 — 2.20UAs              → Propagation vector: Not found
# 🔍 2043/2167 — 2.21TbOOH            → Propagation vector: Not found
# 🔍 2044/2167 — 2.22FeTa2O6          → Propagation vector: Not found
# 🔍 2045/2167 — 2.23Sr2CoO2Ag2Se2    → Propagation vector: Not found
# 🔍 2046/2167 — 2.24Ba2CoO2Ag2Se2    → Propagation vector: Not found
# 🔍 2047/2167 — 2.25Sr2CoOsO6        → Propagation vector: Not found
# 🔍 2048/2167 — 2.26PrCo2P2          → Propagation vector: Not found
# 🔍 2049/2167 — 2.27Sr2Mn3Sb2O2      → Propagation vector: Not found
# 🔍 2050/2167 — 2.28NpNiGa5          → Propagation vector: Not found
# 🔍 2051/2167 — 2.29Mn3O4            → Propagation vector: Not found
# 🔍 2052/2167 — 2.30CeRh2Si2         → Propagation vector: Not found
# 🔍 2053/2167 — 2.31Mn3ZnN           → Propagation vector: Not found
# 🔍 2054/2167 — 2.32Dy3Ru4Al12       → Propagation vector: Not found
# 🔍 2055/2167 — 2.33Na2Mn3Se4        → Propagation vector: Not found
# 🔍 2056/2167 — 2.34La0.25Pr0.75Co2P2 → Propagation vector: Not found
# 🔍 2057/2167 — 2.35CrSe             → Propagation vector: Not found
# 🔍 2058/2167 — 2.36TbGe3            → Propagation vector: Not found
# 🔍 2059/2167 — 2.37La8Cu7O19        → Propagation vector: Not found
# 🔍 2060/2167 — 2.38Pb2MnWO6         → Propagation vector: Not found
# 🔍 2061/2167 — 2.39LaCaFeO4         → Propagation vector: Not found
# 🔍 2062/2167 — 2.40LaBaFeO4         → Propagation vector: Not found
# 🔍 2063/2167 — 2.41LaSrFeO4         → Propagation vector: Not found
# 🔍 2064/2167 — 2.42LaSrFeO4         → Propagation vector: Not found
# 🔍 2065/2167 — 2.43Fe2MnBO5         → Propagation vector: Not found
# 🔍 2066/2167 — 2.44KCuMnS2          → Propagation vector: Not found
# 🔍 2067/2167 — 2.45Pb2BaCuFeO5Br    → Propagation vector: Not found
# 🔍 2068/2167 — 2.46Pb2BaCuFeO5Cl    → Propagation vector: Not found
# 🔍 2069/2167 — 2.47Y2SrCuFeO6.5     → Propagation vector: Not found
# 🔍 2070/2167 — 2.48Pr2CuO4          → Propagation vector: Not found
# 🔍 2071/2167 — 2.49La2O2Fe2OSe2     → Propagation vector: Not found
# 🔍 2072/2167 — 2.50EuMnBi2          → Propagation vector: Not found
# 🔍 2073/2167 — 2.51EuMnBi2          → Propagation vector: Not found
# 🔍 2074/2167 — 2.52Mn3O4            → Propagation vector: Not found
# 🔍 2075/2167 — 2.53Ba2Mn3Sb2O2      → Propagation vector: Not found
# 🔍 2076/2167 — 2.54Sr2Cr3As2O2      → Propagation vector: Not found
# 🔍 2077/2167 — 2.55Sr2Fe3Se2O3      → Propagation vector: Not found
# 🔍 2078/2167 — 2.56La2O2Fe2OS2      → Propagation vector: Not found
# 🔍 2079/2167 — 2.57TbMn2Si2         → Propagation vector: Not found
# 🔍 2080/2167 — 2.58La0.73Tb0.27Mn2Si2 → Propagation vector: Not found
# 🔍 2081/2167 — 2.59Mn3As2           → Propagation vector: Not found
# 🔍 2082/2167 — 2.60NdMn2Si2         → Propagation vector: Not found
# 🔍 2083/2167 — 2.61Fe3F8(H2O)2      → Propagation vector: Not found
# 🔍 2084/2167 — 2.62TbCrO3           → Propagation vector: Not found
# 🔍 2085/2167 — 2.63DyCrO3           → Propagation vector: Not found
# 🔍 2086/2167 — 2.64DyCrO3           → Propagation vector: Not found
# 🔍 2087/2167 — 2.65UPd2Si2          → Propagation vector: Not found
# 🔍 2088/2167 — 2.66FeSn2            → Propagation vector: Not found
# 🔍 2089/2167 — 2.67FeSn2            → Propagation vector: Not found
# 🔍 2090/2167 — 2.68FeGe2            → Propagation vector: Not found
# 🔍 2091/2167 — 2.69La0.5Ca0.5MnO3   → Propagation vector: Not found
# 🔍 2092/2167 — 2.70GdMg             → Propagation vector: Not found
# 🔍 2093/2167 — 2.71HoRh             → Propagation vector: Not found
# 🔍 2094/2167 — 2.72VNb3S6           → Propagation vector: Not found
# 🔍 2095/2167 — 2.73BaNd2ZnO5        → Propagation vector: Not found
# 🔍 2096/2167 — 2.74BaDy2O4          → Propagation vector: Not found
# 🔍 2097/2167 — 2.75Sr2Fe3S2O3       → Propagation vector: Not found
# 🔍 2098/2167 — 2.76Sr2Fe3Se2O3      → Propagation vector: Not found
# 🔍 2099/2167 — 2.77Eu2CuO4          → Propagation vector: Not found
# 🔍 2100/2167 — 2.78Nd2CuO4          → Propagation vector: Not found
# 🔍 2101/2167 — 2.79Pr2CuO4          → Propagation vector: Not found
# 🔍 2102/2167 — 2.80ErFe6Ge6         → Propagation vector: Not found
# 🔍 2103/2167 — 2.81ErMn2Si2         → Propagation vector: Not found
# 🔍 2104/2167 — 2.82ErMn2Si2         → Propagation vector: Not found
# 🔍 2105/2167 — 2.83ErMn2Ge2         → Propagation vector: Not found
# 🔍 2106/2167 — 2.84ErMn2Ge2         → Propagation vector: Not found
# 🔍 2107/2167 — 2.85Ho2BaCuO5        → Propagation vector: Not found
# 🔍 2108/2167 — 2.86FeTa2O6          → Propagation vector: Not found
# 🔍 2109/2167 — 2.87TbCoGa5          → Propagation vector: Not found
# 🔍 2110/2167 — 2.88UNiGa            → Propagation vector: Not found
# 🔍 2111/2167 — 2.89LaSrCrO4         → Propagation vector: Not found
# 🔍 2112/2167 — 2.90Mn3O4            → Propagation vector: Not found
# 🔍 2113/2167 — 2.91NaCo2(SeO3)2(OH) → Propagation vector: Not found
# 🔍 2114/2167 — 2.92Er2Ni2Pb         → Propagation vector: Not found
# 🔍 2115/2167 — 2.93CoCrO4           → Propagation vector: Not found
# 🔍 2116/2167 — 2.94TmMn2Ge2         → Propagation vector: Not found
# 🔍 2117/2167 — 2.95TbMn2Ge2         → Propagation vector: Not found
# 🔍 2118/2167 — 2.96GdMn2Si2         → Propagation vector: Not found
# 🔍 2119/2167 — 2.97GdMn2Si2         → Propagation vector: Not found
# 🔍 2120/2167 — 2.98EuMnBi2          → Propagation vector: Not found
# 🔍 2121/2167 — 2.99TbNiAl           → Propagation vector: Not found
# 🔍 2122/2167 — 2.100HoP             → Propagation vector: Not found
# 🔍 2123/2167 — 2.101TbSbTe          → Propagation vector: Not found
# 🔍 2124/2167 — 2.102TbSbTe          → Propagation vector: Not found
# 🔍 2125/2167 — 2.103Eu3PbO          → Propagation vector: Not found
# 🔍 2126/2167 — 2.104BaNd2ZnS5       → Propagation vector: Not found
# 🔍 2127/2167 — 2.105DySbTe          → Propagation vector: Not found
# 🔍 2128/2167 — 2.106CaCo3V4O12      → Propagation vector: Not found
# 🔍 2129/2167 — 2.107DyTe3           → Propagation vector: Not found
# 🔍 2130/2167 — 2.108Tb3NbO7         → Propagation vector: Not found
# 🔍 2131/2167 — 2.109La0.35Pr0.35Ca0.3MnO3 → Propagation vector: Not found
# 🔍 2132/2167 — 2.110La0.35Pr0.35Ca0.3MnO3 → Propagation vector: Not found
# 🔍 2133/2167 — 2.111TbFe6Ge6        → Propagation vector: Not found
# 🔍 2134/2167 — 2.112TbFe6Ge6        → Propagation vector: Not found
# 🔍 2135/2167 — 2.113TbFe6Ge6        → Propagation vector: Not found
# 🔍 2136/2167 — 2.114Er2CuMn5O12     → Propagation vector: Not found
# 🔍 2137/2167 — 2.115Er2CuMn5O12     → Propagation vector: Not found
# 🔍 2138/2167 — 2.116Na3Co2SbO6      → Propagation vector: Not found
# 🔍 2139/2167 — 3.1TmAgGe            → Propagation vector: Not found
# 🔍 2140/2167 — 3.2UO2               → Propagation vector: Not found
# 🔍 2141/2167 — 3.3Ho2RhIn8          → Propagation vector: Not found
# 🔍 2142/2167 — 3.4MgCr2O4           → Propagation vector: Not found
# 🔍 2143/2167 — 3.5Fe0.7Mn0.3        → Propagation vector: Not found
# 🔍 2144/2167 — 3.6DyCu              → Propagation vector: Not found
# 🔍 2145/2167 — 3.7NpBi              → Propagation vector: Not found
# 🔍 2146/2167 — 3.8NdZn              → Propagation vector: Not found
# 🔍 2147/2167 — 3.9NpS               → Propagation vector: Not found
# 🔍 2148/2167 — 3.10NpSe             → Propagation vector: Not found
# 🔍 2149/2167 — 3.11NpTe             → Propagation vector: Not found
# 🔍 2150/2167 — 3.12USb              → Propagation vector: Not found
# 🔍 2151/2167 — 3.13CeB6             → Propagation vector: Not found
# 🔍 2152/2167 — 3.14FeI2             → Propagation vector: Not found
# 🔍 2153/2167 — 3.15FeI2             → Propagation vector: Not found
# 🔍 2154/2167 — 3.16Gd2Ti2O7         → Propagation vector: Not found
# 🔍 2155/2167 — 3.17BaCu3V2O8(OD)2   → Propagation vector: Not found
# 🔍 2156/2167 — 3.18HoRh             → Propagation vector: Not found
# 🔍 2157/2167 — 3.19CoO              → Propagation vector: Not found
# 🔍 2158/2167 — 3.20TbMn2Ge2         → Propagation vector: Not found
# 🔍 2159/2167 — 3.21TmGa3            → Propagation vector: Not found
# 🔍 2160/2167 — 3.22Eu3PbO           → Propagation vector: Not found
# 🔍 2161/2167 — 3.23Eu3PbO           → Propagation vector: Not found
# 🔍 2162/2167 — 3.24CaFe3Ti4O12      → Propagation vector: Not found
# 🔍 2163/2167 — 3.25CoTa3S6          → Propagation vector: Not found
# 🔍 2164/2167 — 3.26CoNb3S6          → Propagation vector: Not found
# 🔍 2165/2167 — 3.27Gd3Ru4Al12       → Propagation vector: Not found
# 🔍 2166/2167 — 3.28NiO              → Propagation vector: Not found
# 🔍 2167/2167 — 3.29Na2Co2TeO6       → Propagation vector: Not found
# ✅ All done! Results saved to 'MAGNDATA_Commensurate_WithVectors.csv'

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import time
import numpy as np

df = pd.read_csv("MAGNDATA_Commensurate_Only.csv")
subset = df.copy()

def clean_float(val):
    val = val.replace("\u2212", "-")  # Unicode minus
    val = re.sub(r"\([^)]*\)", "", val)  # Remove uncertainty like (7)
    val = re.sub(r"[^\d\.\-]+", "", val)  # Remove anything non-numeric
    try:
        return float(val)
    except:
        return None

def extract_all_moments(url):
    try:
        response = requests.get(url, timeout=10)
        soup = BeautifulSoup(response.content, "html.parser")

        moments = []

        # Look for all tables with Mx, My, Mz as last 3 headers
        for table in soup.find_all("table"):
            headers = table.find_all("th")
            if len(headers) >= 3 and [h.get_text(strip=True) for h in headers[-3:]] == ["Mx", "My", "Mz"]:
                rows = table.find_all("tr")[1:]  # skip header
                for row in rows:
                    cols = row.find_all("td")
                    if len(cols) < 3:
                        continue
                    mx = clean_float(cols[-3].get_text())
                    my = clean_float(cols[-2].get_text())
                    mz = clean_float(cols[-1].get_text())
                    if None not in (mx, my, mz):
                        vec = np.array([mx, my, mz])
                        if np.linalg.norm(vec) > 0.01:
                            moments.append(vec)

        return moments

    except Exception as e:
        print(f"⚠️ Error parsing {url}: {e}")
        return None

def classify_order(moments):
    if not moments or len(moments) < 2:
        return "Unknown"

    moments = np.array(moments)
    norms = np.linalg.norm(moments, axis=1)

    if np.all(norms < 0.0005):
        return "NM"

    directions = moments / norms[:, None]
    ref_dir = directions[0]

    # Check if all directions ~ parallel to ref_dir
    all_parallel = np.allclose(directions, ref_dir, atol=0.15)

    if all_parallel:
        # Now check if magnitudes are also equal → FM
        if np.allclose(norms, norms[0], rtol=0.1):  # 10% tolerance
            return "FM"
        else:
            return "FiM"

    # If not all parallel, check if all are either aligned or anti-aligned
    if all(np.allclose(d, ref_dir, atol=0.15) or np.allclose(d, -ref_dir, atol=0.15) for d in directions):
        return "AFM"

    return "Complex"


# Run for subset
orders = []
for i, (label, url) in enumerate(zip(subset["Full Label"], subset["URL"])):
    all_moments = extract_all_moments(url)
    order = classify_order(all_moments)
    orders.append(order)
    print(f"{i+1:2d}. {label:<20} → Magnetic Order: {order}")
    time.sleep(0.5)

subset["Magnetic Order"] = orders
subset.to_csv("MAGNDATA_MagneticOrder_AllSpecies.csv", index=False)
print("✅ Saved to 'MAGNDATA_MagneticOrder_AllSpecies.csv'")
# Out:
#  1. 0.1LaMnO3            → Magnetic Order: AFM
#  2. 0.2Cd2Os2O7          → Magnetic Order: Complex
#  3. 0.3Ca3LiOsO6         → Magnetic Order: AFM
#  4. 0.4NiCr2O4           → Magnetic Order: AFM
#  5. 0.5Cr2S3             → Magnetic Order: AFM
#  6. 0.6YMnO3             → Magnetic Order: Complex
#  7. 0.7ScMnO3            → Magnetic Order: Complex
#  8. 0.8ScMnO3            → Magnetic Order: Complex
#  9. 0.9GdB4              → Magnetic Order: Complex
# 10. 0.10DyFeO3           → Magnetic Order: Complex
# 11. 0.11DyFeO3           → Magnetic Order: Complex
# 12. 0.12U3Ru4Al12        → Magnetic Order: Complex
# 13. 0.13Ca3Co2-xMnxO6    → Magnetic Order: AFM
# 14. 0.14Gd5Ge4           → Magnetic Order: AFM
# 15. 0.15MnF2             → Magnetic Order: AFM
# 16. 0.16EuTiO3           → Magnetic Order: AFM
# 17. 0.17FePO4            → Magnetic Order: Complex
# 18. 0.18BaMn2As2         → Magnetic Order: AFM
# 19. 0.19MnTiO3           → Magnetic Order: AFM
# 20. 0.20MnTe2            → Magnetic Order: Complex
# 21. 0.21PbNiO3           → Magnetic Order: AFM
# 22. 0.22DyB4             → Magnetic Order: AFM
# 23. 0.23Ca3Mn2O7         → Magnetic Order: AFM
# 24. 0.24LiMnPO4          → Magnetic Order: AFM
# 25. 0.25NaOsO3           → Magnetic Order: AFM
# 26. 0.26TmAgGe           → Magnetic Order: Complex
# 27. 0.27YFe4Ge2          → Magnetic Order: Complex
# 28. 0.28LiFeSi2O6        → Magnetic Order: AFM
# 29. 0.29Er2Ti2O7         → Magnetic Order: Complex
# 30. 0.30YbMnO3           → Magnetic Order: Complex
# 31. 0.31HoMnO3           → Magnetic Order: Complex
# 32. 0.32HoMnO3           → Magnetic Order: Complex
# 33. 0.33HoMnO3           → Magnetic Order: Complex
# 34. 0.34La0.5Sr0.5FeO2.5F0.5 → Magnetic Order: AFM
# 35. 0.35Cu2OSeO3         → Magnetic Order: AFM
# 36. 0.36NiF2             → Magnetic Order: AFM
# 37. 0.37U3Al2Si3         → Magnetic Order: Complex
# 38. 0.38GaFeO3           → Magnetic Order: AFM
# 39. 0.39Nd2NaRuO6        → Magnetic Order: Complex
# 40. 0.40Mn2O3-alpha      → Magnetic Order: Complex
# 41. 0.41Mn2O3-alpha      → Magnetic Order: Complex
# 42. 0.42HoMnO3           → Magnetic Order: Complex
# 43. 0.43HoMnO3           → Magnetic Order: Complex
# 44. 0.44YMnO3            → Magnetic Order: Complex
# 45. 0.45La2NiO4          → Magnetic Order: AFM
# 46. 0.46CaBaCo4O7        → Magnetic Order: Complex
# 47. 0.47Gd2Sn2O7         → Magnetic Order: Complex
# 48. 0.48Tb2Sn2O7         → Magnetic Order: Complex
# 49. 0.49Ho2Ru2O7         → Magnetic Order: Complex
# 50. 0.50MnTiO3           → Magnetic Order: AFM
# 51. 0.51Ho2Ru2O7         → Magnetic Order: Complex
# 52. 0.52KyFe2-xSe2       → Magnetic Order: AFM
# 53. 0.53RbyFe2-xSe2      → Magnetic Order: AFM
# 54. 0.54RbyFe2-xSe2      → Magnetic Order: AFM
# 55. 0.55KyFe2-xSe2       → Magnetic Order: AFM
# 56. 0.56Ba2CoGe2O7       → Magnetic Order: AFM
# 57. 0.57ScFeO3           → Magnetic Order: AFM
# 58. 0.58CoAl2O4          → Magnetic Order: AFM
# 59. 0.59Cr2O3            → Magnetic Order: AFM
# 60. 0.60[NH2(CH3)2]n[FeIIIFeII(HCOO)6]n → Magnetic Order: Complex
# 61. 0.61Li2FeP2O7        → Magnetic Order: Complex
# 62. 0.62SrMn2V2O8        → Magnetic Order: AFM
# 63. 0.63Ho2CrSbO7        → Magnetic Order: Complex
# 64. 0.64MnV2O4           → Magnetic Order: Complex
# 65. 0.65Fe2O3-alpha      → Magnetic Order: AFM
# 66. 0.66Fe2O3-alpha      → Magnetic Order: AFM
# 67. 0.67BiFe0.5Sc0.5O3   → Magnetic Order: AFM
# 68. 0.68BiFe0.5Sc0.5O3   → Magnetic Order: AFM
# 69. 0.69Co4(OH)2(C10H16O4)3 → Magnetic Order: Complex
# 70. 0.70Na3Co(CO3)2Cl    → Magnetic Order: Complex
# 71. 0.71Li2Ni(SO4)2      → Magnetic Order: AFM
# 72. 0.72CaMnBi2          → Magnetic Order: AFM
# 73. 0.73SrMnBi2          → Magnetic Order: AFM
# 74. 0.74Mn3Cu0.5Ge0.5N   → Magnetic Order: Complex
# 75. 0.75Cr2WO6           → Magnetic Order: AFM
# 76. 0.76Cr2TeO6          → Magnetic Order: AFM
# 77. 0.77Tb2Ti2O7         → Magnetic Order: Complex
# 78. 0.78NiN2O6           → Magnetic Order: Complex
# 79. 0.79CaIrO3           → Magnetic Order: AFM
# 80. 0.80U2Pd2In          → Magnetic Order: Complex
# 81. 0.81U2Pd2Sn          → Magnetic Order: Complex
# 82. 0.82Gd2CuO4          → Magnetic Order: Complex
# 83. 0.83LiFeP2O7         → Magnetic Order: AFM
# 84. 0.84Mn2FeMoO6        → Magnetic Order: AFM
# 85. 0.85KCo4(PO4)3       → Magnetic Order: Complex
# 86. 0.86KMn4(PO4)3       → Magnetic Order: AFM
# 87. 0.87NaFePO4          → Magnetic Order: AFM
# 88. 0.88LiNiPO4          → Magnetic Order: Complex
# 89. 0.89BaMn2Bi2         → Magnetic Order: AFM
# 90. 0.90Rb2Fe2O(AsO4)2   → Magnetic Order: Complex
# 91. 0.91Rb2Fe2O(AsO4)2   → Magnetic Order: Complex
# 92. 0.92CaMn2Sb2         → Magnetic Order: AFM
# 93. 0.93Ca2Fe2O5         → Magnetic Order: Complex
# 94. 0.94TeNiO3           → Magnetic Order: Complex
# 95. 0.95LiFePO4          → Magnetic Order: AFM
# 96. 0.96CoSO4            → Magnetic Order: Complex
# 97. 0.97FeSb2O4          → Magnetic Order: Complex
# 98. 0.98YBaMn2O5.5       → Magnetic Order: AFM
# 99. 0.99YBaMn2O5.5       → Magnetic Order: AFM
# 100. 0.100YCr0.5Mn0.5O3   → Magnetic Order: Complex
# 101. 0.101Mn2GeO4         → Magnetic Order: Complex
# 102. 0.102Mn2GeO4         → Magnetic Order: Complex
# 103. 0.103Mn2GeO4         → Magnetic Order: Complex
# 104. 0.104ErVO3           → Magnetic Order: Complex
# 105. 0.105ErVO3           → Magnetic Order: AFM
# 106. 0.106DyVO3           → Magnetic Order: Complex
# 107. 0.107Ho2Ge2O7        → Magnetic Order: Complex
# 108. 0.108Mn3Ir           → Magnetic Order: Complex
# 109. 0.109Mn3Pt           → Magnetic Order: Complex
# 110. 0.110Cr2O3           → Magnetic Order: AFM
# 111. 0.111Co4Nb2O9        → Magnetic Order: AFM
# 112. 0.112FeBO3           → Magnetic Order: AFM
# 113. 0.113NiCO3           → Magnetic Order: AFM
# 114. 0.114CoCO3           → Magnetic Order: AFM
# 115. 0.115MnCO3           → Magnetic Order: AFM
# 116. 0.116FeCO3           → Magnetic Order: AFM
# 117. 0.117LuFeO3          → Magnetic Order: Complex
# 118. 0.118Ba5Co5ClO13     → Magnetic Order: AFM
# 119. 0.119CoSe2O5         → Magnetic Order: Complex
# 120. 0.120LiFe(SO4)2      → Magnetic Order: AFM
# 121. 0.121Li2Co(SO4)2     → Magnetic Order: AFM
# 122. 0.122Li2Mn(SO4)2     → Magnetic Order: AFM
# 123. 0.123Mn3NiN          → Magnetic Order: Complex
# 124. 0.124Mn3NiN          → Magnetic Order: Complex
# 125. 0.125MnGeO3          → Magnetic Order: AFM
# 126. 0.126NpCo2           → Magnetic Order: AFM
# 127. 0.127Dy3Al5O12       → Magnetic Order: Complex
# 128. 0.128FeSO4F          → Magnetic Order: AFM
# 129. 0.129Cu3Mo2O9        → Magnetic Order: Complex
# 130. 0.130Cu3Mo2O9        → Magnetic Order: Complex
# 131. 0.131Mn(N(CN2))2     → Magnetic Order: AFM
# 132. 0.132Fe(N(CN2))2     → Magnetic Order: Complex
# 133. 0.133Ni3B7O13Cl      → Magnetic Order: Complex
# 134. 0.134Mn3B7O13I       → Magnetic Order: Complex
# 135. 0.135Ni3B7O13Br      → Magnetic Order: Complex
# 136. 0.136Co3B7O13Br      → Magnetic Order: Complex
# 137. 0.137Cu2V2O7         → Magnetic Order: AFM
# 138. 0.138BiCrO3          → Magnetic Order: AFM
# 139. 0.139BiCrO3          → Magnetic Order: AFM
# 140. 0.140LuFe4Ge2        → Magnetic Order: Complex
# 141. 0.141Tb5Ge4          → Magnetic Order: Complex
# 142. 0.142Fe2TeO6         → Magnetic Order: AFM
# 143. 0.143Cr2TeO6         → Magnetic Order: AFM
# 144. 0.144Cr2WO6          → Magnetic Order: AFM
# 145. 0.145Co3TeO6         → Magnetic Order: Complex
# 146. 0.146EuZrO3          → Magnetic Order: AFM
# 147. 0.147EuZrO3          → Magnetic Order: AFM
# 148. 0.148La2LiRuO6       → Magnetic Order: AFM
# 149. 0.149Nd3Ru4Al12      → Magnetic Order: FiM
# 150. 0.150NiS2            → Magnetic Order: Complex
# 151. 0.151Tm2Mn2O7        → Magnetic Order: Complex
# 152. 0.152LiFePO4         → Magnetic Order: AFM
# 153. 0.153Bi2RuMnO7       → Magnetic Order: AFM
# 154. 0.154Er2Ru2O7        → Magnetic Order: AFM
# 155. 0.155CaMnGe2O6       → Magnetic Order: AFM
# 156. 0.156CaMnGe2O6       → Magnetic Order: AFM
# 157. 0.157Yb2Sn2O7        → Magnetic Order: Complex
# 158. 0.158Yb2Ti2O7        → Magnetic Order: Complex
# 159. 0.159DyCoO3          → Magnetic Order: Complex
# 160. 0.160TbCoO3          → Magnetic Order: Complex
# 161. 0.161CoSe2O5         → Magnetic Order: AFM
# 162. 0.162NdCrTiO5        → Magnetic Order: Complex
# 163. 0.163MnPS3           → Magnetic Order: AFM
# 164. 0.164Y2MnCoO6        → Magnetic Order: Complex
# 165. 0.165SrMn(VO4)(OH)   → Magnetic Order: Complex
# 166. 0.166Ce2PdGe3        → Magnetic Order: AFM
# 167. 0.167Nd3Sb3Mg2O14    → Magnetic Order: Complex
# 168. 0.168NH4Fe2F6        → Magnetic Order: Complex
# 169. 0.169U3As4           → Magnetic Order: Complex
# 170. 0.170U3P4            → Magnetic Order: Complex
# 171. 0.171DyScO3          → Magnetic Order: Complex
# 172. 0.172Y3Co3.25Al0.75  → Magnetic Order: Complex
# 173. 0.173Pr3Ru4Al12      → Magnetic Order: FiM
# 174. 0.174Pr3Ru4Al12      → Magnetic Order: Complex
# 175. 0.175Ca2CoSi2O7      → Magnetic Order: AFM
# 176. 0.176Mn3Ti2Te6       → Magnetic Order: AFM
# 177. 0.177Mn3GaN          → Magnetic Order: Complex
# 178. 0.178CoF2            → Magnetic Order: AFM
# 179. 0.179FeCl5D2O(ND4)2  → Magnetic Order: Complex
# 180. 0.180MnPSe3          → Magnetic Order: AFM
# 181. 0.181Nd15Ge9C0.39    → Magnetic Order: Complex
# 182. 0.182KCrF4           → Magnetic Order: Complex
# 183. 0.183KMnFeF6         → Magnetic Order: Complex
# 184. 0.184Nd5Si4          → Magnetic Order: Complex
# 185. 0.185Nd5Ge4          → Magnetic Order: Complex
# 186. 0.186CeMnAsO         → Magnetic Order: AFM
# 187. 0.187CeMnAsO         → Magnetic Order: AFM
# 188. 0.188CeMnAsO         → Magnetic Order: Complex
# 189. 0.189CeMn2Ge4O12     → Magnetic Order: Unknown
# 190. 0.190CeMnCoGe4O12    → Magnetic Order: AFM
# 191. 0.191BaCuF4          → Magnetic Order: AFM
# 192. 0.192RbFe2F6         → Magnetic Order: Complex
# 193. 0.193LiCoPO4         → Magnetic Order: AFM
# 194. 0.194UPt2Si2         → Magnetic Order: AFM
# 195. 0.195Sr2Ir0.92Sn0.08O4 → Magnetic Order: Complex
# 196. 0.196Co4Nb2O9        → Magnetic Order: AFM
# 197. 0.197Co4Nb2O9        → Magnetic Order: AFM
# 198. 0.198GdVO4           → Magnetic Order: AFM
# 199. 0.199Mn3Sn           → Magnetic Order: Complex
# 200. 0.200Mn3Sn           → Magnetic Order: Complex
# 201. 0.201Ca2PrCr2NbO9    → Magnetic Order: AFM
# 202. 0.202Ca2PrCr2TaO9    → Magnetic Order: AFM
# 203. 0.203Mn3Ge           → Magnetic Order: Complex
# 204. 0.204Ca2MnReO6       → Magnetic Order: Complex
# 205. 0.205Sr2MnReO6       → Magnetic Order: Complex
# 206. 0.206Ca2Fe0.875Cr0.125GaO5 → Magnetic Order: AFM
# 207. 0.207TlFe1.6Se2      → Magnetic Order: Complex
# 208. 0.208TlFe1.6Se2      → Magnetic Order: AFM
# 209. 0.209TlFe1.6Se2      → Magnetic Order: AFM
# 210. 0.210Sr2CoOsO6       → Magnetic Order: AFM
# 211. 0.211Ca2MnO4         → Magnetic Order: AFM
# 212. 0.212Sr2Mn3As2O2     → Magnetic Order: AFM
# 213. 0.213Sr2Mn2CuAs2O2   → Magnetic Order: AFM
# 214. 0.214FePbBiO4        → Magnetic Order: Complex
# 215. 0.215BaNi2P2O8       → Magnetic Order: AFM
# 216. 0.216SrEr2O4         → Magnetic Order: AFM
# 217. 0.217LiCrGe2O6       → Magnetic Order: AFM
# 218. 0.218Co2SiO4         → Magnetic Order: Complex
# 219. 0.219Co2SiO4         → Magnetic Order: Complex
# 220. 0.220Mn2SiO4         → Magnetic Order: Complex
# 221. 0.221Fe2SiO4         → Magnetic Order: Complex
# 222. 0.222CuMnAs          → Magnetic Order: AFM
# 223. 0.223Cu0.95MnAs      → Magnetic Order: AFM
# 224. 0.224Nd0.5Tb0.5Co2   → Magnetic Order: Complex
# 225. 0.225Nd0.5Tb0.5Co2   → Magnetic Order: Complex
# 226. 0.226NdCo2           → Magnetic Order: FiM
# 227. 0.227NdCo2           → Magnetic Order: FiM
# 228. 0.228TbCo2           → Magnetic Order: FiM
# 229. 0.229Ba2MnSi2O7      → Magnetic Order: AFM
# 230. 0.230K2CoP2O7        → Magnetic Order: AFM
# 231. 0.231TmMn3O6         → Magnetic Order: AFM
# 232. 0.232TmMn3O6         → Magnetic Order: AFM
# 233. 0.233Mn2FeSbO6       → Magnetic Order: AFM
# 234. 0.234MnLaMnSbO6      → Magnetic Order: AFM
# 235. 0.235MnPrMnSbO6      → Magnetic Order: AFM
# 236. 0.236CaFe4Al8        → Magnetic Order: AFM
# 237. 0.237Er2Sn2O7        → Magnetic Order: Complex
# 238. 0.238Er2Pt2O7        → Magnetic Order: Complex
# 239. 0.239Ca3LiRuO6       → Magnetic Order: AFM
# 240. 0.240Er2Cu2O5        → Magnetic Order: Complex
# 241. 0.241Y2Cu2O5         → Magnetic Order: AFM
# 242. 0.242Tm2Cu2O5        → Magnetic Order: Complex
# 243. 0.243Li2Fe(SO4)2     → Magnetic Order: AFM
# 244. 0.244Li2Co(SO4)2     → Magnetic Order: AFM
# 245. 0.245Li1.5Fe(SO4)2   → Magnetic Order: AFM
# 246. 0.246LiFe(SO4)2      → Magnetic Order: AFM
# 247. 0.247Nd2NiO4.11      → Magnetic Order: Complex
# 248. 0.248TbPt0.8Cu0.2    → Magnetic Order: Complex
# 249. 0.249NdNi0.6Cu0.4    → Magnetic Order: Complex
# 250. 0.250(NH2(CH3)2)(FeCo(HCOO)6) → Magnetic Order: AFM
# 251. 0.251(NH2(CH3)2)(FeMn(HCOO)6) → Magnetic Order: Complex
# 252. 0.252Cs2FeCl5.D2O    → Magnetic Order: AFM
# 253. 0.253Cs2FeCl5.D2O    → Magnetic Order: Complex
# 254. 0.254[C(ND2)3]Cu(DCOO)3 → Magnetic Order: AFM
# 255. 0.255[C(ND2)3]Cu(DCOO)3 → Magnetic Order: AFM
# 256. 0.256[C(ND2)3]Mn(DCOO)3 → Magnetic Order: AFM
# 257. 0.257[C(ND2)3]Co(DCOO)3 → Magnetic Order: AFM
# 258. 0.258Li3Fe2(PO4)3    → Magnetic Order: AFM
# 259. 0.259Li3Fe2(PO4)3    → Magnetic Order: AFM
# 260. 0.260CuFePO5         → Magnetic Order: AFM
# 261. 0.261NiFePO5         → Magnetic Order: AFM
# 262. 0.262CoFePO5         → Magnetic Order: Complex
# 263. 0.263Fe2PO5          → Magnetic Order: AFM
# 264. 0.264Fe3(PO4)2       → Magnetic Order: AFM
# 265. 0.265Mn3(Co0.61Mn0.39)N → Magnetic Order: Complex
# 266. 0.266Na2BaCo(VO4)2   → Magnetic Order: FM
# 267. 0.267YbMnBi2         → Magnetic Order: AFM
# 268. 0.268Tb2MnNiO6       → Magnetic Order: Complex
# 269. 0.269Tb2MnNiO6       → Magnetic Order: Complex
# 270. 0.270Tb2MnNiO6       → Magnetic Order: FiM
# 271. 0.271Tb2MnNiO6       → Magnetic Order: FiM
# 272. 0.272Tb2MnNiO6       → Magnetic Order: FiM
# 273. 0.273Mn3ZnN          → Magnetic Order: Complex
# 274. 0.274Mn4N            → Magnetic Order: AFM
# 275. 0.275Mn3AlN          → Magnetic Order: FM
# 276. 0.276Mn3AlN          → Magnetic Order: FiM
# 277. 0.277MgMnO3          → Magnetic Order: AFM
# 278. 0.278Cu0.82Mn1.18As  → Magnetic Order: Complex
# 279. 0.279Mn3As           → Magnetic Order: Complex
# 280. 0.280Mn3As           → Magnetic Order: Complex
# 281. 0.281Co2V2O7         → Magnetic Order: Complex
# 282. 0.282U14Au51         → Magnetic Order: AFM
# 283. 0.283U14Au51         → Magnetic Order: Complex
# 284. 0.284KOsO4           → Magnetic Order: AFM
# 285. 0.285KRuO4           → Magnetic Order: AFM
# 286. 0.286Mn5Ge3          → Magnetic Order: FiM
# 287. 0.287SrCo(VO4)(OH)   → Magnetic Order: Complex
# 288. 0.288NdMnO3          → Magnetic Order: Complex
# 289. 0.289NdMnO3          → Magnetic Order: Complex
# 290. 0.290CeCu2           → Magnetic Order: AFM
# 291. 0.291Tl2NiMnO6       → Magnetic Order: FiM
# 292. 0.292NiTe2O5         → Magnetic Order: Complex
# 293. 0.293(Tm0.7Mn0.3)MnO3 → Magnetic Order: Complex
# 294. 0.294Cu4(OD)6FBr     → Magnetic Order: Complex
# 295. 0.295Cu2(OD)3Cl      → Magnetic Order: Complex
# 296. 0.296Cu2(OD)3Cl      → Magnetic Order: Complex
# 297. 0.297NaCrGe2O6       → Magnetic Order: FM
# 298. 0.298Na2BaFe(VO4)2   → Magnetic Order: Complex
# 299. 0.299Fe2O3           → Magnetic Order: AFM
# 300. 0.300Fe2O3           → Magnetic Order: AFM
# 301. 0.301Sr2CoTeO6       → Magnetic Order: AFM
# 302. 0.302Sr2Co0.9Mg0.1TeO6 → Magnetic Order: AFM
# 303. 0.303BaCrF5          → Magnetic Order: AFM
# 304. 0.304Pr0.5Sr0.5CoO3  → Magnetic Order: FM
# 305. 0.305Pr0.5Sr0.5CoO3  → Magnetic Order: FM
# 306. 0.306GaFeO3          → Magnetic Order: AFM
# 307. 0.307ScCrO3          → Magnetic Order: AFM
# 308. 0.308InCrO3          → Magnetic Order: AFM
# 309. 0.309TlCrO3          → Magnetic Order: AFM
# 310. 0.310NaMnFeF6        → Magnetic Order: AFM
# 311. 0.311CoGeO3          → Magnetic Order: Complex
# 312. 0.312MnGeO3          → Magnetic Order: AFM
# 313. 0.313MnGeO3          → Magnetic Order: AFM
# 314. 0.314ZrCo2Ge4O12     → Magnetic Order: Complex
# 315. 0.315ZrMn2Ge4O12     → Magnetic Order: AFM
# 316. 0.316DyCrWO6         → Magnetic Order: Complex
# 317. 0.317Ho2CoMnO6       → Magnetic Order: FM
# 318. 0.318Tm2CoMnO6       → Magnetic Order: Complex
# 319. 0.319Tm2CoMnO6       → Magnetic Order: Complex
# 320. 0.320U2Pd2In         → Magnetic Order: Complex
# 321. 0.321U2Pd2Sn         → Magnetic Order: Complex
# 322. 0.322Cu1.94Mn1.06BO5 → Magnetic Order: Complex
# 323. 0.323LaCrO3          → Magnetic Order: AFM
# 324. 0.324CdYb2S4         → Magnetic Order: Complex
# 325. 0.325CdYb2Se4        → Magnetic Order: Complex
# 326. 0.326Nd2Sn2O7        → Magnetic Order: Complex
# 327. 0.327CsMnF4          → Magnetic Order: FM
# 328. 0.328KMnF4           → Magnetic Order: Complex
# 329. 0.329RbMnF4          → Magnetic Order: AFM
# 330. 0.330ErGe3           → Magnetic Order: AFM
# 331. 0.331Fe2Mo3O8        → Magnetic Order: AFM
# 332. 0.332Co2Mo3O8        → Magnetic Order: AFM
# 333. 0.333Mn2Mo3O8        → Magnetic Order: AFM
# 334. 0.334CoF3            → Magnetic Order: AFM
# 335. 0.335FeF3            → Magnetic Order: AFM
# 336. 0.336NdFeO3          → Magnetic Order: AFM
# 337. 0.337NdFeO3          → Magnetic Order: Complex
# 338. 0.338Co2Mo3O8        → Magnetic Order: AFM
# 339. 0.339Nd2Hf2O7        → Magnetic Order: Complex
# 340. 0.340Nd2Zr2O7        → Magnetic Order: Complex
# 341. 0.341DyGe1.75        → Magnetic Order: AFM
# 342. 0.342Tb3Ge5          → Magnetic Order: Complex
# 343. 0.343TbGe2           → Magnetic Order: AFM
# 344. 0.344ErGe1.83        → Magnetic Order: AFM
# 345. 0.345Tb2C3           → Magnetic Order: AFM
# 346. 0.346Tb2ReC2         → Magnetic Order: AFM
# 347. 0.347Er2ReC2         → Magnetic Order: Complex
# 348. 0.348Bi2CuO4         → Magnetic Order: AFM
# 349. 0.349Nd2NiO4         → Magnetic Order: Complex
# 350. 0.350TbAlO3          → Magnetic Order: Complex
# 351. 0.351TbFeO3          → Magnetic Order: AFM
# 352. 0.352TbFeO3          → Magnetic Order: Complex
# 353. 0.353TbFeO3          → Magnetic Order: Complex
# 354. 0.354TbCrO3          → Magnetic Order: AFM
# 355. 0.355Mn2.85Ga1.15    → Magnetic Order: Complex
# 356. 0.356Mn2.85Ga1.15    → Magnetic Order: AFM
# 357. 0.357CaFe5O7         → Magnetic Order: Complex
# 358. 0.358CaFe5O7         → Magnetic Order: AFM
# 359. 0.359Mn2ScSbO6       → Magnetic Order: AFM
# 360. 0.360Mn2ScSbO6       → Magnetic Order: AFM
# 361. 0.361Sr3LiRuO6       → Magnetic Order: AFM
# 362. 0.362RbFeCl5(D2O)    → Magnetic Order: AFM
# 363. 0.363KFeCl5(D2O)     → Magnetic Order: AFM
# 364. 0.364SrCr2As2        → Magnetic Order: AFM
# 365. 0.365BaCr2As2        → Magnetic Order: AFM
# 366. 0.366BaCrFeAs2       → Magnetic Order: AFM
# 367. 0.367EuCr2As2        → Magnetic Order: AFM
# 368. 0.368(CH3NH3)(Co(COOH)3 → Magnetic Order: Complex
# 369. 0.369(CH3NH3)(Co(COOH)3 → Magnetic Order: Complex
# 370. 0.370NdMnO3          → Magnetic Order: Complex
# 371. 0.371NdMnO3          → Magnetic Order: Complex
# 372. 0.372DyCrO4          → Magnetic Order: AFM
# 373. 0.373La0.75Bi0.25Fe0.5Cr0.5O3 → Magnetic Order: AFM
# 374. 0.374YNi4Si          → Magnetic Order: FM
# 375. 0.375La2CoIrO6       → Magnetic Order: Complex
# 376. 0.376LaCaFeO4        → Magnetic Order: AFM
# 377. 0.377Mn3Ge           → Magnetic Order: Complex
# 378. 0.378UBi2            → Magnetic Order: AFM
# 379. 0.379SmFeO3          → Magnetic Order: AFM
# 380. 0.380SmFeO3          → Magnetic Order: AFM
# 381. 0.381Co6(OH)3(TeO3)4(OH)0.9(H20) → Magnetic Order: Complex
# 382. 0.382LiMnPO4         → Magnetic Order: AFM
# 383. 0.383LiCoPO4         → Magnetic Order: AFM
# 384. 0.384LiCoPO4         → Magnetic Order: AFM
# 385. 0.385LiCoPO4         → Magnetic Order: Complex
# 386. 0.386Fe3BO5          → Magnetic Order: AFM
# 387. 0.387Fe3BO5          → Magnetic Order: Complex
# 388. 0.388Co3Al2Si3O12    → Magnetic Order: Complex
# 389. 0.389Fe1.5Mn1.5BO5   → Magnetic Order: AFM
# 390. 0.390Y2SrCu0.6Co1.4O6.5 → Magnetic Order: AFM
# 391. 0.391Y2SrCu0.6Co1.4O6.5 → Magnetic Order: AFM
# 392. 0.392Fe3(PO4)2(OH)2  → Magnetic Order: AFM
# 393. 0.393Cu4(OH)6FBr     → Magnetic Order: Complex
# 394. 0.394Cu2CdB2O6       → Magnetic Order: Complex
# 395. 0.395MnPtGa          → Magnetic Order: FM
# 396. 0.396MnPtGa          → Magnetic Order: Complex
# 397. 0.397Mn3Si2Te6       → Magnetic Order: AFM
# 398. 0.398Ca2RuO4         → Magnetic Order: Complex
# 399. 0.399FeOOH           → Magnetic Order: AFM
# 400. 0.400Sr2Fe1.9Co0.1O5.5 → Magnetic Order: AFM
# 401. 0.401Sr4Fe4O11       → Magnetic Order: AFM
# 402. 0.402Sr4Fe4O11       → Magnetic Order: AFM
# 403. 0.403NdCo2           → Magnetic Order: FiM
# 404. 0.404Sr3NaRuO6       → Magnetic Order: AFM
# 405. 0.405CsCoF4          → Magnetic Order: AFM
# 406. 0.406GdNiSi3         → Magnetic Order: AFM
# 407. 0.407NdSi            → Magnetic Order: Complex
# 408. 0.408PrSi            → Magnetic Order: Complex
# 409. 0.409TmNi            → Magnetic Order: Complex
# 410. 0.410GdAlO3          → Magnetic Order: AFM
# 411. 0.411Tb5Ge4          → Magnetic Order: Complex
# 412. 0.412Tb5Ge4          → Magnetic Order: Complex
# 413. 0.413UGeSe           → Magnetic Order: AFM
# 414. 0.414AlFe2B2         → Magnetic Order: FM
# 415. 0.415EuFe2P2         → Magnetic Order: FM
# 416. 0.416LaCrO3          → Magnetic Order: AFM
# 417. 0.417LaCrO3          → Magnetic Order: AFM
# 418. 0.418K0.8Fe1.8Se2    → Magnetic Order: AFM
# 419. 0.419Er2Ge2O7        → Magnetic Order: Complex
# 420. 0.420Sr2LuRuO6       → Magnetic Order: AFM
# 421. 0.421EuMnSb2         → Magnetic Order: AFM
# 422. 0.422EuMnSb2         → Magnetic Order: Complex
# 423. 0.423EuMnSb2         → Magnetic Order: AFM
# 424. 0.424EuMnSb2         → Magnetic Order: Complex
# 425. 0.425Na2CoP2O7       → Magnetic Order: Complex
# 426. 0.426EuMnBi2         → Magnetic Order: AFM
# 427. 0.427Sm2Ti2O7        → Magnetic Order: Complex
# 428. 0.428BaMn2Si2O7      → Magnetic Order: AFM
# 429. 0.429CaCr0.86Fe3.14As3 → Magnetic Order: AFM
# 430. 0.430Yb3Pt4          → Magnetic Order: Complex
# 431. 0.431CuB2O4          → Magnetic Order: Complex
# 432. 0.432KMnF3           → Magnetic Order: AFM
# 433. 0.433KMnF3           → Magnetic Order: AFM
# 434. 0.434K2ReI6          → Magnetic Order: AFM
# 435. 0.435Pb5Fe3TiO11Cl   → Magnetic Order: AFM
# 436. 0.436TbNi4Si         → Magnetic Order: FM
# 437. 0.437Ho3NiGe2        → Magnetic Order: Complex
# 438. 0.438Pr3CoGe2        → Magnetic Order: Complex
# 439. 0.439Tb3NiGe2        → Magnetic Order: AFM
# 440. 0.440SrCuTe2O6       → Magnetic Order: Complex
# 441. 0.441Fe4Nb2O9        → Magnetic Order: AFM
# 442. 0.442Fe4Nb2O9        → Magnetic Order: AFM
# 443. 0.443Fe4Nb2O9        → Magnetic Order: AFM
# 444. 0.444YbCl3           → Magnetic Order: AFM
# 445. 0.445MnCoGe          → Magnetic Order: FiM
# 446. 0.446MnCoGeB0.05     → Magnetic Order: Complex
# 447. 0.447MnCoGeB0.05     → Magnetic Order: FiM
# 448. 0.448Ce4Ge3          → Magnetic Order: AFM
# 449. 0.449Tb2Pt           → Magnetic Order: Complex
# 450. 0.450Nd5Ge4          → Magnetic Order: Complex
# 451. 0.451DyRuAsO         → Magnetic Order: AFM
# 452. 0.452TbRuAsO         → Magnetic Order: AFM
# 453. 0.453DyCoSi2         → Magnetic Order: AFM
# 454. 0.454PrScSb          → Magnetic Order: AFM
# 455. 0.455RbFeO2          → Magnetic Order: AFM
# 456. 0.456RbFeO2          → Magnetic Order: AFM
# 457. 0.457CsFeO2          → Magnetic Order: AFM
# 458. 0.458CsFeO2          → Magnetic Order: AFM
# 459. 0.459KFeO2           → Magnetic Order: AFM
# 460. 0.460KFeO2           → Magnetic Order: AFM
# 461. 0.461CoRh2O4         → Magnetic Order: AFM
# 462. 0.462MnAl2O4         → Magnetic Order: AFM
# 463. 0.463Co3O4           → Magnetic Order: AFM
# 464. 0.464BaMn2P2         → Magnetic Order: AFM
# 465. 0.465HoCr2Si2        → Magnetic Order: AFM
# 466. 0.466ThCr2Si2        → Magnetic Order: AFM
# 467. 0.467TbPO4           → Magnetic Order: AFM
# 468. 0.468ErB4            → Magnetic Order: AFM
# 469. 0.469TbB4            → Magnetic Order: AFM
# 470. 0.470BaMn2Sb2        → Magnetic Order: AFM
# 471. 0.471Ba2Mn3Sb2O2     → Magnetic Order: AFM
# 472. 0.472LaMn2Si2        → Magnetic Order: AFM
# 473. 0.473LaMn2Si2        → Magnetic Order: Complex
# 474. 0.474EuMn2Ge2        → Magnetic Order: AFM
# 475. 0.475Sr2TbIrO6       → Magnetic Order: AFM
# 476. 0.476Cs2[FeCl5(H2O)] → Magnetic Order: AFM
# 477. 0.477Mn4Ta2O9        → Magnetic Order: AFM
# 478. 0.478SmCrO3          → Magnetic Order: Complex
# 479. 0.479SmCrO3          → Magnetic Order: Complex
# 480. 0.480HoNi            → Magnetic Order: Complex
# 481. 0.481HoNi            → Magnetic Order: Complex
# 482. 0.482SrMn2As2        → Magnetic Order: AFM
# 483. 0.483YbMn2Sb2        → Magnetic Order: AFM
# 484. 0.484U2N2S           → Magnetic Order: AFM
# 485. 0.485U2N2Se          → Magnetic Order: AFM
# 486. 0.486ErCr2Si2        → Magnetic Order: AFM
# 487. 0.487ErCr2Si2        → Magnetic Order: Complex
# 488. 0.488YbMnO3          → Magnetic Order: Complex
# 489. 0.489YbMnO3          → Magnetic Order: Complex
# 490. 0.490YbMnO3          → Magnetic Order: Complex
# 491. 0.491NdB4            → Magnetic Order: Complex
# 492. 0.492NdB4            → Magnetic Order: Complex
# 493. 0.493Ho(Co0.667Ga0.333)2 → Magnetic Order: FM
# 494. 0.494Er(Co0.667Ga0.333)2 → Magnetic Order: FM
# 495. 0.495LaMn2Si2        → Magnetic Order: Complex
# 496. 0.496LaMn2Si2        → Magnetic Order: Complex
# 497. 0.497LaMn2Si2        → Magnetic Order: Complex
# 498. 0.498LaMn2Si2        → Magnetic Order: AFM
# 499. 0.499UCr2Si2C        → Magnetic Order: AFM
# 500. 0.500Ca2FeMn0.5W0.5O6 → Magnetic Order: AFM
# 501. 0.501LiFe2F6         → Magnetic Order: AFM
# 502. 0.502La2Ni1.19Os0.81O6 → Magnetic Order: Complex
# 503. 0.503K1.62Fe4O6.62(OH)0.38 → Magnetic Order: AFM
# 504. 0.504NaCrSi2O6       → Magnetic Order: AFM
# 505. 0.505Pb2VO(PO4)2     → Magnetic Order: AFM
# 506. 0.506Cs2Cu3SnF12     → Magnetic Order: Complex
# 507. 0.507Mn4Nb2O9        → Magnetic Order: AFM
# 508. 0.508FeMnO3          → Magnetic Order: AFM
# 509. 0.509BaFe12O19       → Magnetic Order: AFM
# 510. 0.510Mn2NiReO6       → Magnetic Order: Complex
# 511. 0.511Co4Ta2O9        → Magnetic Order: Complex
# 512. 0.512Mn3As2          → Magnetic Order: AFM
# 513. 0.513YRuO3           → Magnetic Order: AFM
# 514. 0.514CoFe3O5         → Magnetic Order: AFM
# 515. 0.515CoFe3O5         → Magnetic Order: Complex
# 516. 0.516BaMg2Fe16O27    → Magnetic Order: AFM
# 517. 0.517BaCo2Fe16O27    → Magnetic Order: AFM
# 518. 0.518TbCr2Si2        → Magnetic Order: AFM
# 519. 0.519HoCr2Si2        → Magnetic Order: AFM
# 520. 0.520TbCoO3          → Magnetic Order: Complex
# 521. 0.521DyCoO3          → Magnetic Order: Complex
# 522. 0.522La2O3FeMnSe2    → Magnetic Order: AFM
# 523. 0.523CaMn2Sb2        → Magnetic Order: AFM
# 524. 0.524MnPSe3          → Magnetic Order: AFM
# 525. 0.525NaCeO2          → Magnetic Order: AFM
# 526. 0.526Mn4Ta2O9        → Magnetic Order: AFM
# 527. 0.527Er2Si2O7        → Magnetic Order: AFM
# 528. 0.528CrSb            → Magnetic Order: AFM
# 529. 0.529Co4Nb2O9        → Magnetic Order: Complex
# 530. 0.530SrCuTe2O6       → Magnetic Order: Complex
# 531. 0.531Sr0.7Tb0.3CoO2.9 → Magnetic Order: AFM
# 532. 0.532Sr0.7Ho0.3CoO2.7 → Magnetic Order: AFM
# 533. 0.533Sr0.7Er0.3CoO2.8 → Magnetic Order: AFM
# 534. 0.534Tb0.55Sr0.45MnO3 → Magnetic Order: Complex
# 535. 0.535Tb0.55Sr0.45MnO3 → Magnetic Order: Complex
# 536. 0.536Tb0.55Sr0.45MnO3 → Magnetic Order: Complex
# 537. 0.537CaMn0.7Co1.3ReO6 → Magnetic Order: AFM
# 538. 0.538CaMn1.2Ni0.8ReO6 → Magnetic Order: FiM
# 539. 0.539Mn2Fe0.8Mo1.2O6 → Magnetic Order: AFM
# 540. 0.540Mn2Fe0.8Mo1.2O6 → Magnetic Order: Complex
# 541. 0.541Mn2FeReO6       → Magnetic Order: AFM
# 542. 0.542Mn2FeReO6       → Magnetic Order: AFM
# 543. 0.543Mn2FeReO6       → Magnetic Order: AFM
# 544. 0.544Mn2FeReO6       → Magnetic Order: Complex
# 545. 0.545Mn2FeReO6       → Magnetic Order: Complex
# 546. 0.546Mn2FeReO6       → Magnetic Order: AFM
# 547. 0.547Mn2FeReO6       → Magnetic Order: AFM
# 548. 0.548Mn2FeReO6       → Magnetic Order: Complex
# 549. 0.549Mn2FeReO6       → Magnetic Order: Complex
# 550. 0.550Mn3ReO6         → Magnetic Order: Complex
# 551. 0.551Mn3ReO6         → Magnetic Order: Complex
# 552. 0.552Pb2MnO4         → Magnetic Order: Complex
# 553. 0.553K2ReI6          → Magnetic Order: AFM
# 554. 0.554Co2MnSi         → Magnetic Order: FiM
# 555. 0.555Ho0.05Bi0.95FeO3 → Magnetic Order: AFM
# 556. 0.556Ho0.1Bi0.9FeO3  → Magnetic Order: AFM
# 557. 0.557Ho0.15Bi0.85FeO3 → Magnetic Order: Complex
# 558. 0.558Ho0.2Bi0.8FeO3  → Magnetic Order: Complex
# 559. 0.559Ho0.15Bi0.85FeO3 → Magnetic Order: AFM
# 560. 0.560Ho0.2Bi0.8FeO3  → Magnetic Order: AFM
# 561. 0.561NdNiGe2         → Magnetic Order: FM
# 562. 0.562Ce2Ni3Ge5       → Magnetic Order: AFM
# 563. 0.563Ce2Ni3Ge5       → Magnetic Order: AFM
# 564. 0.564U2Rh3Si5        → Magnetic Order: Complex
# 565. 0.565Ce2Ni3Ge5       → Magnetic Order: Complex
# 566. 0.566TbNiGe2         → Magnetic Order: AFM
# 567. 0.567HoNi0.64Ge2     → Magnetic Order: AFM
# 568. 0.568TbNi0.4Ge2      → Magnetic Order: AFM
# 569. 0.569TbCu0.4Ge2      → Magnetic Order: AFM
# 570. 0.570Li0.5FeCr1.5O4  → Magnetic Order: AFM
# 571. 0.571CoSO4           → Magnetic Order: Complex
# 572. 0.572Na2NiCrF7       → Magnetic Order: Complex
# 573. 0.573Na2NiCrF7       → Magnetic Order: Complex
# 574. 0.574MnFeF5(H2O)2    → Magnetic Order: Complex
# 575. 0.575ZnFeF5(H2O)2    → Magnetic Order: AFM
# 576. 0.576Cr2F5           → Magnetic Order: Complex
# 577. 0.577BaMnFeF7        → Magnetic Order: AFM
# 578. 0.578NaBaFe2F9       → Magnetic Order: AFM
# 579. 0.579Na2NiFeF7       → Magnetic Order: Complex
# 580. 0.580Na2NiFeF7       → Magnetic Order: Complex
# 581. 0.581FeF3            → Magnetic Order: AFM
# 582. 0.582Fe3F8(H2O)2     → Magnetic Order: AFM
# 583. 0.583Fe2F5(H2O)2     → Magnetic Order: Complex
# 584. 0.584Fe2F5(H2O)2     → Magnetic Order: Complex
# 585. 0.585YbCl3           → Magnetic Order: AFM
# 586. 0.586YCrO3           → Magnetic Order: AFM
# 587. 0.587TmCrO3          → Magnetic Order: AFM
# 588. 0.588PrCrO3          → Magnetic Order: Complex
# 589. 0.589NdCrO3          → Magnetic Order: Complex
# 590. 0.590ErCrO3          → Magnetic Order: Complex
# 591. 0.591ErCrO3          → Magnetic Order: AFM
# 592. 0.592DyCrO3          → Magnetic Order: AFM
# 593. 0.593UPSe            → Magnetic Order: FM
# 594. 0.594UAsS            → Magnetic Order: FM
# 595. 0.595UPTe            → Magnetic Order: FM
# 596. 0.596UAsTe           → Magnetic Order: FM
# 597. 0.597MnBi8Te13       → Magnetic Order: FM
# 598. 0.598AlCr2           → Magnetic Order: AFM
# 599. 0.599CaMnSi          → Magnetic Order: AFM
# 600. 0.600CaMnSi          → Magnetic Order: AFM
# 601. 0.601CaMnGe          → Magnetic Order: AFM
# 602. 0.602CaMnGe          → Magnetic Order: Unknown
# 603. 0.603CaMn2Ge2        → Magnetic Order: AFM
# 604. 0.604CaMn2Ge2        → Magnetic Order: AFM
# 605. 0.605BaMn2Ge2        → Magnetic Order: AFM
# 606. 0.606BaMn2Ge2        → Magnetic Order: AFM
# 607. 0.607RuO2            → Magnetic Order: AFM
# 608. 0.608PrMnO3          → Magnetic Order: AFM
# 609. 0.609NdMnO3          → Magnetic Order: AFM
# 610. 0.610Pr0.95K0.05MnO3 → Magnetic Order: Complex
# 611. 0.611BaMnSb2         → Magnetic Order: AFM
# 612. 0.612Cu2OSO4         → Magnetic Order: Complex
# 613. 0.613FeCr2S4         → Magnetic Order: AFM
# 614. 0.614FeCr2S4         → Magnetic Order: AFM
# 615. 0.615FeCr2S4         → Magnetic Order: AFM
# 616. 0.616HoB2            → Magnetic Order: FM
# 617. 0.617KMnSb           → Magnetic Order: AFM
# 618. 0.618KMnBi           → Magnetic Order: AFM
# 619. 0.619LaMnAsO         → Magnetic Order: AFM
# 620. 0.620NdMnAsO         → Magnetic Order: AFM
# 621. 0.621NdMnAsO         → Magnetic Order: AFM
# 622. 0.622NdMnAsO         → Magnetic Order: AFM
# 623. 0.623NdMnAsO         → Magnetic Order: AFM
# 624. 0.624LaMnAsO         → Magnetic Order: AFM
# 625. 0.625U2Pd2In         → Magnetic Order: Complex
# 626. 0.626NaMnP           → Magnetic Order: AFM
# 627. 0.627NaMnP           → Magnetic Order: AFM
# 628. 0.628NaMnP           → Magnetic Order: AFM
# 629. 0.629NaMnAs          → Magnetic Order: AFM
# 630. 0.630NaMnAs          → Magnetic Order: AFM
# 631. 0.631NaMnSb          → Magnetic Order: AFM
# 632. 0.632NaMnSb          → Magnetic Order: AFM
# 633. 0.633KFeS2           → Magnetic Order: AFM
# 634. 0.634NaMnBi          → Magnetic Order: AFM
# 635. 0.635NaMnBi          → Magnetic Order: AFM
# 636. 0.636RbFeS2          → Magnetic Order: AFM
# 637. 0.637KFeSe2          → Magnetic Order: Unknown
# 638. 0.638RbFeSe2         → Magnetic Order: AFM
# 639. 0.639Mn2Au           → Magnetic Order: AFM
# 640. 0.640Mn2Au           → Magnetic Order: AFM
# 641. 0.641Mn3Ga           → Magnetic Order: Complex
# 642. 0.642LaMnO3          → Magnetic Order: AFM
# 643. 0.643La0.95Ca0.05MnO3 → Magnetic Order: Complex
# 644. 0.644La0.95Ba0.05MnO3 → Magnetic Order: Complex
# 645. 0.645La0.95Ba0.05Mn0.95Ti0.05O3 → Magnetic Order: AFM
# 646. 0.646La0.90Ba0.10Mn0.90Ti0.10O3 → Magnetic Order: Complex
# 647. 0.647La0.875Ba0.125Mn0.875Ti0.125O3 → Magnetic Order: Complex
# 648. 0.648(Ho0.8Mn0.2)MnO3 → Magnetic Order: AFM
# 649. 0.649(Ho0.8Mn0.2)MnO3 → Magnetic Order: Complex
# 650. 0.650Er2Si2O7        → Magnetic Order: AFM
# 651. 0.651Er3Cu4Sn4       → Magnetic Order: AFM
# 652. 0.652HoMnO3          → Magnetic Order: Complex
# 653. 0.653HoMn0.99Fe0.01O3 → Magnetic Order: Complex
# 654. 0.654HoMn0.95Fe0.05O3 → Magnetic Order: Complex
# 655. 0.655HoMn0.9Fe0.1O3  → Magnetic Order: Complex
# 656. 0.656NdMn2Ge2        → Magnetic Order: Complex
# 657. 0.657PrMn2Ge2        → Magnetic Order: Complex
# 658. 0.658BaCuTe2O6       → Magnetic Order: Complex
# 659. 0.659NdMn0.8Fe0.2O3  → Magnetic Order: Complex
# 660. 0.660NdMn0.8Fe0.2O3  → Magnetic Order: Complex
# 661. 0.661(Lu0.6Mn0.4)MnO3 → Magnetic Order: Complex
# 662. 0.662Mn3Sn2          → Magnetic Order: FiM
# 663. 0.663Mn3Sn2          → Magnetic Order: Complex
# 664. 0.664Mn3Sn2          → Magnetic Order: Complex
# 665. 0.665CeMnSbO         → Magnetic Order: AFM
# 666. 0.666CeMnSbO         → Magnetic Order: AFM
# 667. 0.667LaMnSbO         → Magnetic Order: AFM
# 668. 0.668PrMnSbO         → Magnetic Order: AFM
# 669. 0.669Sr2YbRuO6       → Magnetic Order: AFM
# 670. 0.670Sr2YbRuO6       → Magnetic Order: AFM
# 671. 0.671Sr2TmRuO6       → Magnetic Order: AFM
# 672. 0.672CaCu3Fe2Sb2O12  → Magnetic Order: AFM
# 673. 0.673MnFe4Si3        → Magnetic Order: FM
# 674. 0.674MnFe4Si3        → Magnetic Order: FiM
# 675. 0.675MnFe4Si3        → Magnetic Order: FiM
# 676. 0.676Nd0.95Sr0.05CrO3 → Magnetic Order: Complex
# 677. 0.677Nd0.9Sr0.1CrO3  → Magnetic Order: Complex
# 678. 0.678Nd0.85Sr0.15CrO3 → Magnetic Order: Complex
# 679. 0.679TbCr0.5Mn0.5O3  → Magnetic Order: AFM
# 680. 0.680Bi0.8La0.2Fe0.5Mn0.5O3 → Magnetic Order: AFM
# 681. 0.681Ce4Sb3          → Magnetic Order: AFM
# 682. 0.682Ca2FeOsO6       → Magnetic Order: AFM
# 683. 0.683SrCaFeOsO6      → Magnetic Order: AFM
# 684. 0.684TbPt            → Magnetic Order: Complex
# 685. 0.685ErPt            → Magnetic Order: Complex
# 686. 0.686HoPt            → Magnetic Order: Complex
# 687. 0.687DyPt            → Magnetic Order: Complex
# 688. 0.688TmPt            → Magnetic Order: Complex
# 689. 0.689PrPt            → Magnetic Order: FM
# 690. 0.690NdPt            → Magnetic Order: FM
# 691. 0.691CaCo1.86As2     → Magnetic Order: AFM
# 692. 0.692Ba4Ru3O10       → Magnetic Order: AFM
# 693. 0.693Ba4Ru3O10       → Magnetic Order: AFM
# 694. 0.694Bi2CuO4         → Magnetic Order: AFM
# 695. 0.695Bi2CuO4         → Magnetic Order: AFM
# 696. 0.696SmCrO3          → Magnetic Order: Complex
# 697. 0.697SmCrO3          → Magnetic Order: Complex
# 698. 0.698SmCrO3          → Magnetic Order: Complex
# 699. 0.699LiMn6Sn6        → Magnetic Order: FM
# 700. 0.700TbMn6Sn6        → Magnetic Order: AFM
# 701. 0.701TbMn6Sn6        → Magnetic Order: AFM
# 702. 0.702TbMn6Sn6        → Magnetic Order: AFM
# 703. 0.703HoMn6Sn6        → Magnetic Order: AFM
# 704. 0.704HoMn6Sn6        → Magnetic Order: AFM
# 705. 0.705HoMn6Sn6        → Magnetic Order: AFM
# 706. 0.706Tb2Ir3Ga9       → Magnetic Order: AFM
# 707. 0.707Tb2Ir3Ga9       → Magnetic Order: Complex
# 708. 0.708CrNb4S8         → Magnetic Order: AFM
# 709. 0.709MnNb4S8         → Magnetic Order: FM
# 710. 0.710MnNb3S6         → Magnetic Order: FM
# 711. 0.711MnTa4S8         → Magnetic Order: FM
# 712. 0.712VNb3S6          → Magnetic Order: AFM
# 713. 0.713NiFe2O4         → Magnetic Order: AFM
# 714. 0.714Li2Ni(SO4)2     → Magnetic Order: AFM
# 715. 0.715HoCrWO6         → Magnetic Order: Complex
# 716. 0.716HoCrWO6         → Magnetic Order: Complex
# 717. 0.717Pr0.5Sr0.4Ba0.1CoO3 → Magnetic Order: FM
# 718. 0.718Pr0.5Sr0.4Ba0.1CoO3 → Magnetic Order: FM
# 719. 0.719Yb0.42Sc0.58FeO3 → Magnetic Order: Complex
# 720. 0.720Yb0.42Sc0.58FeO3 → Magnetic Order: Complex
# 721. 0.721Yb0.42Sc0.58FeO3 → Magnetic Order: Complex
# 722. 0.722Mn4Nb2O9        → Magnetic Order: AFM
# 723. 0.723YbCl3           → Magnetic Order: AFM
# 724. 0.724BaCoSiO4        → Magnetic Order: Complex
# 725. 0.725Ce5TeO8         → Magnetic Order: AFM
# 726. 0.726CsMn2F6         → Magnetic Order: Complex
# 727. 0.727CsMn2F6         → Magnetic Order: Complex
# 728. 0.728MoP3SiO11       → Magnetic Order: AFM
# 729. 0.729ErNi4B          → Magnetic Order: FM
# 730. 0.730TbNi4B          → Magnetic Order: FM
# 731. 0.731HoNi4B          → Magnetic Order: FM
# 732. 0.732SrRuO3          → Magnetic Order: FM
# 733. 0.733AgRuO3          → Magnetic Order: AFM
# 734. 0.734Mn3Ta2O8        → Magnetic Order: AFM
# 735. 0.735LaBaMn2O5       → Magnetic Order: AFM
# 736. 0.736LaBaMn2O6       → Magnetic Order: FM
# 737. 0.737LaBaMn2O6       → Magnetic Order: FM
# 738. 0.738LaBaMn2O6       → Magnetic Order: FM
# 739. 0.739YBaMn2O5        → Magnetic Order: AFM
# 740. 0.740Dy3Ga5O12       → Magnetic Order: Complex
# 741. 0.741Er3Ga5O12       → Magnetic Order: Complex
# 742. 0.742Tb3Ga5O12       → Magnetic Order: Complex
# 743. 0.743Ho3Al5O12       → Magnetic Order: Complex
# 744. 0.744Tb3Al5O12       → Magnetic Order: Complex
# 745. 0.745Ho3Ga5O12       → Magnetic Order: Complex
# 746. 0.746Tb3Ga5O12       → Magnetic Order: Complex
# 747. 0.747Ba3CoIr2O9      → Magnetic Order: AFM
# 748. 0.748Ba3NiRu2O9      → Magnetic Order: AFM
# 749. 0.749Ba3CoRu2O9      → Magnetic Order: AFM
# 750. 0.750Ba3CoRu2O9      → Magnetic Order: AFM
# 751. 0.751Ca2YZr2Fe3O12   → Magnetic Order: Complex
# 752. 0.752Ca2YZr2Fe3O12   → Magnetic Order: Complex
# 753. 0.753Ca2LaZr2Fe3O12  → Magnetic Order: Complex
# 754. 0.754Ca2LaZr2Fe3O12  → Magnetic Order: Unknown
# 755. 0.755Mn2SeO3F2       → Magnetic Order: AFM
# 756. 0.756GaV4S8          → Magnetic Order: Complex
# 757. 0.757CeFeO3          → Magnetic Order: AFM
# 758. 0.758CeFeO3          → Magnetic Order: AFM
# 759. 0.759CeFeO3          → Magnetic Order: AFM
# 760. 0.760FeOHSO4         → Magnetic Order: AFM
# 761. 0.761SrFe2Se2O       → Magnetic Order: AFM
# 762. 0.762SrFe2S2O        → Magnetic Order: Complex
# 763. 0.763Mn5(PO4)2(PO3(OH))2(HOH)4 → Magnetic Order: Complex
# 764. 0.764Mn5(PO4)2(PO3(OH))2(HOH)4 → Magnetic Order: Complex
# 765. 0.765Mn5(PO4)2(PO3(OH))2(HOH)4 → Magnetic Order: Complex
# 766. 0.766YbMnSb2         → Magnetic Order: AFM
# 767. 0.767SrMnSb2         → Magnetic Order: FM
# 768. 0.768SrMnSb2         → Magnetic Order: AFM
# 769. 0.769YbMnBi2         → Magnetic Order: AFM
# 770. 0.770Fe2Co2Nb2O9     → Magnetic Order: AFM
# 771. 0.771PrMnSi2         → Magnetic Order: FM
# 772. 0.772PrMnSi2         → Magnetic Order: FM
# 773. 0.773NdMnSi2         → Magnetic Order: Complex
# 774. 0.774NdMnSi2         → Magnetic Order: FM
# 775. 0.775NdMnSi2         → Magnetic Order: FM
# 776. 0.776CeMnSi2         → Magnetic Order: AFM
# 777. 0.777CeMnSi2         → Magnetic Order: FM
# 778. 0.778LaMnSi2         → Magnetic Order: FM
# 779. 0.779LaMnSi2         → Magnetic Order: FM
# 780. 0.780LaMnSi2         → Magnetic Order: FM
# 781. 0.781CeMnSi2         → Magnetic Order: AFM
# 782. 0.782NdScO3          → Magnetic Order: Complex
# 783. 0.783NdInO3          → Magnetic Order: Complex
# 784. 0.784NdCoO3          → Magnetic Order: AFM
# 785. 0.785NdVO3           → Magnetic Order: Complex
# 786. 0.786NdVO3           → Magnetic Order: AFM
# 787. 0.787YVO3            → Magnetic Order: AFM
# 788. 0.788YVO3            → Magnetic Order: Complex
# 789. 0.789CeCuSi          → Magnetic Order: FM
# 790. 0.790Sr2DyRuO6       → Magnetic Order: AFM
# 791. 0.791Sr2TbRuO6       → Magnetic Order: AFM
# 792. 0.792Sr2HoRuO6       → Magnetic Order: AFM
# 793. 0.793Sr2HoRuO6       → Magnetic Order: AFM
# 794. 0.794Sr2HoRuO6       → Magnetic Order: AFM
# 795. 0.795Sr2YRuO6        → Magnetic Order: AFM
# 796. 0.796Ca2NiOsO6       → Magnetic Order: AFM
# 797. 0.797SmBaMn2O5       → Magnetic Order: AFM
# 798. 0.798MnPd2           → Magnetic Order: AFM
# 799. 0.799Sr2Co2O5        → Magnetic Order: AFM
# 800. 0.800MnTe            → Magnetic Order: AFM
# 801. 0.801Tl3Fe2S4        → Magnetic Order: AFM
# 802. 0.802CuFeS2          → Magnetic Order: AFM
# 803. 0.803NbMnP           → Magnetic Order: Complex
# 804. 0.804MoP3SiO11       → Magnetic Order: AFM
# 805. 0.805DyBaCuO5        → Magnetic Order: Complex
# 806. 0.806Fe2Se2O7        → Magnetic Order: Complex
# 807. 0.807Fe2Se2O7        → Magnetic Order: Complex
# 808. 0.808Fe2Se2O7        → Magnetic Order: Complex
# 809. 0.809Fe2WO6          → Magnetic Order: Complex
# 810. 0.810Fe2WO6          → Magnetic Order: Complex
# 811. 0.811Fe2WO6          → Magnetic Order: AFM
# 812. 0.812Fe2WO6          → Magnetic Order: Complex
# 813. 0.813Fe2WO6          → Magnetic Order: AFM
# 814. 0.814Fe2WO6          → Magnetic Order: AFM
# 815. 0.815MnNb2O6         → Magnetic Order: AFM
# 816. 0.816MnTa2O6         → Magnetic Order: AFM
# 817. 0.817Mn(Nb0.5Ta0.5)2O6 → Magnetic Order: Complex
# 818. 0.818MnTa2O6         → Magnetic Order: Complex
# 819. 0.819MnNb2O6         → Magnetic Order: Complex
# 820. 0.820Bi0.85Ca0.15Fe0.55Mn0.45O3 → Magnetic Order: AFM
# 821. 0.821SrGd2O4         → Magnetic Order: AFM
# 822. 0.822Nd2ScNbO7       → Magnetic Order: Complex
# 823. 0.823Sr2MnGaO5       → Magnetic Order: AFM
# 824. 0.824Sr2MnGaO5.5     → Magnetic Order: AFM
# 825. 0.825Ca2MnGaO5       → Magnetic Order: AFM
# 826. 0.826MnTeLi0.003     → Magnetic Order: AFM
# 827. 0.827Na2MnPO4F       → Magnetic Order: AFM
# 828. 0.828Na2MnPO4F       → Magnetic Order: AFM
# 829. 0.829Na2MnPO4F       → Magnetic Order: AFM
# 830. 0.830Na2MnPO4F       → Magnetic Order: AFM
# 831. 0.831BaCaFe4O7       → Magnetic Order: Complex
# 832. 0.832CeAuGe          → Magnetic Order: FM
# 833. 0.833CeCuGe          → Magnetic Order: FM
# 834. 0.834CrSbSe3         → Magnetic Order: FM
# 835. 0.835Dy5Pd2In4       → Magnetic Order: AFM
# 836. 0.836DyFeO3          → Magnetic Order: AFM
# 837. 0.837DyFeO3          → Magnetic Order: AFM
# 838. 0.838DyFeO3          → Magnetic Order: AFM
# 839. 0.839DyFeO3          → Magnetic Order: AFM
# 840. 0.840DyFeO3          → Magnetic Order: AFM
# 841. 0.841DyFeO3          → Magnetic Order: AFM
# 842. 0.842DyAlO3          → Magnetic Order: Complex
# 843. 0.843SrZn2Fe16O27    → Magnetic Order: AFM
# 844. 0.844SrNi2Fe16O27    → Magnetic Order: AFM
# 845. 0.845SrMg2Fe16O27    → Magnetic Order: AFM
# 846. 0.846SrCo2Fe16O27    → Magnetic Order: AFM
# 847. 0.847Er5Pd2In4       → Magnetic Order: Complex
# 848. 0.848Er5Pd2In4       → Magnetic Order: Complex
# 849. 0.849Er5Pd2In4       → Magnetic Order: Complex
# 850. 0.850Er5Pd2In4       → Magnetic Order: Complex
# 851. 0.851C7H14NFeCl4     → Magnetic Order: Complex
# 852. 0.852HoVO3           → Magnetic Order: Complex
# 853. 0.853HoVO3           → Magnetic Order: Complex
# 854. 0.854Gd2Pt2O7        → Magnetic Order: Complex
# 855. 0.855Mn2Sb           → Magnetic Order: AFM
# 856. 0.856Tm2Fe17         → Magnetic Order: AFM
# 857. 0.857Tm2Fe17         → Magnetic Order: AFM
# 858. 0.858Tm2Fe17         → Magnetic Order: FM
# 859. 0.859YCo3            → Magnetic Order: AFM
# 860. 0.860Co3Sn2S2        → Magnetic Order: FM
# 861. 0.861Co3Sn2S2        → Magnetic Order: FM
# 862. 0.862Eu2Ir2O7        → Magnetic Order: Complex
# 863. 0.863EuCd2As2        → Magnetic Order: FM
# 864. 0.864La2NiIrO6       → Magnetic Order: Complex
# 865. 0.865Nd2NiIrO6       → Magnetic Order: Complex
# 866. 0.866Pr2NiIrO6       → Magnetic Order: Complex
# 867. 0.867Nd2NiIrO6       → Magnetic Order: AFM
# 868. 0.868Pr2NiIrO6       → Magnetic Order: Complex
# 869. 0.869Pr2NiIrO6       → Magnetic Order: Complex
# 870. 0.870Pr2NiIrO6       → Magnetic Order: Complex
# 871. 0.871Pr2NiIrO6       → Magnetic Order: Complex
# 872. 0.872Pr2NiIrO6       → Magnetic Order: Complex
# 873. 0.873Pr2NiIrO6       → Magnetic Order: Complex
# 874. 0.874Nd2NiIrO6       → Magnetic Order: Complex
# 875. 0.875Nd2NiIrO6       → Magnetic Order: Complex
# 876. 0.876La2ZnIrO6       → Magnetic Order: Complex
# 877. 0.877Nd2ZnIrO6       → Magnetic Order: Complex
# 878. 0.878Nd2ZnIrO6       → Magnetic Order: Complex
# 879. 0.879Nd2ZnIrO6       → Magnetic Order: Complex
# 880. 0.880CdCu3(OH)6(NO3)2H2O → Magnetic Order: Complex
# 881. 0.881CuMnAs          → Magnetic Order: AFM
# 882. 0.882Bi0.85Ca0.15Fe0.55Mn0.45O3 → Magnetic Order: AFM
# 883. 0.883NaCo2(SeO3)2(OH) → Magnetic Order: Complex
# 884. 0.884Mn1.15Co1.85O4  → Magnetic Order: Complex
# 885. 0.885Mn1.17Co1.60Cu0.23O4 → Magnetic Order: AFM
# 886. 0.886SnCo2O4         → Magnetic Order: AFM
# 887. 0.887MnCo2O4         → Magnetic Order: AFM
# 888. 0.888Mn0.6Co2.4O4    → Magnetic Order: AFM
# 889. 0.889Mn0.8Co2.2O4    → Magnetic Order: AFM
# 890. 0.890Mn1.2Co1.8O4    → Magnetic Order: AFM
# 891. 0.891CuCr2O4         → Magnetic Order: Complex
# 892. 0.892NiCr2O4         → Magnetic Order: AFM
# 893. 0.893NiCr2O4         → Magnetic Order: AFM
# 894. 0.894Ni0.85Cu0.15Cr2O4 → Magnetic Order: Complex
# 895. 0.895NiCr2O4         → Magnetic Order: AFM
# 896. 0.896NiCrO4          → Magnetic Order: AFM
# 897. 0.897TbMn2Ge2        → Magnetic Order: AFM
# 898. 0.898Mn3IrSi         → Magnetic Order: Complex
# 899. 0.899Mn3IrGe         → Magnetic Order: Complex
# 900. 0.900Mn3CoGe         → Magnetic Order: Complex
# 901. 0.901La0.3Y0.7Mn2Ge2 → Magnetic Order: Complex
# 902. 0.902DyMn2Ge2        → Magnetic Order: AFM
# 903. 0.903Pr2PdGe6        → Magnetic Order: Complex
# 904. 0.904Nd2PdGe6        → Magnetic Order: AFM
# 905. 0.905Tb2PdGe6        → Magnetic Order: Unknown
# 906. 0.906Dy2PdGe6        → Magnetic Order: Unknown
# 907. 0.907Ho2PdGe6        → Magnetic Order: Complex
# 908. 0.908Tb2PtGe6        → Magnetic Order: Complex
# 909. 0.909Er2PtGe6        → Magnetic Order: AFM
# 910. 0.910TbNiSi2         → Magnetic Order: AFM
# 911. 0.911Tb5Pd2In4       → Magnetic Order: FiM
# 912. 0.912Ho5Ni2In4       → Magnetic Order: Complex
# 913. 0.913Ho5Ni2In4       → Magnetic Order: Complex
# 914. 0.914Tb5Ni2In4       → Magnetic Order: FiM
# 915. 0.915Tb5Ni2In4       → Magnetic Order: Complex
# 916. 0.916Cd2Os2O7        → Magnetic Order: Complex
# 917. 0.917Sr2ScOsO6       → Magnetic Order: AFM
# 918. 0.918Ag2RuO4         → Magnetic Order: Complex
# 919. 0.919EuMnBi2         → Magnetic Order: AFM
# 920. 0.920ThMnPN          → Magnetic Order: AFM
# 921. 0.921ThMnPN          → Magnetic Order: AFM
# 922. 0.922ThMnAsN         → Magnetic Order: AFM
# 923. 0.923ThMnAsN         → Magnetic Order: AFM
# 924. 0.924RbRuO4          → Magnetic Order: Complex
# 925. 0.925Au70Si17Tb13    → Magnetic Order: Complex
# 926. 0.926Pr2PdGe6        → Magnetic Order: Complex
# 927. 0.927Nd2PdGe6        → Magnetic Order: AFM
# 928. 0.928Dy2PdGe6        → Magnetic Order: Complex
# 929. 0.929Tb2PdGe6        → Magnetic Order: Complex
# 930. 0.930Ho2PdGe6        → Magnetic Order: Complex
# 931. 0.931Tb2PtGe6        → Magnetic Order: Complex
# 932. 0.932Er2PtGe6        → Magnetic Order: AFM
# 933. 0.933Na2RuO4         → Magnetic Order: AFM
# 934. 0.934Sr2NiTeO6       → Magnetic Order: AFM
# 935. 0.935Sr2Ni0.9Mg0.1TeO6 → Magnetic Order: AFM
# 936. 0.936Sr2MnTeO6       → Magnetic Order: AFM
# 937. 0.937Sr2CoTeO6       → Magnetic Order: AFM
# 938. 0.938TbNi3Ga2        → Magnetic Order: FiM
# 939. 0.939NiMn0.85Ti0.15Ge → Magnetic Order: Complex
# 940. 0.940NiMn0.75Ti0.25Ge → Magnetic Order: Complex
# 941. 0.941Er2O3           → Magnetic Order: Complex
# 942. 0.942Er2Ge2O7        → Magnetic Order: Complex
# 943. 0.943Yb2Ge2O7        → Magnetic Order: Complex
# 944. 0.944Yb2Ir2O7        → Magnetic Order: Complex
# 945. 0.945Yb2Ir2O7        → Magnetic Order: Complex
# 946. 0.946YCr0.5Fe0.5O3   → Magnetic Order: AFM
# 947. 0.947YCrO3           → Magnetic Order: AFM
# 948. 0.948CaNi3P4O14      → Magnetic Order: Complex
# 949. 0.949(La0.5Er0.5)2O3 → Magnetic Order: Complex
# 950. 0.950LaErO3          → Magnetic Order: Complex
# 951. 0.951LaYbO3          → Magnetic Order: Complex
# 952. 0.952YbPdSi          → Magnetic Order: Complex
# 953. 0.953Pb2FeMoO6       → Magnetic Order: AFM
# 954. 0.954Nd2Ir2O7        → Magnetic Order: Complex
# 955. 0.955Na2Mn(H2C3O4)2(H2O)2 → Magnetic Order: AFM
# 956. 0.956Fe2.71GeTe2     → Magnetic Order: FM
# 957. 0.957Fe2.90GeTe2     → Magnetic Order: FiM
# 958. 0.958Mn3Si2Te6       → Magnetic Order: Complex
# 959. 0.959Cr2TeO6         → Magnetic Order: AFM
# 960. 0.960Fe2TeO6         → Magnetic Order: AFM
# 961. 0.961LiCrGe2O6       → Magnetic Order: AFM
# 962. 0.962LiCrGe2O6       → Magnetic Order: AFM
# 963. 0.963LiCrGe2O6       → Magnetic Order: AFM
# 964. 0.964LiCrGe2O6       → Magnetic Order: AFM
# 965. 0.965LuFe2O4         → Magnetic Order: AFM
# ...
# 1859. 1.690TmMn2Ge2        → Magnetic Order: AFM
# 1860. 1.691YMn2Ge2         → Magnetic Order: AFM
# 1861. 1.692YMn2Ge2         → Magnetic Order: AFM
# 1862. 1.693DyMn2Ge2        → Magnetic Order: AFM
# 1863. 1.694TbMn2Ge2        → Magnetic Order: AFM
# 1864. 1.695Mn3Ni2Si        → Magnetic Order: AFM
# 1865. 1.696HoNiSi2         → Magnetic Order: AFM
# 1866. 1.697Tb5Pd2In4       → Magnetic Order: AFM
# 1867. 1.698Dy2TiO5         → Magnetic Order: Complex
# 1868. 1.699GdInCu4         → Magnetic Order: AFM
# 1869. 1.700HoInCu4         → Magnetic Order: AFM
# 1870. 1.701HoCdCu4         → Magnetic Order: AFM
# 1871. 1.702YBaCo2O5        → Magnetic Order: AFM
# 1872. 1.703YBaCo2O5        → Magnetic Order: AFM
# 1873. 1.704TaBaFe2O5       → Magnetic Order: AFM
# 1874. 1.705Na2Ni2TeO6      → Magnetic Order: Complex
# 1875. 1.706Ba2MnTeO6       → Magnetic Order: AFM
# 1876. 1.707Ba2MnWO6        → Magnetic Order: AFM
# 1877. 1.708CrPS4           → Magnetic Order: AFM
# 1878. 1.709CsCrF4          → Magnetic Order: Complex
# 1879. 1.710BaFe2Se3        → Magnetic Order: Complex
# 1880. 1.711CsCr0.94Fe0.06F4 → Magnetic Order: Complex
# 1881. 1.712CsCr0.98Al0.02F4 → Magnetic Order: Complex
# 1882. 1.713CsCr0.98Al0.02F4 → Magnetic Order: Complex
# 1883. 1.714CeAuBi2         → Magnetic Order: AFM
# 1884. 1.715Sr2CoWO6        → Magnetic Order: AFM
# 1885. 1.716Sr2MnMoO6       → Magnetic Order: Complex
# 1886. 1.717Sr2MnWO6        → Magnetic Order: Complex
# 1887. 1.718Ca2MnWO6        → Magnetic Order: Complex
# 1888. 1.719Ca2MnWO6        → Magnetic Order: AFM
# 1889. 1.720Yb2O3           → Magnetic Order: Complex
# 1890. 1.721UCu5            → Magnetic Order: AFM
# 1891. 1.722Ba3LaRu2O9      → Magnetic Order: AFM
# 1892. 1.723NaMn2O4         → Magnetic Order: AFM
# 1893. 1.724Ba2NiTeO6       → Magnetic Order: AFM
# 1894. 1.725Ba3NiTa2O9      → Magnetic Order: Complex
# 1895. 1.726RuCl3           → Magnetic Order: AFM
# 1896. 1.727Tm3Cu4Ge4       → Magnetic Order: AFM
# 1897. 1.728Tm3Cu4Sn4       → Magnetic Order: AFM
# 1898. 1.729Gd2Fe2Si2C      → Magnetic Order: AFM
# 1899. 1.730Cu2MnSiS4       → Magnetic Order: Complex
# 1900. 1.731Cu2FeSiS4       → Magnetic Order: Complex
# 1901. 1.732Cu2MnSnS4       → Magnetic Order: AFM
# 1902. 1.733Cu2MnGeS4       → Magnetic Order: Complex
# 1903. 1.734Cu2FeGeS4       → Magnetic Order: AFM
# 1904. 1.735Li2FeGeS4       → Magnetic Order: AFM
# 1905. 1.736Mn(N2H5)2(SO4)2 → Magnetic Order: AFM
# 1906. 1.737CeRh0.25Pd0.75Sn → Magnetic Order: AFM
# 1907. 1.738TbNiAl          → Magnetic Order: AFM
# 1908. 1.739Cu9O2(SeO3)4Cl6 → Magnetic Order: Complex
# 1909. 1.740CeAuSb2         → Magnetic Order: AFM
# 1910. 1.741KNiAsO4         → Magnetic Order: AFM
# 1911. 1.742KNiAsO4         → Magnetic Order: AFM
# 1912. 1.743CeRhGe3         → Magnetic Order: AFM
# 1913. 1.744PrPdSn          → Magnetic Order: AFM
# 1914. 1.745La2Co3          → Magnetic Order: Complex
# 1915. 1.746YMn2            → Magnetic Order: AFM
# 1916. 1.747ErAuIn          → Magnetic Order: Complex
# 1917. 1.748TbAuIn          → Magnetic Order: Complex
# 1918. 1.749HoSbTe          → Magnetic Order: AFM
# 1919. 1.750HoSbTe          → Magnetic Order: AFM
# 1920. 1.751CaCo3Ti4O12     → Magnetic Order: Complex
# 1921. 1.752CsCo2(MoO4)2(OH) → Magnetic Order: Complex
# 1922. 1.753HoBi            → Magnetic Order: AFM
# 1923. 1.754BaFe2O4         → Magnetic Order: AFM
# 1924. 1.755KErSe2          → Magnetic Order: AFM
# 1925. 1.756CaFe3O5         → Magnetic Order: AFM
# 1926. 1.757Pr2PdAl7Ge4     → Magnetic Order: Complex
# 1927. 1.758CaMn3V4O12      → Magnetic Order: Complex
# 1928. 1.759ZnFe2O4         → Magnetic Order: Complex
# 1929. 1.760ZnFe2O4         → Magnetic Order: Complex
# 1930. 1.761ZnFe2O4         → Magnetic Order: AFM
# 1931. 1.762CaFe3O5         → Magnetic Order: AFM
# 1932. 1.763BaNiTe2O7       → Magnetic Order: Complex
# 1933. 1.764NdSbTe          → Magnetic Order: Complex
# 1934. 1.765DySbTe          → Magnetic Order: AFM
# 1935. 1.766DySbTe          → Magnetic Order: AFM
# 1936. 1.767Li2CoCl4        → Magnetic Order: AFM
# 1937. 1.768Ni2Mo3O8        → Magnetic Order: Complex
# 1938. 1.769Ni2Te3O8        → Magnetic Order: Complex
# 1939. 1.770Tb2Ni2In        → Magnetic Order: AFM
# 1940. 1.771Na2Co2TeO6      → Magnetic Order: AFM
# 1941. 1.772Pr2PdAl7Ge4     → Magnetic Order: Complex
# 1942. 1.773PrIr3B2         → Magnetic Order: AFM
# 1943. 1.774BaNd2PtO5       → Magnetic Order: Complex
# 1944. 1.775CaCu3Ti4O12     → Magnetic Order: Complex
# 1945. 1.776Ba2ErRuO6       → Magnetic Order: AFM
# 1946. 1.777EuAl2Si2        → Magnetic Order: AFM
# 1947. 1.778ThCr2Si2C       → Magnetic Order: AFM
# 1948. 1.779Sr2FeIrO6       → Magnetic Order: AFM
# 1949. 1.780YMn12           → Magnetic Order: Complex
# 1950. 1.781CsMn(NCS)3      → Magnetic Order: Complex
# 1951. 1.782FeBr3           → Magnetic Order: AFM
# 1952. 1.783Fe0.99O         → Magnetic Order: AFM
# 1953. 1.784Li2CoCl4        → Magnetic Order: AFM
# 1954. 1.785K2ReCl6         → Magnetic Order: AFM
# 1955. 1.786RuBr3           → Magnetic Order: AFM
# 1956. 1.787RuCl3           → Magnetic Order: AFM
# 1957. 1.788Na3Co2SbO6      → Magnetic Order: AFM
# 1958. 1.789Na3Ni2BiO6      → Magnetic Order: AFM
# 1959. 1.790Tm5Pt2In4       → Magnetic Order: Complex
# 1960. 1.791La0.4Na0.6Fe2As2 → Magnetic Order: AFM
# 1961. 1.792V3O5            → Magnetic Order: Complex
# 1962. 1.793Ca3Ru2O7        → Magnetic Order: AFM
# 1963. 1.794Ca3Ru2O7        → Magnetic Order: AFM
# 1964. 1.795BiMn3Cr4O12     → Magnetic Order: AFM
# 1965. 1.796BiMn3Cr4O12     → Magnetic Order: AFM
# 1966. 1.797BiMn3Cr4O12     → Magnetic Order: AFM
# 1967. 1.798Tb2O3           → Magnetic Order: Complex
# 1968. 1.799MnO             → Magnetic Order: AFM
# 1969. 1.800NiO             → Magnetic Order: AFM
# 1970. 1.801Tb3NbO7         → Magnetic Order: Complex
# 1971. 1.802CrSBr           → Magnetic Order: AFM
# 1972. 1.803LiCrTe2         → Magnetic Order: AFM
# 1973. 1.804Na2Cu3O(SO4)3   → Magnetic Order: Complex
# 1974. 1.805FeVMoO7         → Magnetic Order: AFM
# 1975. 1.806CrVMoO7         → Magnetic Order: AFM
# 1976. 1.807FeWO4           → Magnetic Order: AFM
# 1977. 1.808BaFeO2.96       → Magnetic Order: AFM
# 1978. 1.809BiCoO3          → Magnetic Order: AFM
# 1979. 1.810BiCoO3          → Magnetic Order: AFM
# 1980. 1.811BiCoO3          → Magnetic Order: AFM
# 1981. 1.812TbFe6Ge6        → Magnetic Order: AFM
# 1982. 1.813TbFe6Ge6        → Magnetic Order: AFM
# 1983. 1.814TbFe6Ge6        → Magnetic Order: AFM
# 1984. 1.815Ba4CeMn3O12     → Magnetic Order: AFM
# 1985. 1.816Ba4PrMn3O12     → Magnetic Order: Complex
# 1986. 1.817Ba4PrMn3O12     → Magnetic Order: Complex
# 1987. 1.818(Ho0.68Lu0.32)2Fe2Si2C → Magnetic Order: AFM
# 1988. 1.819(Ho0.54Lu0.46)2Fe2Si2C → Magnetic Order: AFM
# 1989. 1.820Ba4TbRu3O12     → Magnetic Order: AFM
# 1990. 1.821Yb3Ga5O12       → Magnetic Order: Complex
# 1991. 1.822Sr2MnSi2O7      → Magnetic Order: AFM
# 1992. 1.823Sr2MnSi2O7      → Magnetic Order: Complex
# 1993. 1.824PbCo2V2O8       → Magnetic Order: AFM
# 1994. 1.825TbFeWO6         → Magnetic Order: Complex
# 1995. 1.826NdZnPO          → Magnetic Order: AFM
# 1996. 1.827(Co0.45Fe0.55)Sn → Magnetic Order: AFM
# 1997. 1.828ZnFe2O4         → Magnetic Order: Complex
# 1998. 1.829LuFeWO6         → Magnetic Order: Complex
# 1999. 1.830FeBi4S7         → Magnetic Order: AFM
# 2000. 1.831Y6FeSi2S14      → Magnetic Order: AFM
# 2001. 1.832Tb6FeSi2S14     → Magnetic Order: Complex
# 2002. 1.833Pb(OF)Cu3(SeO3)2(NO3) → Magnetic Order: Complex
# 2003. 1.834Na3Co(CO3)2Cl   → Magnetic Order: Complex
# 2004. 1.835La2Co2O3Se2     → Magnetic Order: Complex
# 2005. 1.836CeLi3Bi2        → Magnetic Order: AFM
# 2006. 1.837Y2Co3           → Magnetic Order: AFM
# 2007. 1.838LaMn2Au4        → Magnetic Order: AFM
# 2008. 1.839LaMnAu5         → Magnetic Order: Complex
# 2009. 1.840Sr2Mn2O5        → Magnetic Order: Complex
# 2010. 1.841Sr3Fe2O5Cl2     → Magnetic Order: AFM
# 2011. 1.842Ca2FeO3Cl       → Magnetic Order: Complex
# 2012. 1.843Ca2FeO3Cl       → Magnetic Order: Complex
# 2013. 1.844Sr2FeO3Cl       → Magnetic Order: Complex
# 2014. 1.845Sr2FeO3Cl       → Magnetic Order: Complex
# 2015. 1.846LaCu3Fe4O12     → Magnetic Order: AFM
# 2016. 1.847PrCaFeO4        → Magnetic Order: AFM
# 2017. 1.848La2Ba2Mn4O11    → Magnetic Order: AFM
# 2018. 1.849Na3Ni2SbO6      → Magnetic Order: AFM
# 2019. 1.850Tb6FeSi2S14     → Magnetic Order: Complex
# 2020. 1.851Y6FeSi2S14      → Magnetic Order: AFM
# 2021. 1.852UCu0.6Bi2       → Magnetic Order: AFM
# 2022. 1.853Ba2YFeO5        → Magnetic Order: Complex
# 2023. 2.1EuFe2As2          → Magnetic Order: AFM
# 2024. 2.2Sr2F2Fe2OS2       → Magnetic Order: Complex
# 2025. 2.3HoNiO3            → Magnetic Order: Complex
# 2026. 2.4Eu(Fe0.82Co0.18)As2 → Magnetic Order: Complex
# 2027. 2.5Mn3CuN            → Magnetic Order: Complex
# 2028. 2.6Nd2CuO4           → Magnetic Order: Complex
# 2029. 2.7Sm2CuO4           → Magnetic Order: Complex
# 2030. 2.8SrHo2O4           → Magnetic Order: Complex
# 2031. 2.9Ca3CuNi2(PO4)4    → Magnetic Order: Complex
# 2032. 2.10HoP              → Magnetic Order: Complex
# 2033. 2.11TbMg             → Magnetic Order: Complex
# 2034. 2.12TbMg             → Magnetic Order: Complex
# 2035. 2.13UP               → Magnetic Order: Complex
# 2036. 2.14NdMg             → Magnetic Order: Complex
# 2037. 2.15Mn3Ni20P6        → Magnetic Order: AFM
# 2038. 2.16Ce2PdGe3         → Magnetic Order: Complex
# 2039. 2.17Pb2Mn0.6Co0.4WO6 → Magnetic Order: AFM
# 2040. 2.18Sc2NiMnO6        → Magnetic Order: AFM
# 2041. 2.19Mn3ZnC           → Magnetic Order: Complex
# 2042. 2.20UAs              → Magnetic Order: Complex
# 2043. 2.21TbOOH            → Magnetic Order: Complex
# 2044. 2.22FeTa2O6          → Magnetic Order: Complex
# 2045. 2.23Sr2CoO2Ag2Se2    → Magnetic Order: Complex
# 2046. 2.24Ba2CoO2Ag2Se2    → Magnetic Order: Complex
# 2047. 2.25Sr2CoOsO6        → Magnetic Order: Complex
# 2048. 2.26PrCo2P2          → Magnetic Order: AFM
# 2049. 2.27Sr2Mn3Sb2O2      → Magnetic Order: Complex
# 2050. 2.28NpNiGa5          → Magnetic Order: Complex
# 2051. 2.29Mn3O4            → Magnetic Order: Complex
# 2052. 2.30CeRh2Si2         → Magnetic Order: AFM
# 2053. 2.31Mn3ZnN           → Magnetic Order: Complex
# 2054. 2.32Dy3Ru4Al12       → Magnetic Order: Complex
# 2055. 2.33Na2Mn3Se4        → Magnetic Order: Complex
# 2056. 2.34La0.25Pr0.75Co2P2 → Magnetic Order: Complex
# 2057. 2.35CrSe             → Magnetic Order: Complex
# 2058. 2.36TbGe3            → Magnetic Order: AFM
# 2059. 2.37La8Cu7O19        → Magnetic Order: Complex
# 2060. 2.38Pb2MnWO6         → Magnetic Order: Complex
# 2061. 2.39LaCaFeO4         → Magnetic Order: Complex
# 2062. 2.40LaBaFeO4         → Magnetic Order: Complex
# 2063. 2.41LaSrFeO4         → Magnetic Order: Complex
# 2064. 2.42LaSrFeO4         → Magnetic Order: Complex
# 2065. 2.43Fe2MnBO5         → Magnetic Order: Complex
# 2066. 2.44KCuMnS2          → Magnetic Order: Complex
# 2067. 2.45Pb2BaCuFeO5Br    → Magnetic Order: Complex
# 2068. 2.46Pb2BaCuFeO5Cl    → Magnetic Order: Complex
# 2069. 2.47Y2SrCuFeO6.5     → Magnetic Order: Complex
# 2070. 2.48Pr2CuO4          → Magnetic Order: Complex
# 2071. 2.49La2O2Fe2OSe2     → Magnetic Order: Complex
# 2072. 2.50EuMnBi2          → Magnetic Order: AFM
# 2073. 2.51EuMnBi2          → Magnetic Order: Complex
# 2074. 2.52Mn3O4            → Magnetic Order: Complex
# 2075. 2.53Ba2Mn3Sb2O2      → Magnetic Order: Complex
# 2076. 2.54Sr2Cr3As2O2      → Magnetic Order: Complex
# 2077. 2.55Sr2Fe3Se2O3      → Magnetic Order: Complex
# 2078. 2.56La2O2Fe2OS2      → Magnetic Order: Complex
# 2079. 2.57TbMn2Si2         → Magnetic Order: Complex
# 2080. 2.58La0.73Tb0.27Mn2Si2 → Magnetic Order: Complex
# 2081. 2.59Mn3As2           → Magnetic Order: Complex
# 2082. 2.60NdMn2Si2         → Magnetic Order: Complex
# 2083. 2.61Fe3F8(H2O)2      → Magnetic Order: Complex
# 2084. 2.62TbCrO3           → Magnetic Order: Complex
# 2085. 2.63DyCrO3           → Magnetic Order: Complex
# 2086. 2.64DyCrO3           → Magnetic Order: Complex
# 2087. 2.65UPd2Si2          → Magnetic Order: AFM
# 2088. 2.66FeSn2            → Magnetic Order: Complex
# 2089. 2.67FeSn2            → Magnetic Order: Complex
# 2090. 2.68FeGe2            → Magnetic Order: Complex
# 2091. 2.69La0.5Ca0.5MnO3   → Magnetic Order: Complex
# 2092. 2.70GdMg             → Magnetic Order: Complex
# 2093. 2.71HoRh             → Magnetic Order: Complex
# 2094. 2.72VNb3S6           → Magnetic Order: Complex
# 2095. 2.73BaNd2ZnO5        → Magnetic Order: Complex
# 2096. 2.74BaDy2O4          → Magnetic Order: AFM
# 2097. 2.75Sr2Fe3S2O3       → Magnetic Order: Complex
# 2098. 2.76Sr2Fe3Se2O3      → Magnetic Order: Complex
# 2099. 2.77Eu2CuO4          → Magnetic Order: Complex
# 2100. 2.78Nd2CuO4          → Magnetic Order: Complex
# 2101. 2.79Pr2CuO4          → Magnetic Order: Complex
# 2102. 2.80ErFe6Ge6         → Magnetic Order: AFM
# 2103. 2.81ErMn2Si2         → Magnetic Order: Complex
# 2104. 2.82ErMn2Si2         → Magnetic Order: Complex
# 2105. 2.83ErMn2Ge2         → Magnetic Order: Complex
# 2106. 2.84ErMn2Ge2         → Magnetic Order: Complex
# 2107. 2.85Ho2BaCuO5        → Magnetic Order: Complex
# 2108. 2.86FeTa2O6          → Magnetic Order: Complex
# 2109. 2.87TbCoGa5          → Magnetic Order: Complex
# 2110. 2.88UNiGa            → Magnetic Order: AFM
# 2111. 2.89LaSrCrO4         → Magnetic Order: Complex
# 2112. 2.90Mn3O4            → Magnetic Order: Complex
# 2113. 2.91NaCo2(SeO3)2(OH) → Magnetic Order: Complex
# 2114. 2.92Er2Ni2Pb         → Magnetic Order: AFM
# 2115. 2.93CoCrO4           → Magnetic Order: Complex
# 2116. 2.94TmMn2Ge2         → Magnetic Order: Complex
# 2117. 2.95TbMn2Ge2         → Magnetic Order: AFM
# 2118. 2.96GdMn2Si2         → Magnetic Order: Complex
# 2119. 2.97GdMn2Si2         → Magnetic Order: Complex
# 2120. 2.98EuMnBi2          → Magnetic Order: AFM
# 2121. 2.99TbNiAl           → Magnetic Order: AFM
# 2122. 2.100HoP             → Magnetic Order: Complex
# 2123. 2.101TbSbTe          → Magnetic Order: Complex
# 2124. 2.102TbSbTe          → Magnetic Order: Complex
# 2125. 2.103Eu3PbO          → Magnetic Order: AFM
# 2126. 2.104BaNd2ZnS5       → Magnetic Order: Complex
# 2127. 2.105DySbTe          → Magnetic Order: Complex
# 2128. 2.106CaCo3V4O12      → Magnetic Order: AFM
# 2129. 2.107DyTe3           → Magnetic Order: Complex
# 2130. 2.108Tb3NbO7         → Magnetic Order: Complex
# 2131. 2.109La0.35Pr0.35Ca0.3MnO3 → Magnetic Order: AFM
# 2132. 2.110La0.35Pr0.35Ca0.3MnO3 → Magnetic Order: Unknown
# 2133. 2.111TbFe6Ge6        → Magnetic Order: Complex
# 2134. 2.112TbFe6Ge6        → Magnetic Order: Complex
# 2135. 2.113TbFe6Ge6        → Magnetic Order: Complex
# 2136. 2.114Er2CuMn5O12     → Magnetic Order: Complex
# 2137. 2.115Er2CuMn5O12     → Magnetic Order: Complex
# 2138. 2.116Na3Co2SbO6      → Magnetic Order: Complex
# 2139. 3.1TmAgGe            → Magnetic Order: Complex
# 2140. 3.2UO2               → Magnetic Order: Complex
# 2141. 3.3Ho2RhIn8          → Magnetic Order: AFM
# 2142. 3.4MgCr2O4           → Magnetic Order: Complex
# 2143. 3.5Fe0.7Mn0.3        → Magnetic Order: Complex
# 2144. 3.6DyCu              → Magnetic Order: Complex
# 2145. 3.7NpBi              → Magnetic Order: Complex
# 2146. 3.8NdZn              → Magnetic Order: Complex
# 2147. 3.9NpS               → Magnetic Order: Complex
# 2148. 3.10NpSe             → Magnetic Order: Complex
# 2149. 3.11NpTe             → Magnetic Order: Complex
# 2150. 3.12USb              → Magnetic Order: Complex
# 2151. 3.13CeB6             → Magnetic Order: Complex
# 2152. 3.14FeI2             → Magnetic Order: AFM
# 2153. 3.15FeI2             → Magnetic Order: AFM
# 2154. 3.16Gd2Ti2O7         → Magnetic Order: Complex
# 2155. 3.17BaCu3V2O8(OD)2   → Magnetic Order: Complex
# 2156. 3.18HoRh             → Magnetic Order: Complex
# 2157. 3.19CoO              → Magnetic Order: Complex
# 2158. 3.20TbMn2Ge2         → Magnetic Order: Complex
# 2159. 3.21TmGa3            → Magnetic Order: Complex
# 2160. 3.22Eu3PbO           → Magnetic Order: Complex
# 2161. 3.23Eu3PbO           → Magnetic Order: AFM
# 2162. 3.24CaFe3Ti4O12      → Magnetic Order: Complex
# 2163. 3.25CoTa3S6          → Magnetic Order: Complex
# 2164. 3.26CoNb3S6          → Magnetic Order: Complex
# 2165. 3.27Gd3Ru4Al12       → Magnetic Order: Complex
# 2166. 3.28NiO              → Magnetic Order: Complex
# 2167. 3.29Na2Co2TeO6       → Magnetic Order: Complex
# ✅ Saved to 'MAGNDATA_MagneticOrder_AllSpecies.csv'

# %%
import pandas as pd

# Load your classified file
df = pd.read_csv("MAGNDATA_MagneticOrder_AllSpecies.csv")

# Replace Unknown and Complex with AFM
df["Magnetic Order"] = df["Magnetic Order"].replace({"Unknown": "AFM", "Complex": "AFM"})

# Save new CSV
df.to_csv("MAGNDATA_Reclassified.csv", index=False)

print("✅ Saved updated file as 'MAGNDATA_Reclassified.csv'")
# Out:
# ✅ Saved updated file as 'MAGNDATA_Reclassified.csv'

# %%
import pandas as pd

# Load both datasets
magndata = pd.read_csv("MAGNDATA_Reclassified.csv")
materials = pd.read_csv("All Data Imported.csv")

# Extract formula from MAGNDATA label (e.g. '0.123ABC' → 'ABC')
magndata["formula"] = magndata["Full Label"].str.extract(r"\d*\.\d+(.*)")[0].str.strip()
materials["formula"] = materials["formula"].str.strip()

# Left join: keep only MAGNDATA entries
merged = pd.merge(magndata, materials, on="formula", how="left")

# Save result
merged.to_csv("MAGNDATA_Enriched_WithMP.csv", index=False)
print("✅ Saved merged file: 'MAGNDATA_Enriched_WithMP.csv'")
# Out:
# ✅ Saved merged file: 'MAGNDATA_Enriched_WithMP.csv'
